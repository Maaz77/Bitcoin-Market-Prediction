# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle as pkl
import numpy as np
import pandas as pd 


with open('/content/drive/MyDrive/Dataset_with_memory /5min/X_train_5min.pickle', 'rb') as f:
    X_train = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /5min/Y_train_5min.pickle', 'rb') as f:
    Y_train = pkl.load(f)


with open('/content/drive/MyDrive/Dataset_with_memory /5min/Y_val_5min.pickle', 'rb') as f:
    Y_val = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /5min/X_val_5min.pickle', 'rb') as f:
     X_val = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /5min/Y_test_5min.pickle', 'rb') as f:
    Y_test = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /5min/X_test_5min.pickle', 'rb') as f:
     X_test = pkl.load(f)


Y_train = Y_train.reshape((-1,1))
Y_val = Y_val.reshape((-1,1))
Y_test = Y_test.reshape((-1,1))

X_train.shape , Y_train.shape , X_val.shape , Y_val.shape , X_test.shape , Y_test.shape
# Out:
# ((225480, 120, 5),
#  (225480, 1),
#  (45000, 120, 5),
#  (45000, 1),
#  (135240, 120, 5),
#  (135240, 1))

# %%
from sklearn.utils.class_weight import compute_class_weight



class_weights = compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique ( np.reshape( Y_train , (np.shape(Y_train)[0]))),
                                        y = np.reshape(Y_train ,(np.shape(Y_train)[0]))                                                 
                                    )
class_weights = dict(zip(np.unique(np.reshape(Y_train ,(np.shape(Y_train)[0]))), class_weights))
class_weights
# Out:
# {0: 1.0362703825578616, 1: 0.9661827468590919}

# %%
import os

filepath = "/content/drive/MyDrive/parameter_tuning_GRU_5min.csv"

# check if the file exists, create it if not
if not os.path.isfile(filepath):
    columns_name = ['GRU_blocks', 'learning_rate', 'regularizer', 'droput', 'optimizer', 'batch size' , 'weight_decay',
                    'train_loss' , 'val_loss' , 'train_accuracy' , 'val_accuracy', 'test_loss' , 'test_accuracy']
    df = pd.DataFrame(columns=columns_name)  # create an empty dataframe
    df.to_csv(filepath, index=False)  # save as a CSV file with no index

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, BatchNormalization
from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import load_model
from tensorflow.keras import regularizers
from tensorflow import keras
import numpy as np 

#reproducibility 
np.random.seed(0)
tf.random.set_seed(0)

#defining hyperparameters

weight_decay = 1e-7
GRU_blocks= 20
regularizer = 0
lr = 0.001
dropout  = 0.5
batchsize = 128
optimizer_func = 'Adam'
#threshold = 0.5

# Define the model
def create_model(GRU_blocks, regularizer, dropout):
    model = Sequential()
    #model.add(BatchNormalization(input_shape=(120, 5)))
    model.add(GRU(GRU_blocks, input_shape=(120, 5) , return_sequences=False, activation='tanh', bias_regularizer=regularizers.l1(regularizer),  kernel_regularizer=regularizers.l1(regularizer)))
   

    model.add(Dropout(dropout))

    model.add(Dense(50, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.summary()
    return model 


model = create_model(GRU_blocks, regularizer, dropout)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 20)                1620
#
#  dropout (Dropout)           (None, 20)                0
#
#  dense (Dense)               (None, 50)                1050
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 2,721
# Trainable params: 2,721
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
optimizer = keras.optimizers.Adam(learning_rate=lr,weight_decay=weight_decay) if optimizer_func == 'Adam' else keras.optimizers.SGD(learning_rate=lr ,weight_decay=weight_decay)

model.compile(loss='binary_crossentropy', optimizer= optimizer, metrics=['binary_accuracy' ])


checkpoint_path = '/content/drive/MyDrive/my_best_model_GRU_5min.hdf5'

checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             monitor='val_binary_accuracy',
                             verbose=1, 
                             save_best_only=True,
                             mode='max')


earlystopping = EarlyStopping(monitor='val_binary_accuracy', patience=10, restore_best_weights=True)

callback = [earlystopping, checkpoint]
# Train the model
history = model.fit(X_train, Y_train, validation_data=(X_val , Y_val) , verbose=1,  batch_size=batchsize, epochs=150,callbacks = callback, class_weight=class_weights)

loss, accuracy = model.evaluate(X_test, Y_test, batch_size=batchsize)

print(f"Loss: {loss:.4f}")
print(f"Accuracy: {accuracy*100:.2f}%")

filepath = "/content/drive/MyDrive/parameter_tuning_GRU_5min.csv"
parameters_to_save = pd.read_csv(filepath)

parameters_to_save = parameters_to_save.append({'GRU_blocks' : GRU_blocks, 'learning_rate': lr, 'regularizer': regularizer, 'droput': dropout, 
                                                'optimizer': optimizer_func, 'batch size': batchsize, 'weight_decay': weight_decay,
                                                'train_loss' : history.history['loss'][-1] ,'val_loss' : history.history['val_loss'][-1] , 
                                                'train_accuracy' : history.history['binary_accuracy'][-1] , 'val_accuracy' : history.history['val_binary_accuracy'][-1],
                                                'test_loss' : f"{loss:.4f}" , 'test_accuracy' : f"{accuracy*100:.2f}%" } , ignore_index = True ) 

parameters_to_save.to_csv(filepath, index=False)
# Out:
# Epoch 1/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.4678 - binary_accuracy: 0.7840
# Epoch 1: val_binary_accuracy improved from -inf to 0.78049, saving model to /content/drive/MyDrive/my_best_model_GRU_5min.hdf5
# 1762/1762 [==============================] - 26s 9ms/step - loss: 0.4678 - binary_accuracy: 0.7840 - val_loss: 0.4667 - val_binary_accuracy: 0.7805
# Epoch 2/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.4253 - binary_accuracy: 0.8066
# Epoch 2: val_binary_accuracy improved from 0.78049 to 0.80009, saving model to /content/drive/MyDrive/my_best_model_GRU_5min.hdf5
# 1762/1762 [==============================] - 15s 9ms/step - loss: 0.4253 - binary_accuracy: 0.8066 - val_loss: 0.4288 - val_binary_accuracy: 0.8001
# Epoch 3/150
# 1756/1762 [============================>.] - ETA: 0s - loss: 0.3959 - binary_accuracy: 0.8225
# Epoch 3: val_binary_accuracy improved from 0.80009 to 0.82722, saving model to /content/drive/MyDrive/my_best_model_GRU_5min.hdf5
# 1762/1762 [==============================] - 15s 9ms/step - loss: 0.3959 - binary_accuracy: 0.8225 - val_loss: 0.3823 - val_binary_accuracy: 0.8272
# Epoch 4/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.3685 - binary_accuracy: 0.8381
# Epoch 4: val_binary_accuracy improved from 0.82722 to 0.82931, saving model to /content/drive/MyDrive/my_best_model_GRU_5min.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.3684 - binary_accuracy: 0.8382 - val_loss: 0.3817 - val_binary_accuracy: 0.8293
# Epoch 5/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.3627 - binary_accuracy: 0.8418
# Epoch 5: val_binary_accuracy improved from 0.82931 to 0.83384, saving model to /content/drive/MyDrive/my_best_model_GRU_5min.hdf5
# 1762/1762 [==============================] - 15s 9ms/step - loss: 0.3627 - binary_accuracy: 0.8418 - val_loss: 0.3726 - val_binary_accuracy: 0.8338
# Epoch 6/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.3592 - binary_accuracy: 0.8431
# Epoch 6: val_binary_accuracy improved from 0.83384 to 0.83762, saving model to /content/drive/MyDrive/my_best_model_GRU_5min.hdf5
# 1762/1762 [==============================] - 17s 9ms/step - loss: 0.3592 - binary_accuracy: 0.8431 - val_loss: 0.3686 - val_binary_accuracy: 0.8376
# Epoch 7/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.3571 - binary_accuracy: 0.8439
# Epoch 7: val_binary_accuracy did not improve from 0.83762
# 1762/1762 [==============================] - 15s 9ms/step - loss: 0.3571 - binary_accuracy: 0.8439 - val_loss: 0.3686 - val_binary_accuracy: 0.8361
# Epoch 8/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.3560 - binary_accuracy: 0.8450
# Epoch 8: val_binary_accuracy did not improve from 0.83762
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3560 - binary_accuracy: 0.8450 - val_loss: 0.3684 - val_binary_accuracy: 0.8374
# Epoch 9/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.3547 - binary_accuracy: 0.8450
# Epoch 9: val_binary_accuracy did not improve from 0.83762
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3547 - binary_accuracy: 0.8450 - val_loss: 0.3724 - val_binary_accuracy: 0.8344
# Epoch 10/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.3538 - binary_accuracy: 0.8460
# Epoch 10: val_binary_accuracy did not improve from 0.83762
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3539 - binary_accuracy: 0.8460 - val_loss: 0.3670 - val_binary_accuracy: 0.8376
# Epoch 11/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.3527 - binary_accuracy: 0.8468
# Epoch 11: val_binary_accuracy did not improve from 0.83762
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3527 - binary_accuracy: 0.8468 - val_loss: 0.3710 - val_binary_accuracy: 0.8360
# Epoch 12/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.3520 - binary_accuracy: 0.8469
# Epoch 12: val_binary_accuracy improved from 0.83762 to 0.83802, saving model to /content/drive/MyDrive/my_best_model_GRU_5min.hdf5
# 1762/1762 [==============================] - 15s 9ms/step - loss: 0.3520 - binary_accuracy: 0.8469 - val_loss: 0.3672 - val_binary_accuracy: 0.8380
# Epoch 13/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.3521 - binary_accuracy: 0.8471
# Epoch 13: val_binary_accuracy improved from 0.83802 to 0.83842, saving model to /content/drive/MyDrive/my_best_model_GRU_5min.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.3520 - binary_accuracy: 0.8471 - val_loss: 0.3675 - val_binary_accuracy: 0.8384
# Epoch 14/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.3512 - binary_accuracy: 0.8473
# Epoch 14: val_binary_accuracy did not improve from 0.83842
# 1762/1762 [==============================] - 15s 9ms/step - loss: 0.3512 - binary_accuracy: 0.8472 - val_loss: 0.3662 - val_binary_accuracy: 0.8378
# Epoch 15/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.3502 - binary_accuracy: 0.8476
# Epoch 15: val_binary_accuracy improved from 0.83842 to 0.84022, saving model to /content/drive/MyDrive/my_best_model_GRU_5min.hdf5
# 1762/1762 [==============================] - 15s 9ms/step - loss: 0.3502 - binary_accuracy: 0.8476 - val_loss: 0.3630 - val_binary_accuracy: 0.8402
# Epoch 16/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.3505 - binary_accuracy: 0.8476
# Epoch 16: val_binary_accuracy did not improve from 0.84022
# 1762/1762 [==============================] - 15s 9ms/step - loss: 0.3505 - binary_accuracy: 0.8476 - val_loss: 0.3657 - val_binary_accuracy: 0.8380
# Epoch 17/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.3500 - binary_accuracy: 0.8482
# Epoch 17: val_binary_accuracy did not improve from 0.84022
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3500 - binary_accuracy: 0.8482 - val_loss: 0.3689 - val_binary_accuracy: 0.8350
# Epoch 18/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.3490 - binary_accuracy: 0.8489
# Epoch 18: val_binary_accuracy did not improve from 0.84022
# 1762/1762 [==============================] - 15s 9ms/step - loss: 0.3490 - binary_accuracy: 0.8489 - val_loss: 0.3643 - val_binary_accuracy: 0.8398
# Epoch 19/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.3483 - binary_accuracy: 0.8486
# Epoch 19: val_binary_accuracy did not improve from 0.84022
# 1762/1762 [==============================] - 15s 9ms/step - loss: 0.3484 - binary_accuracy: 0.8486 - val_loss: 0.3635 - val_binary_accuracy: 0.8396
# Epoch 20/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.3487 - binary_accuracy: 0.8487
# Epoch 20: val_binary_accuracy did not improve from 0.84022
# 1762/1762 [==============================] - 15s 9ms/step - loss: 0.3488 - binary_accuracy: 0.8486 - val_loss: 0.3634 - val_binary_accuracy: 0.8382
# Epoch 21/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.3486 - binary_accuracy: 0.8492
# Epoch 21: val_binary_accuracy did not improve from 0.84022
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.3486 - binary_accuracy: 0.8492 - val_loss: 0.3658 - val_binary_accuracy: 0.8365
# Epoch 22/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.3474 - binary_accuracy: 0.8489
# Epoch 22: val_binary_accuracy did not improve from 0.84022
# 1762/1762 [==============================] - 15s 9ms/step - loss: 0.3473 - binary_accuracy: 0.8490 - val_loss: 0.3625 - val_binary_accuracy: 0.8389
# Epoch 23/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.3476 - binary_accuracy: 0.8493
# Epoch 23: val_binary_accuracy did not improve from 0.84022
# 1762/1762 [==============================] - 15s 9ms/step - loss: 0.3476 - binary_accuracy: 0.8493 - val_loss: 0.3660 - val_binary_accuracy: 0.8376
# Epoch 24/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.3476 - binary_accuracy: 0.8491
# Epoch 24: val_binary_accuracy did not improve from 0.84022
# 1762/1762 [==============================] - 15s 9ms/step - loss: 0.3477 - binary_accuracy: 0.8490 - val_loss: 0.3681 - val_binary_accuracy: 0.8367
# Epoch 25/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.3478 - binary_accuracy: 0.8486
# Epoch 25: val_binary_accuracy did not improve from 0.84022
# 1762/1762 [==============================] - 15s 9ms/step - loss: 0.3478 - binary_accuracy: 0.8486 - val_loss: 0.3677 - val_binary_accuracy: 0.8356
# 1057/1057 [==============================] - 5s 5ms/step - loss: 0.3857 - binary_accuracy: 0.8260
# Loss: 0.3857
# Accuracy: 82.60%
# <ipython-input-6-6bb51eb5460a>:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parameters_to_save = parameters_to_save.append({'GRU_blocks' : GRU_blocks, 'learning_rate': lr, 'regularizer': regularizer, 'droput': dropout,

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2,1, figsize = (15,15))
axs = axs.flatten()
axs[0].plot(history.history['binary_accuracy'])
axs[0].plot(history.history['val_binary_accuracy'])
axs[0].set_title('model accuracy')

axs[0].legend(['train', 'val'], loc='upper left')

# summarize history for loss
axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('model loss')

axs[1].legend(['train', 'val'], loc='upper left')
