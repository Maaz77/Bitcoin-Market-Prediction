# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pickle as pkl
import numpy as np
import pandas as pd 


with open('/content/drive/MyDrive/Dataset_with_memory /15min/X_train_15min.pickle', 'rb') as f:
    X_train = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /15min/Y_train_15min.pickle', 'rb') as f:
    Y_train = pkl.load(f)


with open('/content/drive/MyDrive/Dataset_with_memory /15min/Y_val_15min.pickle', 'rb') as f:
    Y_val = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /15min/X_val_15min.pickle', 'rb') as f:
     X_val = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /15min/Y_test_15min.pickle', 'rb') as f:
    Y_test = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /15min/X_test_15min.pickle', 'rb') as f:
     X_test = pkl.load(f)


Y_train = Y_train.reshape((-1,1))
Y_val = Y_val.reshape((-1,1))
Y_test = Y_test.reshape((-1,1))

X_train.shape , Y_train.shape , X_val.shape , Y_val.shape , X_test.shape , Y_test.shape
# Out:
# ((225480, 120, 5),
#  (225480, 1),
#  (45000, 120, 5),
#  (45000, 1),
#  (135240, 120, 5),
#  (135240, 1))

# %%
from sklearn.utils.class_weight import compute_class_weight



class_weights = compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique ( np.reshape( Y_train , (np.shape(Y_train)[0]))),
                                        y = np.reshape(Y_train ,(np.shape(Y_train)[0]))                                                 
                                    )
class_weights = dict(zip(np.unique(np.reshape(Y_train ,(np.shape(Y_train)[0]))), class_weights))
class_weights
# Out:
# {0: 1.0214917367352856, 1: 0.9793939815136563}

# %%
import os

filepath = "/content/drive/MyDrive/parameter_tuning_GRU_15min.csv"

# check if the file exists, create it if not
if not os.path.isfile(filepath):
    columns_name = ['GRU_blocks', 'learning_rate', 'regularizer', 'droput', 'optimizer', 'batch size' , 'weight_decay',
                    'train_loss' , 'val_loss' , 'train_accuracy' , 'val_accuracy', 'test_loss' , 'test_accuracy']
    df = pd.DataFrame(columns=columns_name)  # create an empty dataframe
    df.to_csv(filepath, index=False)  # save as a CSV file with no index

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, BatchNormalization
from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import load_model
from tensorflow.keras import regularizers
from tensorflow import keras
import numpy as np 

#reproducibility 
np.random.seed(0)
tf.random.set_seed(0)

#defining hyperparameters

weight_decay = 1e-7
GRU_blocks= 20
regularizer = 0.7
lr = 0.00005
dropout  = 0.5
batchsize = 1000
optimizer_func = 'Adam'
#threshold = 0.5

# Define the model
def create_model(GRU_blocks, regularizer, dropout):
    model = Sequential()
    #model.add(BatchNormalization(input_shape=(120, 5)))
    model.add(GRU(GRU_blocks, input_shape=(120, 5) , return_sequences=False, activation='sigmoid', bias_regularizer=regularizers.l1(regularizer),  kernel_regularizer=regularizers.l1(regularizer)))
   

    model.add(Dropout(dropout))

    #model.add(Dense(50, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.summary()
    return model 


model = create_model(GRU_blocks, regularizer, dropout)
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 20)                1620
#
#  dropout (Dropout)           (None, 20)                0
#
#  dense (Dense)               (None, 1)                 21
#
# =================================================================
# Total params: 1,641
# Trainable params: 1,641
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
optimizer = keras.optimizers.Adam(learning_rate=lr,weight_decay=weight_decay) if optimizer_func == 'Adam' else keras.optimizers.SGD(learning_rate=lr ,weight_decay=weight_decay)

model.compile(loss='binary_crossentropy', optimizer= optimizer, metrics=['binary_accuracy' ])


checkpoint_path = '/content/drive/MyDrive/my_best_model_GRU_15min.hdf5'

checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             monitor='val_binary_accuracy',
                             verbose=1, 
                             save_best_only=True,
                             mode='max')


earlystopping = EarlyStopping(monitor='val_binary_accuracy', patience=10, restore_best_weights=True)

callback = [earlystopping, checkpoint]
# Train the model
history = model.fit(X_train, Y_train, validation_data=(X_val , Y_val) , verbose=1,  batch_size=batchsize, epochs=300,callbacks = callback, class_weight=class_weights)

loss, accuracy = model.evaluate(X_test, Y_test, batch_size=batchsize)

print(f"Loss: {loss:.4f}")
print(f"Accuracy: {accuracy*100:.2f}%")

filepath = "/content/drive/MyDrive/parameter_tuning_GRU_15min.csv"
parameters_to_save = pd.read_csv(filepath)

parameters_to_save = parameters_to_save.append({'GRU_blocks' : GRU_blocks, 'learning_rate': lr, 'regularizer': regularizer, 'droput': dropout, 
                                                'optimizer': optimizer_func, 'batch size': batchsize, 'weight_decay': weight_decay,
                                                'train_loss' : history.history['loss'][-1] ,'val_loss' : history.history['val_loss'][-1] , 
                                                'train_accuracy' : history.history['binary_accuracy'][-1] , 'val_accuracy' : history.history['val_binary_accuracy'][-1],
                                                'test_loss' : f"{loss:.4f}" , 'test_accuracy' : f"{accuracy*100:.2f}%" } , ignore_index = True ) 

parameters_to_save.to_csv(filepath, index=False)
# Out:
# Epoch 1/300
# 226/226 [==============================] - ETA: 0s - loss: 31.2857 - binary_accuracy: 0.5066
# Epoch 1: val_binary_accuracy improved from -inf to 0.51104, saving model to /content/drive/MyDrive/my_best_model_GRU_15min.hdf5
# 226/226 [==============================] - 69s 270ms/step - loss: 31.2857 - binary_accuracy: 0.5066 - val_loss: 30.0378 - val_binary_accuracy: 0.5110
# Epoch 2/300
# 226/226 [==============================] - ETA: 0s - loss: 28.9721 - binary_accuracy: 0.5066
# Epoch 2: val_binary_accuracy did not improve from 0.51104
# 226/226 [==============================] - 61s 270ms/step - loss: 28.9721 - binary_accuracy: 0.5066 - val_loss: 27.7767 - val_binary_accuracy: 0.5110
# Epoch 3/300
# 226/226 [==============================] - ETA: 0s - loss: 26.7575 - binary_accuracy: 0.5055
# Epoch 3: val_binary_accuracy improved from 0.51104 to 0.51111, saving model to /content/drive/MyDrive/my_best_model_GRU_15min.hdf5
# 226/226 [==============================] - 60s 266ms/step - loss: 26.7575 - binary_accuracy: 0.5055 - val_loss: 25.6145 - val_binary_accuracy: 0.5111
# Epoch 4/300
# 226/226 [==============================] - ETA: 0s - loss: 24.6212 - binary_accuracy: 0.5063
# Epoch 4: val_binary_accuracy improved from 0.51111 to 0.51278, saving model to /content/drive/MyDrive/my_best_model_GRU_15min.hdf5
# 226/226 [==============================] - 63s 278ms/step - loss: 24.6212 - binary_accuracy: 0.5063 - val_loss: 23.5078 - val_binary_accuracy: 0.5128
# Epoch 5/300
# 226/226 [==============================] - ETA: 0s - loss: 22.5486 - binary_accuracy: 0.5079
# Epoch 5: val_binary_accuracy improved from 0.51278 to 0.51853, saving model to /content/drive/MyDrive/my_best_model_GRU_15min.hdf5
# 226/226 [==============================] - 61s 268ms/step - loss: 22.5486 - binary_accuracy: 0.5079 - val_loss: 21.4818 - val_binary_accuracy: 0.5185
# Epoch 6/300
# 226/226 [==============================] - ETA: 0s - loss: 20.5760 - binary_accuracy: 0.5090
# Epoch 6: val_binary_accuracy improved from 0.51853 to 0.53091, saving model to /content/drive/MyDrive/my_best_model_GRU_15min.hdf5
# 226/226 [==============================] - 62s 273ms/step - loss: 20.5760 - binary_accuracy: 0.5090 - val_loss: 19.5788 - val_binary_accuracy: 0.5309
# Epoch 7/300
# 226/226 [==============================] - ETA: 0s - loss: 18.7239 - binary_accuracy: 0.5091
# Epoch 7: val_binary_accuracy improved from 0.53091 to 0.55260, saving model to /content/drive/MyDrive/my_best_model_GRU_15min.hdf5
# 226/226 [==============================] - 59s 262ms/step - loss: 18.7239 - binary_accuracy: 0.5091 - val_loss: 17.7714 - val_binary_accuracy: 0.5526
# Epoch 8/300
# 226/226 [==============================] - ETA: 0s - loss: 16.9399 - binary_accuracy: 0.5085
# Epoch 8: val_binary_accuracy improved from 0.55260 to 0.57576, saving model to /content/drive/MyDrive/my_best_model_GRU_15min.hdf5
# 226/226 [==============================] - 59s 262ms/step - loss: 16.9399 - binary_accuracy: 0.5085 - val_loss: 16.0234 - val_binary_accuracy: 0.5758
# Epoch 9/300
# 226/226 [==============================] - ETA: 0s - loss: 15.2415 - binary_accuracy: 0.5096
# Epoch 9: val_binary_accuracy improved from 0.57576 to 0.60316, saving model to /content/drive/MyDrive/my_best_model_GRU_15min.hdf5
# 226/226 [==============================] - 61s 271ms/step - loss: 15.2415 - binary_accuracy: 0.5096 - val_loss: 14.3851 - val_binary_accuracy: 0.6032
# Epoch 10/300
# 226/226 [==============================] - ETA: 0s - loss: 13.6666 - binary_accuracy: 0.5098
# Epoch 10: val_binary_accuracy improved from 0.60316 to 0.63911, saving model to /content/drive/MyDrive/my_best_model_GRU_15min.hdf5
# 226/226 [==============================] - 60s 265ms/step - loss: 13.6666 - binary_accuracy: 0.5098 - val_loss: 12.8825 - val_binary_accuracy: 0.6391
# Epoch 11/300
# 226/226 [==============================] - ETA: 0s - loss: 12.2082 - binary_accuracy: 0.5115
# Epoch 11: val_binary_accuracy improved from 0.63911 to 0.65224, saving model to /content/drive/MyDrive/my_best_model_GRU_15min.hdf5
# 226/226 [==============================] - 60s 266ms/step - loss: 12.2082 - binary_accuracy: 0.5115 - val_loss: 11.4690 - val_binary_accuracy: 0.6522
# Epoch 12/300
# 226/226 [==============================] - ETA: 0s - loss: 10.8497 - binary_accuracy: 0.5101
# Epoch 12: val_binary_accuracy improved from 0.65224 to 0.67036, saving model to /content/drive/MyDrive/my_best_model_GRU_15min.hdf5
# 226/226 [==============================] - 61s 270ms/step - loss: 10.8497 - binary_accuracy: 0.5101 - val_loss: 10.1655 - val_binary_accuracy: 0.6704
# Epoch 13/300
# 226/226 [==============================] - ETA: 0s - loss: 9.5737 - binary_accuracy: 0.5101
# Epoch 13: val_binary_accuracy improved from 0.67036 to 0.67329, saving model to /content/drive/MyDrive/my_best_model_GRU_15min.hdf5
# 226/226 [==============================] - 60s 266ms/step - loss: 9.5737 - binary_accuracy: 0.5101 - val_loss: 8.9238 - val_binary_accuracy: 0.6733
# Epoch 14/300
# 226/226 [==============================] - ETA: 0s - loss: 8.3696 - binary_accuracy: 0.5110
# Epoch 14: val_binary_accuracy improved from 0.67329 to 0.68862, saving model to /content/drive/MyDrive/my_best_model_GRU_15min.hdf5
# 226/226 [==============================] - 62s 276ms/step - loss: 8.3696 - binary_accuracy: 0.5110 - val_loss: 7.7683 - val_binary_accuracy: 0.6886
# Epoch 15/300
# 226/226 [==============================] - ETA: 0s - loss: 7.2439 - binary_accuracy: 0.5115
# Epoch 15: val_binary_accuracy improved from 0.68862 to 0.69787, saving model to /content/drive/MyDrive/my_best_model_GRU_15min.hdf5
# 226/226 [==============================] - 60s 267ms/step - loss: 7.2439 - binary_accuracy: 0.5115 - val_loss: 6.6681 - val_binary_accuracy: 0.6979
# Epoch 16/300
# 226/226 [==============================] - ETA: 0s - loss: 6.1753 - binary_accuracy: 0.5087
# Epoch 16: val_binary_accuracy improved from 0.69787 to 0.71144, saving model to /content/drive/MyDrive/my_best_model_GRU_15min.hdf5
# 226/226 [==============================] - 62s 277ms/step - loss: 6.1753 - binary_accuracy: 0.5087 - val_loss: 5.6412 - val_binary_accuracy: 0.7114
# Epoch 17/300
# 226/226 [==============================] - ETA: 0s - loss: 5.1821 - binary_accuracy: 0.5105
# Epoch 17: val_binary_accuracy did not improve from 0.71144
# 226/226 [==============================] - 60s 266ms/step - loss: 5.1821 - binary_accuracy: 0.5105 - val_loss: 4.6890 - val_binary_accuracy: 0.7112
# Epoch 18/300
# 226/226 [==============================] - ETA: 0s - loss: 4.2815 - binary_accuracy: 0.5086
# Epoch 18: val_binary_accuracy improved from 0.71144 to 0.71398, saving model to /content/drive/MyDrive/my_best_model_GRU_15min.hdf5
# 226/226 [==============================] - 62s 273ms/step - loss: 4.2815 - binary_accuracy: 0.5086 - val_loss: 3.8458 - val_binary_accuracy: 0.7140
# Epoch 19/300
# 226/226 [==============================] - ETA: 0s - loss: 3.4941 - binary_accuracy: 0.5062
# Epoch 19: val_binary_accuracy improved from 0.71398 to 0.71593, saving model to /content/drive/MyDrive/my_best_model_GRU_15min.hdf5
# 226/226 [==============================] - 61s 268ms/step - loss: 3.4941 - binary_accuracy: 0.5062 - val_loss: 3.1206 - val_binary_accuracy: 0.7159
# Epoch 20/300
# 226/226 [==============================] - ETA: 0s - loss: 2.8264 - binary_accuracy: 0.5065
# Epoch 20: val_binary_accuracy did not improve from 0.71593
# 226/226 [==============================] - 60s 266ms/step - loss: 2.8264 - binary_accuracy: 0.5065 - val_loss: 2.5088 - val_binary_accuracy: 0.7142
# Epoch 21/300
# 226/226 [==============================] - ETA: 0s - loss: 2.2728 - binary_accuracy: 0.5040
# Epoch 21: val_binary_accuracy did not improve from 0.71593
# 226/226 [==============================] - 62s 273ms/step - loss: 2.2728 - binary_accuracy: 0.5040 - val_loss: 2.0123 - val_binary_accuracy: 0.6557
# Epoch 22/300
# 226/226 [==============================] - ETA: 0s - loss: 1.8190 - binary_accuracy: 0.5030
# Epoch 22: val_binary_accuracy did not improve from 0.71593
# 226/226 [==============================] - 60s 264ms/step - loss: 1.8190 - binary_accuracy: 0.5030 - val_loss: 1.6104 - val_binary_accuracy: 0.5657
# Epoch 23/300
# 226/226 [==============================] - ETA: 0s - loss: 1.4623 - binary_accuracy: 0.5021
# Epoch 23: val_binary_accuracy did not improve from 0.71593
# 226/226 [==============================] - 62s 274ms/step - loss: 1.4623 - binary_accuracy: 0.5021 - val_loss: 1.2960 - val_binary_accuracy: 0.6988
# Epoch 24/300
# 226/226 [==============================] - ETA: 0s - loss: 1.1735 - binary_accuracy: 0.5006
# Epoch 24: val_binary_accuracy did not improve from 0.71593
# 226/226 [==============================] - 60s 268ms/step - loss: 1.1735 - binary_accuracy: 0.5006 - val_loss: 1.0382 - val_binary_accuracy: 0.5183
# Epoch 25/300
# 226/226 [==============================] - ETA: 0s - loss: 0.9538 - binary_accuracy: 0.4993
# Epoch 25: val_binary_accuracy did not improve from 0.71593
# 226/226 [==============================] - 60s 265ms/step - loss: 0.9538 - binary_accuracy: 0.4993 - val_loss: 0.8528 - val_binary_accuracy: 0.5120
# Epoch 26/300
# 226/226 [==============================] - ETA: 0s - loss: 0.8041 - binary_accuracy: 0.4997
# Epoch 26: val_binary_accuracy did not improve from 0.71593
# 226/226 [==============================] - 62s 271ms/step - loss: 0.8041 - binary_accuracy: 0.4997 - val_loss: 0.7415 - val_binary_accuracy: 0.5111
# Epoch 27/300
# 226/226 [==============================] - ETA: 0s - loss: 0.7178 - binary_accuracy: 0.5006
# Epoch 27: val_binary_accuracy did not improve from 0.71593
# 226/226 [==============================] - 60s 265ms/step - loss: 0.7178 - binary_accuracy: 0.5006 - val_loss: 0.6949 - val_binary_accuracy: 0.5110
# Epoch 28/300
# 226/226 [==============================] - ETA: 0s - loss: 0.7032 - binary_accuracy: 0.5002
# Epoch 28: val_binary_accuracy did not improve from 0.71593
# 226/226 [==============================] - 62s 275ms/step - loss: 0.7032 - binary_accuracy: 0.5002 - val_loss: 0.6949 - val_binary_accuracy: 0.5110
# Epoch 29/300
# 226/226 [==============================] - ETA: 0s - loss: 0.7026 - binary_accuracy: 0.5000
# Epoch 29: val_binary_accuracy did not improve from 0.71593
# 226/226 [==============================] - 60s 265ms/step - loss: 0.7026 - binary_accuracy: 0.5000 - val_loss: 0.6948 - val_binary_accuracy: 0.5110
# 136/136 [==============================] - 4s 28ms/step - loss: 3.1208 - binary_accuracy: 0.6834
# Loss: 3.1208
# Accuracy: 68.34%
# <ipython-input-8-adf38d5b9a41>:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parameters_to_save = parameters_to_save.append({'GRU_blocks' : GRU_blocks, 'learning_rate': lr, 'regularizer': regularizer, 'droput': dropout,

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2,1, figsize = (15,15))
axs = axs.flatten()
axs[0].plot(history.history['binary_accuracy'])
axs[0].plot(history.history['val_binary_accuracy'])
axs[0].set_title('model accuracy')

axs[0].legend(['train', 'val'], loc='upper left')

# summarize history for loss
axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('model loss')

axs[1].legend(['train', 'val'], loc='upper left')
