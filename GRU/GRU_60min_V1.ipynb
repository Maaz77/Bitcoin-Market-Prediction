# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle as pkl
import numpy as np
import pandas as pd 


with open('/content/drive/MyDrive/Dataset_with_memory /60min/X_train_60min.pickle', 'rb') as f:
    X_train = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /60min/Y_train_60min.pickle', 'rb') as f:
    Y_train = pkl.load(f)


with open('/content/drive/MyDrive/Dataset_with_memory /60min/Y_val_60min.pickle', 'rb') as f:
    Y_val = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /60min/X_val_60min.pickle', 'rb') as f:
     X_val = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /60min/Y_test_60min.pickle', 'rb') as f:
    Y_test = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /60min/X_test_60min.pickle', 'rb') as f:
     X_test = pkl.load(f)


Y_train = Y_train.reshape((-1,1))
Y_val = Y_val.reshape((-1,1))
Y_test = Y_test.reshape((-1,1))

X_train.shape , Y_train.shape , X_val.shape , Y_val.shape , X_test.shape , Y_test.shape
# Out:
# ((225480, 120, 5),
#  (225480, 1),
#  (45000, 120, 5),
#  (45000, 1),
#  (135240, 120, 5),
#  (135240, 1))

# %%
from sklearn.utils.class_weight import compute_class_weight



class_weights = compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique ( np.reshape( Y_train , (np.shape(Y_train)[0]))),
                                        y = np.reshape(Y_train ,(np.shape(Y_train)[0]))                                                 
                                    )
class_weights = dict(zip(np.unique(np.reshape(Y_train ,(np.shape(Y_train)[0]))), class_weights))
class_weights
# Out:
# {0: 1.0305961076120045, 1: 0.9711681755924436}

# %%
import os

filepath = "/content/drive/MyDrive/parameter_tuning_GRU_60min.csv"

# check if the file exists, create it if not
if not os.path.isfile(filepath):
    columns_name = ['GRU_blocks', 'learning_rate', 'regularizer', 'droput', 'optimizer', 'batch size' , 'weight_decay',
                    'train_loss' , 'val_loss' , 'train_accuracy' , 'val_accuracy', 'test_loss' , 'test_accuracy']
    df = pd.DataFrame(columns=columns_name)  # create an empty dataframe
    df.to_csv(filepath, index=False)  # save as a CSV file with no index

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, BatchNormalization
from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import load_model
from tensorflow.keras import regularizers
from tensorflow import keras
import numpy as np 

#reproducibility 
np.random.seed(0)
tf.random.set_seed(0)

#defining hyperparameters

weight_decay = 1e-7
GRU_blocks= 20
regularizer = 0.7
lr = 0.00005
dropout  = 0.5
batchsize = 1000
optimizer_func = 'Adam'
#threshold = 0.5

# Define the model
def create_model(GRU_blocks, regularizer, dropout):
    model = Sequential()
    #model.add(BatchNormalization(input_shape=(120, 5)))
    model.add(GRU(GRU_blocks, input_shape=(120, 5) , return_sequences=False, activation='sigmoid', bias_regularizer=regularizers.l1(regularizer),  kernel_regularizer=regularizers.l1(regularizer)))
   

    model.add(Dropout(dropout))

    #model.add(Dense(50, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.summary()
    return model 


model = create_model(GRU_blocks, regularizer, dropout)
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 20)                1620
#
#  dropout (Dropout)           (None, 20)                0
#
#  dense (Dense)               (None, 1)                 21
#
# =================================================================
# Total params: 1,641
# Trainable params: 1,641
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
optimizer = keras.optimizers.Adam(learning_rate=lr,weight_decay=weight_decay) if optimizer_func == 'Adam' else keras.optimizers.SGD(learning_rate=lr ,weight_decay=weight_decay)

model.compile(loss='binary_crossentropy', optimizer= optimizer, metrics=['binary_accuracy' ])


checkpoint_path = '/content/drive/MyDrive/my_best_model_GRU_60min.hdf5'

checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             monitor='val_binary_accuracy',
                             verbose=1, 
                             save_best_only=True,
                             mode='max')


earlystopping = EarlyStopping(monitor='val_binary_accuracy', patience=10, restore_best_weights=True)

callback = [earlystopping, checkpoint]
# Train the model
history = model.fit(X_train, Y_train, validation_data=(X_val , Y_val) , verbose=1,  batch_size=batchsize, epochs=300,callbacks = callback, class_weight=class_weights)

loss, accuracy = model.evaluate(X_test, Y_test, batch_size=batchsize)

print(f"Loss: {loss:.4f}")
print(f"Accuracy: {accuracy*100:.2f}%")

filepath = "/content/drive/MyDrive/parameter_tuning_GRU_60min.csv"
parameters_to_save = pd.read_csv(filepath)

parameters_to_save = parameters_to_save.append({'GRU_blocks' : GRU_blocks, 'learning_rate': lr, 'regularizer': regularizer, 'droput': dropout, 
                                                'optimizer': optimizer_func, 'batch size': batchsize, 'weight_decay': weight_decay,
                                                'train_loss' : history.history['loss'][-1] ,'val_loss' : history.history['val_loss'][-1] , 
                                                'train_accuracy' : history.history['binary_accuracy'][-1] , 'val_accuracy' : history.history['val_binary_accuracy'][-1],
                                                'test_loss' : f"{loss:.4f}" , 'test_accuracy' : f"{accuracy*100:.2f}%" } , ignore_index = True ) 

parameters_to_save.to_csv(filepath, index=False)
# Out:
# Epoch 1/300
# 226/226 [==============================] - ETA: 0s - loss: 33.6269 - binary_accuracy: 0.5082
# Epoch 1: val_binary_accuracy improved from -inf to 0.57596, saving model to /content/drive/MyDrive/my_best_model_GRU_60min.hdf5
# 226/226 [==============================] - 71s 267ms/step - loss: 33.6269 - binary_accuracy: 0.5082 - val_loss: 32.4098 - val_binary_accuracy: 0.5760
# Epoch 2/300
# 226/226 [==============================] - ETA: 0s - loss: 31.3165 - binary_accuracy: 0.5108
# Epoch 2: val_binary_accuracy improved from 0.57596 to 0.62673, saving model to /content/drive/MyDrive/my_best_model_GRU_60min.hdf5
# 226/226 [==============================] - 61s 269ms/step - loss: 31.3165 - binary_accuracy: 0.5108 - val_loss: 30.1507 - val_binary_accuracy: 0.6267
# Epoch 3/300
# 226/226 [==============================] - ETA: 0s - loss: 29.0983 - binary_accuracy: 0.5110
# Epoch 3: val_binary_accuracy improved from 0.62673 to 0.68060, saving model to /content/drive/MyDrive/my_best_model_GRU_60min.hdf5
# 226/226 [==============================] - 59s 262ms/step - loss: 29.0983 - binary_accuracy: 0.5110 - val_loss: 27.9681 - val_binary_accuracy: 0.6806
# Epoch 4/300
# 226/226 [==============================] - ETA: 0s - loss: 26.9421 - binary_accuracy: 0.5136
# Epoch 4: val_binary_accuracy improved from 0.68060 to 0.71016, saving model to /content/drive/MyDrive/my_best_model_GRU_60min.hdf5
# 226/226 [==============================] - 60s 267ms/step - loss: 26.9421 - binary_accuracy: 0.5136 - val_loss: 25.8484 - val_binary_accuracy: 0.7102
# Epoch 5/300
# 226/226 [==============================] - ETA: 0s - loss: 24.8529 - binary_accuracy: 0.5151
# Epoch 5: val_binary_accuracy improved from 0.71016 to 0.72976, saving model to /content/drive/MyDrive/my_best_model_GRU_60min.hdf5
# 226/226 [==============================] - 59s 263ms/step - loss: 24.8529 - binary_accuracy: 0.5151 - val_loss: 23.8009 - val_binary_accuracy: 0.7298
# Epoch 6/300
# 226/226 [==============================] - ETA: 0s - loss: 22.8446 - binary_accuracy: 0.5159
# Epoch 6: val_binary_accuracy improved from 0.72976 to 0.76667, saving model to /content/drive/MyDrive/my_best_model_GRU_60min.hdf5
# 226/226 [==============================] - 59s 261ms/step - loss: 22.8446 - binary_accuracy: 0.5159 - val_loss: 21.8386 - val_binary_accuracy: 0.7667
# Epoch 7/300
# 226/226 [==============================] - ETA: 0s - loss: 20.9151 - binary_accuracy: 0.5182
# Epoch 7: val_binary_accuracy improved from 0.76667 to 0.77073, saving model to /content/drive/MyDrive/my_best_model_GRU_60min.hdf5
# 226/226 [==============================] - 60s 266ms/step - loss: 20.9151 - binary_accuracy: 0.5182 - val_loss: 19.9389 - val_binary_accuracy: 0.7707
# Epoch 8/300
# 226/226 [==============================] - ETA: 0s - loss: 19.0358 - binary_accuracy: 0.5183
# Epoch 8: val_binary_accuracy improved from 0.77073 to 0.78480, saving model to /content/drive/MyDrive/my_best_model_GRU_60min.hdf5
# 226/226 [==============================] - 59s 261ms/step - loss: 19.0358 - binary_accuracy: 0.5183 - val_loss: 18.0921 - val_binary_accuracy: 0.7848
# Epoch 9/300
# 226/226 [==============================] - ETA: 0s - loss: 17.2269 - binary_accuracy: 0.5202
# Epoch 9: val_binary_accuracy did not improve from 0.78480
# 226/226 [==============================] - 58s 259ms/step - loss: 17.2269 - binary_accuracy: 0.5202 - val_loss: 16.3274 - val_binary_accuracy: 0.7839
# Epoch 10/300
# 226/226 [==============================] - ETA: 0s - loss: 15.4985 - binary_accuracy: 0.5177
# Epoch 10: val_binary_accuracy did not improve from 0.78480
# 226/226 [==============================] - 58s 257ms/step - loss: 15.4985 - binary_accuracy: 0.5177 - val_loss: 14.6312 - val_binary_accuracy: 0.7748
# Epoch 11/300
# 226/226 [==============================] - ETA: 0s - loss: 13.8453 - binary_accuracy: 0.5175
# Epoch 11: val_binary_accuracy improved from 0.78480 to 0.78744, saving model to /content/drive/MyDrive/my_best_model_GRU_60min.hdf5
# 226/226 [==============================] - 60s 265ms/step - loss: 13.8453 - binary_accuracy: 0.5175 - val_loss: 13.0300 - val_binary_accuracy: 0.7874
# Epoch 12/300
# 226/226 [==============================] - ETA: 0s - loss: 12.2834 - binary_accuracy: 0.5187
# Epoch 12: val_binary_accuracy did not improve from 0.78744
# 226/226 [==============================] - 58s 257ms/step - loss: 12.2834 - binary_accuracy: 0.5187 - val_loss: 11.5174 - val_binary_accuracy: 0.7563
# Epoch 13/300
# 226/226 [==============================] - ETA: 0s - loss: 10.8220 - binary_accuracy: 0.5177
# Epoch 13: val_binary_accuracy did not improve from 0.78744
# 226/226 [==============================] - 58s 257ms/step - loss: 10.8220 - binary_accuracy: 0.5177 - val_loss: 10.1064 - val_binary_accuracy: 0.7614
# Epoch 14/300
# 226/226 [==============================] - ETA: 0s - loss: 9.4494 - binary_accuracy: 0.5198
# Epoch 14: val_binary_accuracy improved from 0.78744 to 0.78789, saving model to /content/drive/MyDrive/my_best_model_GRU_60min.hdf5
# 226/226 [==============================] - 61s 269ms/step - loss: 9.4494 - binary_accuracy: 0.5198 - val_loss: 8.7757 - val_binary_accuracy: 0.7879
# Epoch 15/300
# 226/226 [==============================] - ETA: 0s - loss: 8.1677 - binary_accuracy: 0.5193
# Epoch 15: val_binary_accuracy did not improve from 0.78789
# 226/226 [==============================] - 58s 259ms/step - loss: 8.1677 - binary_accuracy: 0.5193 - val_loss: 7.5406 - val_binary_accuracy: 0.7452
# Epoch 16/300
# 226/226 [==============================] - ETA: 0s - loss: 6.9702 - binary_accuracy: 0.5152
# Epoch 16: val_binary_accuracy did not improve from 0.78789
# 226/226 [==============================] - 59s 259ms/step - loss: 6.9702 - binary_accuracy: 0.5152 - val_loss: 6.3865 - val_binary_accuracy: 0.7690
# Epoch 17/300
# 226/226 [==============================] - ETA: 0s - loss: 5.8695 - binary_accuracy: 0.5144
# Epoch 17: val_binary_accuracy did not improve from 0.78789
# 226/226 [==============================] - 61s 269ms/step - loss: 5.8695 - binary_accuracy: 0.5144 - val_loss: 5.3457 - val_binary_accuracy: 0.7050
# Epoch 18/300
# 226/226 [==============================] - ETA: 0s - loss: 4.8873 - binary_accuracy: 0.5137
# Epoch 18: val_binary_accuracy did not improve from 0.78789
# 226/226 [==============================] - 59s 263ms/step - loss: 4.8873 - binary_accuracy: 0.5137 - val_loss: 4.4196 - val_binary_accuracy: 0.7237
# Epoch 19/300
# 226/226 [==============================] - ETA: 0s - loss: 4.0023 - binary_accuracy: 0.5121
# Epoch 19: val_binary_accuracy did not improve from 0.78789
# 226/226 [==============================] - 60s 267ms/step - loss: 4.0023 - binary_accuracy: 0.5121 - val_loss: 3.5747 - val_binary_accuracy: 0.7000
# Epoch 20/300
# 226/226 [==============================] - ETA: 0s - loss: 3.2051 - binary_accuracy: 0.5091
# Epoch 20: val_binary_accuracy did not improve from 0.78789
# 226/226 [==============================] - 59s 261ms/step - loss: 3.2051 - binary_accuracy: 0.5091 - val_loss: 2.8381 - val_binary_accuracy: 0.6541
# Epoch 21/300
# 226/226 [==============================] - ETA: 0s - loss: 2.5330 - binary_accuracy: 0.5082
# Epoch 21: val_binary_accuracy did not improve from 0.78789
# 226/226 [==============================] - 59s 261ms/step - loss: 2.5330 - binary_accuracy: 0.5082 - val_loss: 2.2307 - val_binary_accuracy: 0.6141
# Epoch 22/300
# 226/226 [==============================] - ETA: 0s - loss: 1.9814 - binary_accuracy: 0.5074
# Epoch 22: val_binary_accuracy did not improve from 0.78789
# 226/226 [==============================] - 60s 264ms/step - loss: 1.9814 - binary_accuracy: 0.5074 - val_loss: 1.7280 - val_binary_accuracy: 0.5566
# Epoch 23/300
# 226/226 [==============================] - ETA: 0s - loss: 1.5183 - binary_accuracy: 0.5027
# Epoch 23: val_binary_accuracy did not improve from 0.78789
# 226/226 [==============================] - 60s 262ms/step - loss: 1.5183 - binary_accuracy: 0.5027 - val_loss: 1.3111 - val_binary_accuracy: 0.5477
# Epoch 24/300
# 226/226 [==============================] - ETA: 0s - loss: 1.1571 - binary_accuracy: 0.5023
# Epoch 24: val_binary_accuracy did not improve from 0.78789
# 226/226 [==============================] - 58s 258ms/step - loss: 1.1571 - binary_accuracy: 0.5023 - val_loss: 1.0089 - val_binary_accuracy: 0.5039
# 136/136 [==============================] - 3s 23ms/step - loss: 8.7764 - binary_accuracy: 0.7586
# Loss: 8.7764
# Accuracy: 75.86%
# <ipython-input-7-38c4d237e14e>:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parameters_to_save = parameters_to_save.append({'GRU_blocks' : GRU_blocks, 'learning_rate': lr, 'regularizer': regularizer, 'droput': dropout,

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2,1, figsize = (15,15))
axs = axs.flatten()
axs[0].plot(history.history['binary_accuracy'])
axs[0].plot(history.history['val_binary_accuracy'])
axs[0].set_title('model accuracy')

axs[0].legend(['train', 'val'], loc='upper left')

# summarize history for loss
axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('model loss')

axs[1].legend(['train', 'val'], loc='upper left')
