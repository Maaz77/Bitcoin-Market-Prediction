# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle as pkl
import numpy as np
import pandas as pd 


with open('/content/drive/MyDrive/Dataset_with_memory /1min/X_train.pickle', 'rb') as f:
    X_train = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /1min/Y_train.pickle', 'rb') as f:
    Y_train = pkl.load(f)


with open('/content/drive/MyDrive/Dataset_with_memory /1min/Y_val.pickle', 'rb') as f:
    Y_val = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /1min/X_val.pickle', 'rb') as f:
     X_val = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /1min/Y_test.pickle', 'rb') as f:
    Y_test = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /1min/X_test.pickle', 'rb') as f:
     X_test = pkl.load(f)


Y_train = Y_train.reshape((-1,1))
Y_val = Y_val.reshape((-1,1))
Y_test = Y_test.reshape((-1,1))

X_train.shape , Y_train.shape , X_val.shape , Y_val.shape , X_test.shape , Y_test.shape
# Out:
# ((225480, 120, 5),
#  (225480, 1),
#  (45000, 120, 5),
#  (45000, 1),
#  (135240, 120, 5),
#  (135240, 1))

# %%
from sklearn.utils.class_weight import compute_class_weight



class_weights = compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique ( np.reshape( Y_train , (np.shape(Y_train)[0]))),
                                        y = np.reshape(Y_train ,(np.shape(Y_train)[0]))                                                 
                                    )
class_weights = dict(zip(np.unique(np.reshape(Y_train ,(np.shape(Y_train)[0]))), class_weights))
class_weights
# Out:
# {0: 1.173189589685422, 1: 0.8713664082607452}

# %%
import os

filepath = "/content/drive/MyDrive/parameter_tuning_GRU.csv"

# check if the file exists, create it if not
if not os.path.isfile(filepath):
    columns_name = ['GRU_blocks', 'learning_rate', 'regularizer', 'droput', 'optimizer', 'batch size' , 'weight_decay',
                    'train_loss' , 'val_loss' , 'train_accuracy' , 'val_accuracy', 'test_loss' , 'test_accuracy']
    df = pd.DataFrame(columns=columns_name)  # create an empty dataframe
    df.to_csv(filepath, index=False)  # save as a CSV file with no index

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, BatchNormalization
from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import load_model
from tensorflow.keras import regularizers
from tensorflow import keras
import numpy as np 

#reproducibility 
np.random.seed(0)
tf.random.set_seed(0)

#defining hyperparameters

weight_decay = 1e-7
GRU_blocks= 20
regularizer = 0
lr = 0.001
dropout  = 0.5
batchsize = 128
optimizer_func = 'Adam'
#threshold = 0.5

# Define the model
def create_model(GRU_blocks, regularizer, dropout):
    model = Sequential()
    #model.add(BatchNormalization(input_shape=(120, 5)))
    model.add(GRU(GRU_blocks, input_shape=(120, 5) , return_sequences=False, activation='tanh', bias_regularizer=regularizers.l1(regularizer),  kernel_regularizer=regularizers.l1(regularizer)))
   

    model.add(Dropout(dropout))

    model.add(Dense(50, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.summary()
    return model 


model = create_model(GRU_blocks, regularizer, dropout)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 20)                1620
#
#  dropout (Dropout)           (None, 20)                0
#
#  dense (Dense)               (None, 50)                1050
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 2,721
# Trainable params: 2,721
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
optimizer = keras.optimizers.Adam(learning_rate=lr,weight_decay=weight_decay) if optimizer_func == 'Adam' else keras.optimizers.SGD(learning_rate=lr ,weight_decay=weight_decay)

model.compile(loss='binary_crossentropy', optimizer= optimizer, metrics=['binary_accuracy' ])


checkpoint_path = '/content/drive/MyDrive/my_best_model_GRU.hdf5'

checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             monitor='val_binary_accuracy',
                             verbose=1, 
                             save_best_only=True,
                             mode='max')


earlystopping = EarlyStopping(monitor='val_binary_accuracy', patience=10, restore_best_weights=True)

callback = [earlystopping, checkpoint]
# Train the model
history = model.fit(X_train, Y_train, validation_data=(X_val , Y_val) , verbose=1,  batch_size=batchsize, epochs=150,callbacks = callback, class_weight=class_weights)

loss, accuracy = model.evaluate(X_test, Y_test, batch_size=batchsize)

print(f"Loss: {loss:.4f}")
print(f"Accuracy: {accuracy*100:.2f}%")

filepath = "/content/drive/MyDrive/parameter_tuning_GRU.csv"
parameters_to_save = pd.read_csv(filepath)

parameters_to_save = parameters_to_save.append({'GRU_blocks' : GRU_blocks, 'learning_rate': lr, 'regularizer': regularizer, 'droput': dropout, 
                                                'optimizer': optimizer_func, 'batch size': batchsize, 'weight_decay': weight_decay,
                                                'train_loss' : history.history['loss'][-1] ,'val_loss' : history.history['val_loss'][-1] , 
                                                'train_accuracy' : history.history['binary_accuracy'][-1] , 'val_accuracy' : history.history['val_binary_accuracy'][-1],
                                                'test_loss' : f"{loss:.4f}" , 'test_accuracy' : f"{accuracy*100:.2f}%" } , ignore_index = True ) 

parameters_to_save.to_csv(filepath, index=False)
# Out:
# Epoch 1/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.6923 - binary_accuracy: 0.5322
# Epoch 1: val_binary_accuracy improved from -inf to 0.49509, saving model to /content/drive/MyDrive/my_best_model_GRU.hdf5
# 1762/1762 [==============================] - 27s 10ms/step - loss: 0.6923 - binary_accuracy: 0.5324 - val_loss: 0.6956 - val_binary_accuracy: 0.4951
# Epoch 2/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.6906 - binary_accuracy: 0.5476
# Epoch 2: val_binary_accuracy did not improve from 0.49509
# 1762/1762 [==============================] - 18s 10ms/step - loss: 0.6906 - binary_accuracy: 0.5476 - val_loss: 0.6965 - val_binary_accuracy: 0.4918
# Epoch 3/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.6898 - binary_accuracy: 0.5508
# Epoch 3: val_binary_accuracy improved from 0.49509 to 0.50629, saving model to /content/drive/MyDrive/my_best_model_GRU.hdf5
# 1762/1762 [==============================] - 18s 10ms/step - loss: 0.6898 - binary_accuracy: 0.5507 - val_loss: 0.6957 - val_binary_accuracy: 0.5063
# Epoch 4/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.6886 - binary_accuracy: 0.5538
# Epoch 4: val_binary_accuracy improved from 0.50629 to 0.51876, saving model to /content/drive/MyDrive/my_best_model_GRU.hdf5
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.6886 - binary_accuracy: 0.5539 - val_loss: 0.6932 - val_binary_accuracy: 0.5188
# Epoch 5/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.6882 - binary_accuracy: 0.5542
# Epoch 5: val_binary_accuracy did not improve from 0.51876
# 1762/1762 [==============================] - 18s 10ms/step - loss: 0.6882 - binary_accuracy: 0.5543 - val_loss: 0.6939 - val_binary_accuracy: 0.5184
# Epoch 6/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.6877 - binary_accuracy: 0.5576
# Epoch 6: val_binary_accuracy improved from 0.51876 to 0.52158, saving model to /content/drive/MyDrive/my_best_model_GRU.hdf5
# 1762/1762 [==============================] - 18s 10ms/step - loss: 0.6877 - binary_accuracy: 0.5576 - val_loss: 0.6924 - val_binary_accuracy: 0.5216
# Epoch 7/150
# 1756/1762 [============================>.] - ETA: 0s - loss: 0.6874 - binary_accuracy: 0.5584
# Epoch 7: val_binary_accuracy improved from 0.52158 to 0.53093, saving model to /content/drive/MyDrive/my_best_model_GRU.hdf5
# 1762/1762 [==============================] - 18s 10ms/step - loss: 0.6873 - binary_accuracy: 0.5584 - val_loss: 0.6912 - val_binary_accuracy: 0.5309
# Epoch 8/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.6871 - binary_accuracy: 0.5566
# Epoch 8: val_binary_accuracy did not improve from 0.53093
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.6871 - binary_accuracy: 0.5565 - val_loss: 0.6924 - val_binary_accuracy: 0.5261
# Epoch 9/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.6869 - binary_accuracy: 0.5579
# Epoch 9: val_binary_accuracy did not improve from 0.53093
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.6869 - binary_accuracy: 0.5579 - val_loss: 0.6912 - val_binary_accuracy: 0.5297
# Epoch 10/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.6866 - binary_accuracy: 0.5592
# Epoch 10: val_binary_accuracy did not improve from 0.53093
# 1762/1762 [==============================] - 20s 11ms/step - loss: 0.6866 - binary_accuracy: 0.5591 - val_loss: 0.6919 - val_binary_accuracy: 0.5286
# Epoch 11/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.6864 - binary_accuracy: 0.5589
# Epoch 11: val_binary_accuracy did not improve from 0.53093
# 1762/1762 [==============================] - 18s 10ms/step - loss: 0.6864 - binary_accuracy: 0.5589 - val_loss: 0.6912 - val_binary_accuracy: 0.5297
# Epoch 12/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.6863 - binary_accuracy: 0.5590
# Epoch 12: val_binary_accuracy improved from 0.53093 to 0.53173, saving model to /content/drive/MyDrive/my_best_model_GRU.hdf5
# 1762/1762 [==============================] - 19s 11ms/step - loss: 0.6863 - binary_accuracy: 0.5590 - val_loss: 0.6921 - val_binary_accuracy: 0.5317
# Epoch 13/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.6863 - binary_accuracy: 0.5586
# Epoch 13: val_binary_accuracy did not improve from 0.53173
# 1762/1762 [==============================] - 20s 11ms/step - loss: 0.6863 - binary_accuracy: 0.5586 - val_loss: 0.6930 - val_binary_accuracy: 0.5247
# Epoch 14/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.6860 - binary_accuracy: 0.5599
# Epoch 14: val_binary_accuracy did not improve from 0.53173
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.6860 - binary_accuracy: 0.5600 - val_loss: 0.6914 - val_binary_accuracy: 0.5275
# Epoch 15/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.6861 - binary_accuracy: 0.5585
# Epoch 15: val_binary_accuracy did not improve from 0.53173
# 1762/1762 [==============================] - 18s 10ms/step - loss: 0.6861 - binary_accuracy: 0.5585 - val_loss: 0.6913 - val_binary_accuracy: 0.5301
# Epoch 16/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.6859 - binary_accuracy: 0.5594
# Epoch 16: val_binary_accuracy did not improve from 0.53173
# 1762/1762 [==============================] - 19s 11ms/step - loss: 0.6859 - binary_accuracy: 0.5594 - val_loss: 0.6912 - val_binary_accuracy: 0.5283
# Epoch 17/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.6857 - binary_accuracy: 0.5602
# Epoch 17: val_binary_accuracy did not improve from 0.53173
# 1762/1762 [==============================] - 18s 10ms/step - loss: 0.6857 - binary_accuracy: 0.5602 - val_loss: 0.6922 - val_binary_accuracy: 0.5276
# Epoch 18/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.6858 - binary_accuracy: 0.5605
# Epoch 18: val_binary_accuracy did not improve from 0.53173
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.6857 - binary_accuracy: 0.5606 - val_loss: 0.6921 - val_binary_accuracy: 0.5280
# Epoch 19/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.6856 - binary_accuracy: 0.5590
# Epoch 19: val_binary_accuracy did not improve from 0.53173
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.6856 - binary_accuracy: 0.5590 - val_loss: 0.6914 - val_binary_accuracy: 0.5300
# Epoch 20/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.6856 - binary_accuracy: 0.5604
# Epoch 20: val_binary_accuracy did not improve from 0.53173
# 1762/1762 [==============================] - 19s 11ms/step - loss: 0.6856 - binary_accuracy: 0.5605 - val_loss: 0.6920 - val_binary_accuracy: 0.5284
# Epoch 21/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.6854 - binary_accuracy: 0.5608
# Epoch 21: val_binary_accuracy did not improve from 0.53173
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.6854 - binary_accuracy: 0.5608 - val_loss: 0.6916 - val_binary_accuracy: 0.5306
# Epoch 22/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.6855 - binary_accuracy: 0.5600
# Epoch 22: val_binary_accuracy did not improve from 0.53173
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.6855 - binary_accuracy: 0.5600 - val_loss: 0.6905 - val_binary_accuracy: 0.5313
# 1057/1057 [==============================] - 5s 5ms/step - loss: 0.6943 - binary_accuracy: 0.5242
# Loss: 0.6943
# Accuracy: 52.42%
# <ipython-input-6-846602215e84>:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parameters_to_save = parameters_to_save.append({'GRU_blocks' : GRU_blocks, 'learning_rate': lr, 'regularizer': regularizer, 'droput': dropout,

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2,1, figsize = (15,15))
axs = axs.flatten()
axs[0].plot(history.history['binary_accuracy'])
axs[0].plot(history.history['val_binary_accuracy'])
axs[0].set_title('model accuracy')

axs[0].legend(['train', 'val'], loc='upper left')

# summarize history for loss
axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('model loss')

axs[1].legend(['train', 'val'], loc='upper left')
