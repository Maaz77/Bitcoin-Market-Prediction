# %%
import pickle as pkl
import numpy as np
import pandas as pd 


with open('/content/drive/MyDrive/Dataset_with_memory /5min/X_train_5min.pickle', 'rb') as f:
    X_train = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /5min/Y_train_5min.pickle', 'rb') as f:
    Y_train = pkl.load(f)


with open('/content/drive/MyDrive/Dataset_with_memory /5min/Y_val_5min.pickle', 'rb') as f:
    Y_val = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /5min/X_val_5min.pickle', 'rb') as f:
     X_val = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /5min/Y_test_5min.pickle', 'rb') as f:
    Y_test = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /5min/X_test_5min.pickle', 'rb') as f:
     X_test = pkl.load(f)


Y_train = Y_train.reshape((-1,1))
Y_val = Y_val.reshape((-1,1))
Y_test = Y_test.reshape((-1,1))

X_train.shape , Y_train.shape , X_val.shape , Y_val.shape , X_test.shape , Y_test.shape
# Out:
# ((225480, 120, 5),
#  (225480, 1),
#  (45000, 120, 5),
#  (45000, 1),
#  (135240, 120, 5),
#  (135240, 1))

# %%
from sklearn.utils.class_weight import compute_class_weight



class_weights = compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique ( np.reshape( Y_train , (np.shape(Y_train)[0]))),
                                        y = np.reshape(Y_train ,(np.shape(Y_train)[0]))                                                 
                                    )
class_weights = dict(zip(np.unique(np.reshape(Y_train ,(np.shape(Y_train)[0]))), class_weights))
class_weights
# Out:
# {0: 1.0362703825578616, 1: 0.9661827468590919}

# %%
import os

filepath = "/content/drive/MyDrive/parameter_tuning_GRU_5min.csv"

# check if the file exists, create it if not
if not os.path.isfile(filepath):
    columns_name = ['GRU_blocks', 'learning_rate', 'regularizer', 'droput', 'optimizer', 'batch size' , 'weight_decay',
                    'train_loss' , 'val_loss' , 'train_accuracy' , 'val_accuracy', 'test_loss' , 'test_accuracy']
    df = pd.DataFrame(columns=columns_name)  # create an empty dataframe
    df.to_csv(filepath, index=False)  # save as a CSV file with no index

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, BatchNormalization
from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import load_model
from tensorflow.keras import regularizers
from tensorflow import keras
import numpy as np 

#reproducibility 
np.random.seed(0)
tf.random.set_seed(0)

#defining hyperparameters

weight_decay = 1e-7
GRU_blocks= 20
regularizer = 0.7
lr = 0.00005
dropout  = 0.5
batchsize = 1000
optimizer_func = 'Adam'
#threshold = 0.5

# Define the model
def create_model(GRU_blocks, regularizer, dropout):
    model = Sequential()
    #model.add(BatchNormalization(input_shape=(120, 5)))
    model.add(GRU(GRU_blocks, input_shape=(120, 5) , return_sequences=False, activation='sigmoid', bias_regularizer=regularizers.l1(regularizer),  kernel_regularizer=regularizers.l1(regularizer)))
   

    model.add(Dropout(dropout))

    #model.add(Dense(50, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.summary()
    return model 


model = create_model(GRU_blocks, regularizer, dropout)
# Out:
# WARNING:tensorflow:Layer gru will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 20)                1620
#
#  dropout (Dropout)           (None, 20)                0
#
#  dense (Dense)               (None, 1)                 21
#
# =================================================================
# Total params: 1,641
# Trainable params: 1,641
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
optimizer = keras.optimizers.Adam(learning_rate=lr,weight_decay=weight_decay) if optimizer_func == 'Adam' else keras.optimizers.SGD(learning_rate=lr ,weight_decay=weight_decay)

model.compile(loss='binary_crossentropy', optimizer= optimizer, metrics=['binary_accuracy' ])


checkpoint_path = '/content/drive/MyDrive/my_best_model_GRU_5min.hdf5'

checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             monitor='val_binary_accuracy',
                             verbose=1, 
                             save_best_only=True,
                             mode='max')


earlystopping = EarlyStopping(monitor='val_binary_accuracy', patience=10, restore_best_weights=True)

callback = [earlystopping, checkpoint]
# Train the model
history = model.fit(X_train, Y_train, validation_data=(X_val , Y_val) , verbose=1,  batch_size=batchsize, epochs=300,callbacks = callback, class_weight=class_weights)

loss, accuracy = model.evaluate(X_test, Y_test, batch_size=batchsize)

print(f"Loss: {loss:.4f}")
print(f"Accuracy: {accuracy*100:.2f}%")

filepath = "/content/drive/MyDrive/parameter_tuning_GRU_5min.csv"
parameters_to_save = pd.read_csv(filepath)

parameters_to_save = parameters_to_save.append({'GRU_blocks' : GRU_blocks, 'learning_rate': lr, 'regularizer': regularizer, 'droput': dropout, 
                                                'optimizer': optimizer_func, 'batch size': batchsize, 'weight_decay': weight_decay,
                                                'train_loss' : history.history['loss'][-1] ,'val_loss' : history.history['val_loss'][-1] , 
                                                'train_accuracy' : history.history['binary_accuracy'][-1] , 'val_accuracy' : history.history['val_binary_accuracy'][-1],
                                                'test_loss' : f"{loss:.4f}" , 'test_accuracy' : f"{accuracy*100:.2f}%" } , ignore_index = True ) 

parameters_to_save.to_csv(filepath, index=False)
# Out:
# Epoch 1/300
# 226/226 [==============================] - ETA: 0s - loss: 32.3815 - binary_accuracy: 0.5169
# Epoch 1: val_binary_accuracy improved from -inf to 0.51051, saving model to /content/drive/MyDrive/my_best_model_GRU_5min.hdf5
# 226/226 [==============================] - 73s 290ms/step - loss: 32.3815 - binary_accuracy: 0.5169 - val_loss: 31.1618 - val_binary_accuracy: 0.5105
# Epoch 2/300
# 226/226 [==============================] - ETA: 0s - loss: 30.0690 - binary_accuracy: 0.5173
# Epoch 2: val_binary_accuracy did not improve from 0.51051
# 226/226 [==============================] - 60s 266ms/step - loss: 30.0690 - binary_accuracy: 0.5173 - val_loss: 28.8855 - val_binary_accuracy: 0.5105
# Epoch 3/300
# 226/226 [==============================] - ETA: 0s - loss: 27.8464 - binary_accuracy: 0.5180
# Epoch 3: val_binary_accuracy did not improve from 0.51051
# 226/226 [==============================] - 59s 262ms/step - loss: 27.8464 - binary_accuracy: 0.5180 - val_loss: 26.7192 - val_binary_accuracy: 0.5105
# Epoch 4/300
# 226/226 [==============================] - ETA: 0s - loss: 25.7272 - binary_accuracy: 0.5182
# Epoch 4: val_binary_accuracy did not improve from 0.51051
# 226/226 [==============================] - 63s 278ms/step - loss: 25.7272 - binary_accuracy: 0.5182 - val_loss: 24.6441 - val_binary_accuracy: 0.5105
# Epoch 5/300
# 226/226 [==============================] - ETA: 0s - loss: 23.6857 - binary_accuracy: 0.5171
# Epoch 5: val_binary_accuracy did not improve from 0.51051
# 226/226 [==============================] - 59s 261ms/step - loss: 23.6857 - binary_accuracy: 0.5171 - val_loss: 22.6333 - val_binary_accuracy: 0.5105
# Epoch 6/300
# 226/226 [==============================] - ETA: 0s - loss: 21.7181 - binary_accuracy: 0.5190
# Epoch 6: val_binary_accuracy improved from 0.51051 to 0.51053, saving model to /content/drive/MyDrive/my_best_model_GRU_5min.hdf5
# 226/226 [==============================] - 61s 270ms/step - loss: 21.7181 - binary_accuracy: 0.5190 - val_loss: 20.7294 - val_binary_accuracy: 0.5105
# Epoch 7/300
# 226/226 [==============================] - ETA: 0s - loss: 19.8659 - binary_accuracy: 0.5159
# Epoch 7: val_binary_accuracy improved from 0.51053 to 0.51098, saving model to /content/drive/MyDrive/my_best_model_GRU_5min.hdf5
# 226/226 [==============================] - 61s 268ms/step - loss: 19.8659 - binary_accuracy: 0.5159 - val_loss: 18.9239 - val_binary_accuracy: 0.5110
# Epoch 8/300
# 226/226 [==============================] - ETA: 0s - loss: 18.1237 - binary_accuracy: 0.5170
# Epoch 8: val_binary_accuracy improved from 0.51098 to 0.51173, saving model to /content/drive/MyDrive/my_best_model_GRU_5min.hdf5
# 226/226 [==============================] - 59s 262ms/step - loss: 18.1237 - binary_accuracy: 0.5170 - val_loss: 17.2467 - val_binary_accuracy: 0.5117
# Epoch 9/300
# 226/226 [==============================] - ETA: 0s - loss: 16.4985 - binary_accuracy: 0.5161
# Epoch 9: val_binary_accuracy improved from 0.51173 to 0.51427, saving model to /content/drive/MyDrive/my_best_model_GRU_5min.hdf5
# 226/226 [==============================] - 60s 266ms/step - loss: 16.4985 - binary_accuracy: 0.5161 - val_loss: 15.6784 - val_binary_accuracy: 0.5143
# Epoch 10/300
# 226/226 [==============================] - ETA: 0s - loss: 14.9758 - binary_accuracy: 0.5126
# Epoch 10: val_binary_accuracy improved from 0.51427 to 0.51627, saving model to /content/drive/MyDrive/my_best_model_GRU_5min.hdf5
# 226/226 [==============================] - 61s 270ms/step - loss: 14.9758 - binary_accuracy: 0.5126 - val_loss: 14.1976 - val_binary_accuracy: 0.5163
# Epoch 11/300
# 226/226 [==============================] - ETA: 0s - loss: 13.5204 - binary_accuracy: 0.5116
# Epoch 11: val_binary_accuracy improved from 0.51627 to 0.51873, saving model to /content/drive/MyDrive/my_best_model_GRU_5min.hdf5
# 226/226 [==============================] - 61s 272ms/step - loss: 13.5204 - binary_accuracy: 0.5116 - val_loss: 12.7675 - val_binary_accuracy: 0.5187
# Epoch 12/300
# 226/226 [==============================] - ETA: 0s - loss: 12.1190 - binary_accuracy: 0.5121
# Epoch 12: val_binary_accuracy improved from 0.51873 to 0.52238, saving model to /content/drive/MyDrive/my_best_model_GRU_5min.hdf5
# 226/226 [==============================] - 59s 260ms/step - loss: 12.1190 - binary_accuracy: 0.5121 - val_loss: 11.4048 - val_binary_accuracy: 0.5224
# Epoch 13/300
# 226/226 [==============================] - ETA: 0s - loss: 10.7835 - binary_accuracy: 0.5111
# Epoch 13: val_binary_accuracy improved from 0.52238 to 0.52502, saving model to /content/drive/MyDrive/my_best_model_GRU_5min.hdf5
# 226/226 [==============================] - 60s 266ms/step - loss: 10.7835 - binary_accuracy: 0.5111 - val_loss: 10.1025 - val_binary_accuracy: 0.5250
# Epoch 14/300
# 226/226 [==============================] - ETA: 0s - loss: 9.5122 - binary_accuracy: 0.5075
# Epoch 14: val_binary_accuracy improved from 0.52502 to 0.52731, saving model to /content/drive/MyDrive/my_best_model_GRU_5min.hdf5
# 226/226 [==============================] - 60s 266ms/step - loss: 9.5122 - binary_accuracy: 0.5075 - val_loss: 8.8554 - val_binary_accuracy: 0.5273
# Epoch 15/300
# 226/226 [==============================] - ETA: 0s - loss: 8.2903 - binary_accuracy: 0.5112
# Epoch 15: val_binary_accuracy improved from 0.52731 to 0.52887, saving model to /content/drive/MyDrive/my_best_model_GRU_5min.hdf5
# 226/226 [==============================] - 58s 257ms/step - loss: 8.2903 - binary_accuracy: 0.5112 - val_loss: 7.6771 - val_binary_accuracy: 0.5289
# Epoch 16/300
# 226/226 [==============================] - ETA: 0s - loss: 7.1582 - binary_accuracy: 0.5088
# Epoch 16: val_binary_accuracy improved from 0.52887 to 0.53187, saving model to /content/drive/MyDrive/my_best_model_GRU_5min.hdf5
# 226/226 [==============================] - 60s 266ms/step - loss: 7.1582 - binary_accuracy: 0.5088 - val_loss: 6.5952 - val_binary_accuracy: 0.5319
# Epoch 17/300
# 226/226 [==============================] - ETA: 0s - loss: 6.1179 - binary_accuracy: 0.5096
# Epoch 17: val_binary_accuracy improved from 0.53187 to 0.53209, saving model to /content/drive/MyDrive/my_best_model_GRU_5min.hdf5
# 226/226 [==============================] - 61s 269ms/step - loss: 6.1179 - binary_accuracy: 0.5096 - val_loss: 5.6029 - val_binary_accuracy: 0.5321
# Epoch 18/300
# 226/226 [==============================] - ETA: 0s - loss: 5.1814 - binary_accuracy: 0.5065
# Epoch 18: val_binary_accuracy improved from 0.53209 to 0.53222, saving model to /content/drive/MyDrive/my_best_model_GRU_5min.hdf5
# 226/226 [==============================] - 58s 258ms/step - loss: 5.1814 - binary_accuracy: 0.5065 - val_loss: 4.7239 - val_binary_accuracy: 0.5322
# Epoch 19/300
# 226/226 [==============================] - ETA: 0s - loss: 4.3386 - binary_accuracy: 0.5065
# Epoch 19: val_binary_accuracy improved from 0.53222 to 0.53462, saving model to /content/drive/MyDrive/my_best_model_GRU_5min.hdf5
# 226/226 [==============================] - 62s 273ms/step - loss: 4.3386 - binary_accuracy: 0.5065 - val_loss: 3.9174 - val_binary_accuracy: 0.5346
# Epoch 20/300
# 226/226 [==============================] - ETA: 0s - loss: 3.5702 - binary_accuracy: 0.5044
# Epoch 20: val_binary_accuracy improved from 0.53462 to 0.53478, saving model to /content/drive/MyDrive/my_best_model_GRU_5min.hdf5
# 226/226 [==============================] - 58s 258ms/step - loss: 3.5702 - binary_accuracy: 0.5044 - val_loss: 3.1857 - val_binary_accuracy: 0.5348
# Epoch 21/300
# 226/226 [==============================] - ETA: 0s - loss: 2.8662 - binary_accuracy: 0.5045
# Epoch 21: val_binary_accuracy did not improve from 0.53478
# 226/226 [==============================] - 58s 258ms/step - loss: 2.8662 - binary_accuracy: 0.5045 - val_loss: 2.5195 - val_binary_accuracy: 0.5267
# Epoch 22/300
# 226/226 [==============================] - ETA: 0s - loss: 2.2504 - binary_accuracy: 0.5022
# Epoch 22: val_binary_accuracy did not improve from 0.53478
# 226/226 [==============================] - 62s 277ms/step - loss: 2.2504 - binary_accuracy: 0.5022 - val_loss: 1.9486 - val_binary_accuracy: 0.5179
# Epoch 23/300
# 226/226 [==============================] - ETA: 0s - loss: 1.7109 - binary_accuracy: 0.5031
# Epoch 23: val_binary_accuracy did not improve from 0.53478
# 226/226 [==============================] - 58s 259ms/step - loss: 1.7109 - binary_accuracy: 0.5031 - val_loss: 1.4592 - val_binary_accuracy: 0.5169
# Epoch 24/300
# 226/226 [==============================] - ETA: 0s - loss: 1.2905 - binary_accuracy: 0.5036
# Epoch 24: val_binary_accuracy did not improve from 0.53478
# 226/226 [==============================] - 58s 256ms/step - loss: 1.2905 - binary_accuracy: 0.5036 - val_loss: 1.1025 - val_binary_accuracy: 0.5126
# Epoch 25/300
# 226/226 [==============================] - ETA: 0s - loss: 0.9820 - binary_accuracy: 0.5025
# Epoch 25: val_binary_accuracy did not improve from 0.53478
# 226/226 [==============================] - 62s 275ms/step - loss: 0.9820 - binary_accuracy: 0.5025 - val_loss: 0.8516 - val_binary_accuracy: 0.5107
# Epoch 26/300
# 226/226 [==============================] - ETA: 0s - loss: 0.7921 - binary_accuracy: 0.5003
# Epoch 26: val_binary_accuracy did not improve from 0.53478
# 226/226 [==============================] - 58s 257ms/step - loss: 0.7921 - binary_accuracy: 0.5003 - val_loss: 0.7257 - val_binary_accuracy: 0.5105
# Epoch 27/300
# 226/226 [==============================] - ETA: 0s - loss: 0.7171 - binary_accuracy: 0.5014
# Epoch 27: val_binary_accuracy did not improve from 0.53478
# 226/226 [==============================] - 58s 258ms/step - loss: 0.7171 - binary_accuracy: 0.5014 - val_loss: 0.6948 - val_binary_accuracy: 0.5105
# Epoch 28/300
# 226/226 [==============================] - ETA: 0s - loss: 0.7060 - binary_accuracy: 0.5010
# Epoch 28: val_binary_accuracy did not improve from 0.53478
# 226/226 [==============================] - 63s 277ms/step - loss: 0.7060 - binary_accuracy: 0.5010 - val_loss: 0.6947 - val_binary_accuracy: 0.5105
# Epoch 29/300
# 226/226 [==============================] - ETA: 0s - loss: 0.7056 - binary_accuracy: 0.4997
# Epoch 29: val_binary_accuracy did not improve from 0.53478
# 226/226 [==============================] - 58s 257ms/step - loss: 0.7056 - binary_accuracy: 0.4997 - val_loss: 0.6948 - val_binary_accuracy: 0.5105
# Epoch 30/300
# 226/226 [==============================] - ETA: 0s - loss: 0.7043 - binary_accuracy: 0.5001
# Epoch 30: val_binary_accuracy did not improve from 0.53478
# 226/226 [==============================] - 58s 256ms/step - loss: 0.7043 - binary_accuracy: 0.5001 - val_loss: 0.6948 - val_binary_accuracy: 0.5105
# 136/136 [==============================] - 3s 22ms/step - loss: 3.1860 - binary_accuracy: 0.5289
# Loss: 3.1860
# Accuracy: 52.89%
# <ipython-input-6-4fa72de1b3b4>:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parameters_to_save = parameters_to_save.append({'GRU_blocks' : GRU_blocks, 'learning_rate': lr, 'regularizer': regularizer, 'droput': dropout,

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2,1, figsize = (15,15))
axs = axs.flatten()
axs[0].plot(history.history['binary_accuracy'])
axs[0].plot(history.history['val_binary_accuracy'])
axs[0].set_title('model accuracy')

axs[0].legend(['train', 'val'], loc='upper left')

# summarize history for loss
axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('model loss')

axs[1].legend(['train', 'val'], loc='upper left')
