# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle as pkl
import numpy as np
import pandas as pd 


with open('/content/drive/MyDrive/Dataset_with_memory /1min/X_train.pickle', 'rb') as f:
    X_train = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /1min/Y_train.pickle', 'rb') as f:
    Y_train = pkl.load(f)


with open('/content/drive/MyDrive/Dataset_with_memory /1min/Y_val.pickle', 'rb') as f:
    Y_val = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /1min/X_val.pickle', 'rb') as f:
     X_val = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /1min/Y_test.pickle', 'rb') as f:
    Y_test = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /1min/X_test.pickle', 'rb') as f:
     X_test = pkl.load(f)


Y_train = Y_train.reshape((-1,1))
Y_val = Y_val.reshape((-1,1))
Y_test = Y_test.reshape((-1,1))

X_train.shape , Y_train.shape , X_val.shape , Y_val.shape , X_test.shape , Y_test.shape
# Out:
# ((225480, 120, 5),
#  (225480, 1),
#  (45000, 120, 5),
#  (45000, 1),
#  (135240, 120, 5),
#  (135240, 1))

# %%
from sklearn.utils.class_weight import compute_class_weight



class_weights = compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique ( np.reshape( Y_train , (np.shape(Y_train)[0]))),
                                        y = np.reshape(Y_train ,(np.shape(Y_train)[0]))                                                 
                                    )
class_weights = dict(zip(np.unique(np.reshape(Y_train ,(np.shape(Y_train)[0]))), class_weights))
class_weights
# Out:
# {0: 1.173189589685422, 1: 0.8713664082607452}

# %%
import os

filepath = "/content/drive/MyDrive/parameter_tuning_GRU.csv"

# check if the file exists, create it if not
if not os.path.isfile(filepath):
    columns_name = ['GRU_blocks', 'learning_rate', 'regularizer', 'droput', 'optimizer', 'batch size' , 'weight_decay',
                    'train_loss' , 'val_loss' , 'train_accuracy' , 'val_accuracy', 'test_loss' , 'test_accuracy']
    df = pd.DataFrame(columns=columns_name)  # create an empty dataframe
    df.to_csv(filepath, index=False)  # save as a CSV file with no index

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense, GRU, Dropout, BatchNormalization
from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import load_model
from tensorflow.keras import regularizers
from tensorflow import keras
import numpy as np 

#reproducibility 
np.random.seed(0)
tf.random.set_seed(0)

#defining hyperparameters

weight_decay = 1e-7
GRU_blocks= 20
regularizer = 0
lr = 0.001
dropout  = 0.5
batchsize = 128
optimizer_func = 'Adam'
#threshold = 0.5

# Define the model
def create_model(GRU_blocks, regularizer, dropout):
    model = Sequential()
    #model.add(BatchNormalization(input_shape=(120, 5)))
    model.add(GRU(GRU_blocks, input_shape=(120, 5) , return_sequences=False, activation='tanh', bias_regularizer=regularizers.l1(regularizer),  kernel_regularizer=regularizers.l1(regularizer)))
   

    model.add(Dropout(dropout))

    #model.add(Dense(50, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.summary()
    return model 


model = create_model(GRU_blocks, regularizer, dropout)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  gru (GRU)                   (None, 20)                1620
#
#  dropout (Dropout)           (None, 20)                0
#
#  dense (Dense)               (None, 1)                 21
#
# =================================================================
# Total params: 1,641
# Trainable params: 1,641
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
optimizer = keras.optimizers.Adam(learning_rate=lr,weight_decay=weight_decay) if optimizer_func == 'Adam' else keras.optimizers.SGD(learning_rate=lr ,weight_decay=weight_decay)

model.compile(loss='binary_crossentropy', optimizer= optimizer, metrics=['binary_accuracy' ])


checkpoint_path = '/content/drive/MyDrive/my_best_model_GRU.hdf5'

checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             monitor='val_binary_accuracy',
                             verbose=1, 
                             save_best_only=True,
                             mode='max')


earlystopping = EarlyStopping(monitor='val_binary_accuracy', patience=10, restore_best_weights=True)

callback = [earlystopping, checkpoint]
# Train the model
history = model.fit(X_train, Y_train, validation_data=(X_val , Y_val) , verbose=1,  batch_size=batchsize, epochs=150,callbacks = callback, class_weight=class_weights)

loss, accuracy = model.evaluate(X_test, Y_test, batch_size=batchsize)

print(f"Loss: {loss:.4f}")
print(f"Accuracy: {accuracy*100:.2f}%")

filepath = "/content/drive/MyDrive/parameter_tuning_GRU.csv"
parameters_to_save = pd.read_csv(filepath)

parameters_to_save = parameters_to_save.append({'GRU_blocks' : GRU_blocks, 'learning_rate': lr, 'regularizer': regularizer, 'droput': dropout, 
                                                'optimizer': optimizer_func, 'batch size': batchsize, 'weight_decay': weight_decay,
                                                'train_loss' : history.history['loss'][-1] ,'val_loss' : history.history['val_loss'][-1] , 
                                                'train_accuracy' : history.history['binary_accuracy'][-1] , 'val_accuracy' : history.history['val_binary_accuracy'][-1],
                                                'test_loss' : f"{loss:.4f}" , 'test_accuracy' : f"{accuracy*100:.2f}%" } , ignore_index = True ) 

parameters_to_save.to_csv(filepath, index=False)
# Out:
# Epoch 1/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.6943 - binary_accuracy: 0.5177
# Epoch 1: val_binary_accuracy improved from -inf to 0.49062, saving model to /content/drive/MyDrive/my_best_model_GRU.hdf5
# 1762/1762 [==============================] - 26s 10ms/step - loss: 0.6943 - binary_accuracy: 0.5178 - val_loss: 0.6955 - val_binary_accuracy: 0.4906
# Epoch 2/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.6918 - binary_accuracy: 0.5336
# Epoch 2: val_binary_accuracy did not improve from 0.49062
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.6918 - binary_accuracy: 0.5336 - val_loss: 0.6968 - val_binary_accuracy: 0.4886
# Epoch 3/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.6911 - binary_accuracy: 0.5415
# Epoch 3: val_binary_accuracy improved from 0.49062 to 0.49249, saving model to /content/drive/MyDrive/my_best_model_GRU.hdf5
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.6911 - binary_accuracy: 0.5415 - val_loss: 0.6956 - val_binary_accuracy: 0.4925
# Epoch 4/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.6906 - binary_accuracy: 0.5433
# Epoch 4: val_binary_accuracy did not improve from 0.49249
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6907 - binary_accuracy: 0.5433 - val_loss: 0.6953 - val_binary_accuracy: 0.4915
# Epoch 5/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.6903 - binary_accuracy: 0.5422
# Epoch 5: val_binary_accuracy improved from 0.49249 to 0.49267, saving model to /content/drive/MyDrive/my_best_model_GRU.hdf5
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.6903 - binary_accuracy: 0.5423 - val_loss: 0.6957 - val_binary_accuracy: 0.4927
# Epoch 6/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.6902 - binary_accuracy: 0.5432
# Epoch 6: val_binary_accuracy did not improve from 0.49267
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.6902 - binary_accuracy: 0.5431 - val_loss: 0.6946 - val_binary_accuracy: 0.4886
# Epoch 7/150
# 1756/1762 [============================>.] - ETA: 0s - loss: 0.6897 - binary_accuracy: 0.5443
# Epoch 7: val_binary_accuracy improved from 0.49267 to 0.49818, saving model to /content/drive/MyDrive/my_best_model_GRU.hdf5
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.6897 - binary_accuracy: 0.5444 - val_loss: 0.6950 - val_binary_accuracy: 0.4982
# Epoch 8/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.6895 - binary_accuracy: 0.5456
# Epoch 8: val_binary_accuracy improved from 0.49818 to 0.50469, saving model to /content/drive/MyDrive/my_best_model_GRU.hdf5
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.6895 - binary_accuracy: 0.5456 - val_loss: 0.6951 - val_binary_accuracy: 0.5047
# Epoch 9/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.6892 - binary_accuracy: 0.5473
# Epoch 9: val_binary_accuracy improved from 0.50469 to 0.50793, saving model to /content/drive/MyDrive/my_best_model_GRU.hdf5
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.6892 - binary_accuracy: 0.5473 - val_loss: 0.6942 - val_binary_accuracy: 0.5079
# Epoch 10/150
# 1755/1762 [============================>.] - ETA: 0s - loss: 0.6887 - binary_accuracy: 0.5491
# Epoch 10: val_binary_accuracy improved from 0.50793 to 0.52018, saving model to /content/drive/MyDrive/my_best_model_GRU.hdf5
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.6888 - binary_accuracy: 0.5491 - val_loss: 0.6928 - val_binary_accuracy: 0.5202
# Epoch 11/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.6884 - binary_accuracy: 0.5505
# Epoch 11: val_binary_accuracy improved from 0.52018 to 0.52067, saving model to /content/drive/MyDrive/my_best_model_GRU.hdf5
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.6884 - binary_accuracy: 0.5505 - val_loss: 0.6925 - val_binary_accuracy: 0.5207
# Epoch 12/150
# 1756/1762 [============================>.] - ETA: 0s - loss: 0.6882 - binary_accuracy: 0.5511
# Epoch 12: val_binary_accuracy did not improve from 0.52067
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.6882 - binary_accuracy: 0.5511 - val_loss: 0.6933 - val_binary_accuracy: 0.5171
# Epoch 13/150
# 1756/1762 [============================>.] - ETA: 0s - loss: 0.6882 - binary_accuracy: 0.5512
# Epoch 13: val_binary_accuracy did not improve from 0.52067
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.6882 - binary_accuracy: 0.5511 - val_loss: 0.6935 - val_binary_accuracy: 0.5171
# Epoch 14/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.6879 - binary_accuracy: 0.5536
# Epoch 14: val_binary_accuracy did not improve from 0.52067
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.6879 - binary_accuracy: 0.5536 - val_loss: 0.6925 - val_binary_accuracy: 0.5194
# Epoch 15/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.6877 - binary_accuracy: 0.5514
# Epoch 15: val_binary_accuracy did not improve from 0.52067
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.6877 - binary_accuracy: 0.5514 - val_loss: 0.6929 - val_binary_accuracy: 0.5195
# Epoch 16/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.6874 - binary_accuracy: 0.5542
# Epoch 16: val_binary_accuracy did not improve from 0.52067
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6874 - binary_accuracy: 0.5542 - val_loss: 0.6933 - val_binary_accuracy: 0.5192
# Epoch 17/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.6874 - binary_accuracy: 0.5535
# Epoch 17: val_binary_accuracy did not improve from 0.52067
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.6874 - binary_accuracy: 0.5535 - val_loss: 0.6927 - val_binary_accuracy: 0.5201
# Epoch 18/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.6872 - binary_accuracy: 0.5565
# Epoch 18: val_binary_accuracy improved from 0.52067 to 0.52187, saving model to /content/drive/MyDrive/my_best_model_GRU.hdf5
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.6872 - binary_accuracy: 0.5566 - val_loss: 0.6923 - val_binary_accuracy: 0.5219
# Epoch 19/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.6870 - binary_accuracy: 0.5551
# Epoch 19: val_binary_accuracy improved from 0.52187 to 0.52233, saving model to /content/drive/MyDrive/my_best_model_GRU.hdf5
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.6870 - binary_accuracy: 0.5551 - val_loss: 0.6920 - val_binary_accuracy: 0.5223
# Epoch 20/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.6868 - binary_accuracy: 0.5550
# Epoch 20: val_binary_accuracy improved from 0.52233 to 0.52324, saving model to /content/drive/MyDrive/my_best_model_GRU.hdf5
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.6868 - binary_accuracy: 0.5550 - val_loss: 0.6925 - val_binary_accuracy: 0.5232
# Epoch 21/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.6869 - binary_accuracy: 0.5558
# Epoch 21: val_binary_accuracy improved from 0.52324 to 0.52596, saving model to /content/drive/MyDrive/my_best_model_GRU.hdf5
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.6869 - binary_accuracy: 0.5558 - val_loss: 0.6922 - val_binary_accuracy: 0.5260
# Epoch 22/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.6868 - binary_accuracy: 0.5569
# Epoch 22: val_binary_accuracy did not improve from 0.52596
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.6868 - binary_accuracy: 0.5568 - val_loss: 0.6921 - val_binary_accuracy: 0.5225
# Epoch 23/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.6864 - binary_accuracy: 0.5556
# Epoch 23: val_binary_accuracy did not improve from 0.52596
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.6864 - binary_accuracy: 0.5556 - val_loss: 0.6932 - val_binary_accuracy: 0.5235
# Epoch 24/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.6865 - binary_accuracy: 0.5567
# Epoch 24: val_binary_accuracy did not improve from 0.52596
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.6865 - binary_accuracy: 0.5567 - val_loss: 0.6919 - val_binary_accuracy: 0.5253
# Epoch 25/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.6863 - binary_accuracy: 0.5564
# Epoch 25: val_binary_accuracy did not improve from 0.52596
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.6864 - binary_accuracy: 0.5563 - val_loss: 0.6924 - val_binary_accuracy: 0.5247
# Epoch 26/150
# 1756/1762 [============================>.] - ETA: 0s - loss: 0.6864 - binary_accuracy: 0.5574
# Epoch 26: val_binary_accuracy did not improve from 0.52596
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.6863 - binary_accuracy: 0.5574 - val_loss: 0.6926 - val_binary_accuracy: 0.5242
# Epoch 27/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.6862 - binary_accuracy: 0.5568
# Epoch 27: val_binary_accuracy did not improve from 0.52596
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.6862 - binary_accuracy: 0.5568 - val_loss: 0.6928 - val_binary_accuracy: 0.5245
# Epoch 28/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.6861 - binary_accuracy: 0.5567
# Epoch 28: val_binary_accuracy did not improve from 0.52596
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.6861 - binary_accuracy: 0.5567 - val_loss: 0.6921 - val_binary_accuracy: 0.5259
# Epoch 29/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.6861 - binary_accuracy: 0.5565
# Epoch 29: val_binary_accuracy improved from 0.52596 to 0.52691, saving model to /content/drive/MyDrive/my_best_model_GRU.hdf5
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.6861 - binary_accuracy: 0.5565 - val_loss: 0.6918 - val_binary_accuracy: 0.5269
# Epoch 30/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.6858 - binary_accuracy: 0.5569
# Epoch 30: val_binary_accuracy did not improve from 0.52691
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.6858 - binary_accuracy: 0.5569 - val_loss: 0.6927 - val_binary_accuracy: 0.5260
# Epoch 31/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.6858 - binary_accuracy: 0.5569
# Epoch 31: val_binary_accuracy did not improve from 0.52691
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.6858 - binary_accuracy: 0.5569 - val_loss: 0.6925 - val_binary_accuracy: 0.5254
# Epoch 32/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.6859 - binary_accuracy: 0.5561
# Epoch 32: val_binary_accuracy did not improve from 0.52691
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.6859 - binary_accuracy: 0.5561 - val_loss: 0.6930 - val_binary_accuracy: 0.5237
# Epoch 33/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.6857 - binary_accuracy: 0.5557
# Epoch 33: val_binary_accuracy did not improve from 0.52691
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.6857 - binary_accuracy: 0.5557 - val_loss: 0.6922 - val_binary_accuracy: 0.5256
# Epoch 34/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.6853 - binary_accuracy: 0.5578
# Epoch 34: val_binary_accuracy improved from 0.52691 to 0.52702, saving model to /content/drive/MyDrive/my_best_model_GRU.hdf5
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.6853 - binary_accuracy: 0.5577 - val_loss: 0.6924 - val_binary_accuracy: 0.5270
# Epoch 35/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.6856 - binary_accuracy: 0.5571
# Epoch 35: val_binary_accuracy did not improve from 0.52702
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.6856 - binary_accuracy: 0.5571 - val_loss: 0.6920 - val_binary_accuracy: 0.5269
# Epoch 36/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.6852 - binary_accuracy: 0.5578
# Epoch 36: val_binary_accuracy improved from 0.52702 to 0.52860, saving model to /content/drive/MyDrive/my_best_model_GRU.hdf5
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.6852 - binary_accuracy: 0.5578 - val_loss: 0.6918 - val_binary_accuracy: 0.5286
# Epoch 37/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.6854 - binary_accuracy: 0.5574
# Epoch 37: val_binary_accuracy did not improve from 0.52860
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.6854 - binary_accuracy: 0.5574 - val_loss: 0.6919 - val_binary_accuracy: 0.5270
# Epoch 38/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.6851 - binary_accuracy: 0.5575
# Epoch 38: val_binary_accuracy did not improve from 0.52860
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.6851 - binary_accuracy: 0.5575 - val_loss: 0.6925 - val_binary_accuracy: 0.5260
# Epoch 39/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.6848 - binary_accuracy: 0.5599
# Epoch 39: val_binary_accuracy did not improve from 0.52860
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.6848 - binary_accuracy: 0.5599 - val_loss: 0.6936 - val_binary_accuracy: 0.5239
# Epoch 40/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.6850 - binary_accuracy: 0.5577
# Epoch 40: val_binary_accuracy did not improve from 0.52860
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.6850 - binary_accuracy: 0.5577 - val_loss: 0.6922 - val_binary_accuracy: 0.5282
# Epoch 41/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.6849 - binary_accuracy: 0.5590
# Epoch 41: val_binary_accuracy did not improve from 0.52860
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.6849 - binary_accuracy: 0.5590 - val_loss: 0.6922 - val_binary_accuracy: 0.5270
# Epoch 42/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.6849 - binary_accuracy: 0.5585
# Epoch 42: val_binary_accuracy did not improve from 0.52860
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6849 - binary_accuracy: 0.5585 - val_loss: 0.6923 - val_binary_accuracy: 0.5266
# Epoch 43/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.6848 - binary_accuracy: 0.5588
# Epoch 43: val_binary_accuracy did not improve from 0.52860
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.6848 - binary_accuracy: 0.5588 - val_loss: 0.6927 - val_binary_accuracy: 0.5278
# Epoch 44/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.6848 - binary_accuracy: 0.5585
# Epoch 44: val_binary_accuracy did not improve from 0.52860
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.6848 - binary_accuracy: 0.5585 - val_loss: 0.6931 - val_binary_accuracy: 0.5256
# Epoch 45/150
# 1756/1762 [============================>.] - ETA: 0s - loss: 0.6844 - binary_accuracy: 0.5598
# Epoch 45: val_binary_accuracy improved from 0.52860 to 0.52913, saving model to /content/drive/MyDrive/my_best_model_GRU.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6844 - binary_accuracy: 0.5598 - val_loss: 0.6922 - val_binary_accuracy: 0.5291
# Epoch 46/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.6845 - binary_accuracy: 0.5592
# Epoch 46: val_binary_accuracy did not improve from 0.52913
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.6845 - binary_accuracy: 0.5592 - val_loss: 0.6932 - val_binary_accuracy: 0.5250
# Epoch 47/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.6846 - binary_accuracy: 0.5596
# Epoch 47: val_binary_accuracy did not improve from 0.52913
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.6846 - binary_accuracy: 0.5596 - val_loss: 0.6929 - val_binary_accuracy: 0.5234
# Epoch 48/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.6846 - binary_accuracy: 0.5584
# Epoch 48: val_binary_accuracy did not improve from 0.52913
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.6846 - binary_accuracy: 0.5584 - val_loss: 0.6930 - val_binary_accuracy: 0.5248
# Epoch 49/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.6847 - binary_accuracy: 0.5590
# Epoch 49: val_binary_accuracy did not improve from 0.52913
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.6846 - binary_accuracy: 0.5590 - val_loss: 0.6926 - val_binary_accuracy: 0.5254
# Epoch 50/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.6845 - binary_accuracy: 0.5593
# Epoch 50: val_binary_accuracy did not improve from 0.52913
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.6845 - binary_accuracy: 0.5593 - val_loss: 0.6929 - val_binary_accuracy: 0.5272
# Epoch 51/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.6844 - binary_accuracy: 0.5601
# Epoch 51: val_binary_accuracy did not improve from 0.52913
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.6844 - binary_accuracy: 0.5601 - val_loss: 0.6927 - val_binary_accuracy: 0.5284
# Epoch 52/150
# 1756/1762 [============================>.] - ETA: 0s - loss: 0.6845 - binary_accuracy: 0.5585
# Epoch 52: val_binary_accuracy did not improve from 0.52913
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.6845 - binary_accuracy: 0.5585 - val_loss: 0.6943 - val_binary_accuracy: 0.5255
# Epoch 53/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.6841 - binary_accuracy: 0.5604
# Epoch 53: val_binary_accuracy did not improve from 0.52913
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.6841 - binary_accuracy: 0.5605 - val_loss: 0.6927 - val_binary_accuracy: 0.5279
# Epoch 54/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.6839 - binary_accuracy: 0.5602
# Epoch 54: val_binary_accuracy did not improve from 0.52913
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.6839 - binary_accuracy: 0.5602 - val_loss: 0.6924 - val_binary_accuracy: 0.5270
# Epoch 55/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.6842 - binary_accuracy: 0.5595
# Epoch 55: val_binary_accuracy did not improve from 0.52913
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6842 - binary_accuracy: 0.5596 - val_loss: 0.6933 - val_binary_accuracy: 0.5246
# 1057/1057 [==============================] - 5s 5ms/step - loss: 0.6924 - binary_accuracy: 0.5260
# Loss: 0.6924
# Accuracy: 52.60%
# <ipython-input-6-846602215e84>:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parameters_to_save = parameters_to_save.append({'GRU_blocks' : GRU_blocks, 'learning_rate': lr, 'regularizer': regularizer, 'droput': dropout,

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2,1, figsize = (15,15))
axs = axs.flatten()
axs[0].plot(history.history['binary_accuracy'])
axs[0].plot(history.history['val_binary_accuracy'])
axs[0].set_title('model accuracy')

axs[0].legend(['train', 'val'], loc='upper left')

# summarize history for loss
axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('model loss')

axs[1].legend(['train', 'val'], loc='upper left')
