# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle as pkl
import numpy as np
import pandas as pd 


with open('/content/drive/MyDrive/Dataset_with_memory /5min/X_train_5min.pickle', 'rb') as f:
    X_train = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /5min/Y_train_5min.pickle', 'rb') as f:
    Y_train = pkl.load(f)


with open('/content/drive/MyDrive/Dataset_with_memory /5min/Y_val_5min.pickle', 'rb') as f:
    Y_val = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /5min/X_val_5min.pickle', 'rb') as f:
     X_val = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /5min/Y_test_5min.pickle', 'rb') as f:
    Y_test = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /5min/X_test_5min.pickle', 'rb') as f:
     X_test = pkl.load(f)


Y_train = Y_train.reshape((-1,1))
Y_val = Y_val.reshape((-1,1))
Y_test = Y_test.reshape((-1,1))

X_train.shape , Y_train.shape , X_val.shape , Y_val.shape , X_test.shape , Y_test.shape
# Out:
# ((225480, 120, 5),
#  (225480, 1),
#  (45000, 120, 5),
#  (45000, 1),
#  (135240, 120, 5),
#  (135240, 1))

# %%
from sklearn.utils.class_weight import compute_class_weight



class_weights = compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique ( np.reshape( Y_train , (np.shape(Y_train)[0]))),
                                        y = np.reshape(Y_train ,(np.shape(Y_train)[0]))                                                 
                                    )
class_weights = dict(zip(np.unique(np.reshape(Y_train ,(np.shape(Y_train)[0]))), class_weights))
class_weights
# Out:
# {0: 1.0362703825578616, 1: 0.9661827468590919}

# %%
import os

filepath = "/content/drive/MyDrive/parameter_tuning_LSTM_5min.csv"

# check if the file exists, create it if not
if not os.path.isfile(filepath):
    columns_name = ['LSTM_blocks', 'learning_rate', 'regularizer', 'droput', 'optimizer', 'batch size' ,
                    'train_loss' , 'val_loss' , 'train_accuracy' , 'val_accuracy', 'test_loss' , 'test_accuracy']
    df = pd.DataFrame(columns=columns_name)  # create an empty dataframe
    df.to_csv(filepath, index=False)  # save as a CSV file with no index

# %%
import tensorflow
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, BatchNormalization , Flatten
from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import load_model
from tensorflow.keras import regularizers
from tensorflow import keras
import numpy as np 

#reproducibility 
np.random.seed(0)
tensorflow.random.set_seed(0)

#defining hyperparameters

LSTM_blocks = 20
regularizer = 0
lr = 0.005  
dropout  = 0.5
batchsize = 128
optimizer_func = 'Adam'

# Define the model
def create_model(LSTM_blocks, regularizer, dropout):
    model = Sequential()
    #model.add(BatchNormalization(input_shape=(120, 5)))
    model.add(LSTM(LSTM_blocks, input_shape=(120, 5) , return_sequences=True , activation='tanh', bias_regularizer=regularizers.l1(regularizer),  kernel_regularizer=regularizers.l1(regularizer)))
    model.add(Flatten())
    model.add(Dropout(dropout))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.summary()
    return model 


model = create_model(LSTM_blocks, regularizer, dropout)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 120, 20)           2080
#
#  flatten (Flatten)           (None, 2400)              0
#
#  dropout (Dropout)           (None, 2400)              0
#
#  dense (Dense)               (None, 50)                120050
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 122,181
# Trainable params: 122,181
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
optimizer = keras.optimizers.Adam(learning_rate=lr,weight_decay=1e-7) if optimizer_func == 'Adam' else keras.optimizers.SGD(learning_rate=lr ,weight_decay=1e-7)

model.compile(loss='binary_crossentropy', optimizer= optimizer, metrics=['binary_accuracy' ])


checkpoint_path = '/content/drive/MyDrive/my_best_model_LSTM_5min.hdf5'

checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             monitor='val_binary_accuracy',
                             verbose=1, 
                             save_best_only=True,
                             mode='max')


earlystopping = EarlyStopping(monitor='val_binary_accuracy', patience=10, restore_best_weights=True)

callback = [earlystopping, checkpoint]
# Train the model
history = model.fit(X_train, Y_train, validation_data=(X_val , Y_val) , verbose=1,  batch_size=batchsize, epochs=150,callbacks = callback , class_weight=class_weights)

loss, accuracy = model.evaluate(X_test, Y_test, batch_size= batchsize)

print(f"Loss: {loss:.4f}")
print(f"Accuracy: {accuracy*100:.2f}%")

filepath = "/content/drive/MyDrive/parameter_tuning_LSTM_5min.csv"
parameters_to_save = pd.read_csv(filepath)

parameters_to_save = parameters_to_save.append({'LSTM_blocks' : LSTM_blocks, 'learning_rate': lr, 'regularizer': regularizer, 'droput': dropout, 
                                                'optimizer': optimizer_func, 'batch size': batchsize, 'train_loss' : history.history['loss'][-1] ,
                                                'val_loss' : history.history['val_loss'][-1] , 'train_accuracy' : history.history['binary_accuracy'][-1] , 
                                                'val_accuracy' : history.history['val_binary_accuracy'][-1],'test_loss' : f"{loss:.4f}" , 
                                                'test_accuracy' : f"{accuracy*100:.2f}%" } , ignore_index = True ) 

parameters_to_save.to_csv(filepath, index=False)
# Out:
# Epoch 1/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.4340 - binary_accuracy: 0.7955
# Epoch 1: val_binary_accuracy improved from -inf to 0.81431, saving model to /content/drive/MyDrive/my_best_model_LSTM_5min.hdf5
# 1762/1762 [==============================] - 27s 10ms/step - loss: 0.4341 - binary_accuracy: 0.7955 - val_loss: 0.4016 - val_binary_accuracy: 0.8143
# Epoch 2/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.4013 - binary_accuracy: 0.8174
# Epoch 2: val_binary_accuracy improved from 0.81431 to 0.81818, saving model to /content/drive/MyDrive/my_best_model_LSTM_5min.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.4013 - binary_accuracy: 0.8174 - val_loss: 0.3973 - val_binary_accuracy: 0.8182
# Epoch 3/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.3927 - binary_accuracy: 0.8209
# Epoch 3: val_binary_accuracy improved from 0.81818 to 0.82278, saving model to /content/drive/MyDrive/my_best_model_LSTM_5min.hdf5
# 1762/1762 [==============================] - 15s 9ms/step - loss: 0.3927 - binary_accuracy: 0.8210 - val_loss: 0.3893 - val_binary_accuracy: 0.8228
# Epoch 4/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.3824 - binary_accuracy: 0.8282
# Epoch 4: val_binary_accuracy improved from 0.82278 to 0.82309, saving model to /content/drive/MyDrive/my_best_model_LSTM_5min.hdf5
# 1762/1762 [==============================] - 15s 9ms/step - loss: 0.3824 - binary_accuracy: 0.8282 - val_loss: 0.3887 - val_binary_accuracy: 0.8231
# Epoch 5/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.3753 - binary_accuracy: 0.8317
# Epoch 5: val_binary_accuracy improved from 0.82309 to 0.82784, saving model to /content/drive/MyDrive/my_best_model_LSTM_5min.hdf5
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.3753 - binary_accuracy: 0.8317 - val_loss: 0.3811 - val_binary_accuracy: 0.8278
# Epoch 6/150
# 1756/1762 [============================>.] - ETA: 0s - loss: 0.3716 - binary_accuracy: 0.8349
# Epoch 6: val_binary_accuracy improved from 0.82784 to 0.82824, saving model to /content/drive/MyDrive/my_best_model_LSTM_5min.hdf5
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3715 - binary_accuracy: 0.8349 - val_loss: 0.3788 - val_binary_accuracy: 0.8282
# Epoch 7/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.3674 - binary_accuracy: 0.8369
# Epoch 7: val_binary_accuracy did not improve from 0.82824
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3674 - binary_accuracy: 0.8369 - val_loss: 0.3780 - val_binary_accuracy: 0.8282
# Epoch 8/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.3658 - binary_accuracy: 0.8379
# Epoch 8: val_binary_accuracy improved from 0.82824 to 0.82842, saving model to /content/drive/MyDrive/my_best_model_LSTM_5min.hdf5
# 1762/1762 [==============================] - 15s 9ms/step - loss: 0.3658 - binary_accuracy: 0.8379 - val_loss: 0.3785 - val_binary_accuracy: 0.8284
# Epoch 9/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.3633 - binary_accuracy: 0.8393
# Epoch 9: val_binary_accuracy did not improve from 0.82842
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.3633 - binary_accuracy: 0.8393 - val_loss: 0.3860 - val_binary_accuracy: 0.8230
# Epoch 10/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.3618 - binary_accuracy: 0.8404
# Epoch 10: val_binary_accuracy improved from 0.82842 to 0.83302, saving model to /content/drive/MyDrive/my_best_model_LSTM_5min.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.3618 - binary_accuracy: 0.8404 - val_loss: 0.3718 - val_binary_accuracy: 0.8330
# Epoch 11/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.3594 - binary_accuracy: 0.8417
# Epoch 11: val_binary_accuracy did not improve from 0.83302
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3595 - binary_accuracy: 0.8417 - val_loss: 0.3788 - val_binary_accuracy: 0.8284
# Epoch 12/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.3580 - binary_accuracy: 0.8419
# Epoch 12: val_binary_accuracy did not improve from 0.83302
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3580 - binary_accuracy: 0.8419 - val_loss: 0.3763 - val_binary_accuracy: 0.8309
# Epoch 13/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.3576 - binary_accuracy: 0.8425
# Epoch 13: val_binary_accuracy did not improve from 0.83302
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3576 - binary_accuracy: 0.8425 - val_loss: 0.3806 - val_binary_accuracy: 0.8326
# Epoch 14/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.3560 - binary_accuracy: 0.8436
# Epoch 14: val_binary_accuracy did not improve from 0.83302
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3560 - binary_accuracy: 0.8435 - val_loss: 0.3773 - val_binary_accuracy: 0.8289
# Epoch 15/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.3546 - binary_accuracy: 0.8444
# Epoch 15: val_binary_accuracy did not improve from 0.83302
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3546 - binary_accuracy: 0.8444 - val_loss: 0.3755 - val_binary_accuracy: 0.8313
# Epoch 16/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.3542 - binary_accuracy: 0.8448
# Epoch 16: val_binary_accuracy did not improve from 0.83302
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3542 - binary_accuracy: 0.8448 - val_loss: 0.3782 - val_binary_accuracy: 0.8305
# Epoch 17/150
# 1755/1762 [============================>.] - ETA: 0s - loss: 0.3526 - binary_accuracy: 0.8456
# Epoch 17: val_binary_accuracy did not improve from 0.83302
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3527 - binary_accuracy: 0.8455 - val_loss: 0.3766 - val_binary_accuracy: 0.8294
# Epoch 18/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.3517 - binary_accuracy: 0.8459
# Epoch 18: val_binary_accuracy did not improve from 0.83302
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3517 - binary_accuracy: 0.8459 - val_loss: 0.3790 - val_binary_accuracy: 0.8292
# Epoch 19/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.3499 - binary_accuracy: 0.8474
# Epoch 19: val_binary_accuracy did not improve from 0.83302
# 1762/1762 [==============================] - 17s 9ms/step - loss: 0.3499 - binary_accuracy: 0.8474 - val_loss: 0.3786 - val_binary_accuracy: 0.8303
# Epoch 20/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.3498 - binary_accuracy: 0.8462
# Epoch 20: val_binary_accuracy did not improve from 0.83302
# 1762/1762 [==============================] - 15s 9ms/step - loss: 0.3498 - binary_accuracy: 0.8462 - val_loss: 0.3815 - val_binary_accuracy: 0.8288
# 1057/1057 [==============================] - 4s 4ms/step - loss: 0.3932 - binary_accuracy: 0.8202
# Loss: 0.3932
# Accuracy: 82.02%
# <ipython-input-6-81fd9d9b3cdf>:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parameters_to_save = parameters_to_save.append({'LSTM_blocks' : LSTM_blocks, 'learning_rate': lr, 'regularizer': regularizer, 'droput': dropout,

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2,1, figsize = (15,15))
axs = axs.flatten()
axs[0].plot(history.history['binary_accuracy'])
axs[0].plot(history.history['val_binary_accuracy'])
axs[0].set_title('model accuracy')

axs[0].legend(['train', 'val'], loc='upper left')

# summarize history for loss
axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('model loss')

axs[1].legend(['train', 'val'], loc='upper left')

# %%
import keras.backend as K
def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

def recall(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision
