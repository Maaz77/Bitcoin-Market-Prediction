# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle as pkl
import numpy as np
import pandas as pd 


with open('/content/drive/MyDrive/Dataset_with_memory /60min/X_train_60min.pickle', 'rb') as f:
    X_train = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /60min/Y_train_60min.pickle', 'rb') as f:
    Y_train = pkl.load(f)


with open('/content/drive/MyDrive/Dataset_with_memory /60min/Y_val_60min.pickle', 'rb') as f:
    Y_val = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /60min/X_val_60min.pickle', 'rb') as f:
     X_val = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /60min/Y_test_60min.pickle', 'rb') as f:
    Y_test = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /60min/X_test_60min.pickle', 'rb') as f:
     X_test = pkl.load(f)


Y_train = Y_train.reshape((-1,1))
Y_val = Y_val.reshape((-1,1))
Y_test = Y_test.reshape((-1,1))

X_train.shape , Y_train.shape , X_val.shape , Y_val.shape , X_test.shape , Y_test.shape
# Out:
# ((225480, 120, 5),
#  (225480, 1),
#  (45000, 120, 5),
#  (45000, 1),
#  (135240, 120, 5),
#  (135240, 1))

# %%
from sklearn.utils.class_weight import compute_class_weight



class_weights = compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique ( np.reshape( Y_train , (np.shape(Y_train)[0]))),
                                        y = np.reshape(Y_train ,(np.shape(Y_train)[0]))                                                 
                                    )
class_weights = dict(zip(np.unique(np.reshape(Y_train ,(np.shape(Y_train)[0]))), class_weights))
class_weights
# Out:
# {0: 1.0305961076120045, 1: 0.9711681755924436}

# %%
import os

filepath = "/content/drive/MyDrive/parameter_tuning_LSTM_60min.csv"

# check if the file exists, create it if not
if not os.path.isfile(filepath):
    columns_name = ['LSTM_blocks', 'learning_rate', 'regularizer', 'droput', 'optimizer', 'batch size' ,
                    'train_loss' , 'val_loss' , 'train_accuracy' , 'val_accuracy', 'test_loss' , 'test_accuracy']
    df = pd.DataFrame(columns=columns_name)  # create an empty dataframe
    df.to_csv(filepath, index=False)  # save as a CSV file with no index

# %%
import tensorflow
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, BatchNormalization
from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import load_model
from tensorflow.keras import regularizers
from tensorflow import keras
import numpy as np 

#reproducibility 
np.random.seed(0)
tensorflow.random.set_seed(0)

#defining hyperparameters

LSTM_blocks = 20
regularizer = 0.3
lr = 0.0005  #I think best one is 0.0001
dropout  = 0.5
batchsize = 128
optimizer_func = 'Adam'

# Define the model
def create_model(LSTM_blocks, regularizer, dropout):
    model = Sequential()
    #model.add(BatchNormalization(input_shape=(120, 5)))
    model.add(LSTM(LSTM_blocks, input_shape=(120, 5) , return_sequences=False , activation='tanh', bias_regularizer=regularizers.l1(regularizer),  kernel_regularizer=regularizers.l1(regularizer)))
    model.add(Dropout(dropout))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.summary()
    return model 


model = create_model(LSTM_blocks, regularizer, dropout)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 20)                2080
#
#  dropout (Dropout)           (None, 20)                0
#
#  dense (Dense)               (None, 50)                1050
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 3,181
# Trainable params: 3,181
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
optimizer = keras.optimizers.Adam(learning_rate=lr,weight_decay=1e-7) if optimizer_func == 'Adam' else keras.optimizers.SGD(learning_rate=lr ,weight_decay=1e-7)

model.compile(loss='binary_crossentropy', optimizer= optimizer, metrics=['binary_accuracy' ])


checkpoint_path = '/content/drive/MyDrive/my_best_model_LSTM_60min.hdf5'

checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             monitor='val_binary_accuracy',
                             verbose=1, 
                             save_best_only=True,
                             mode='max')


earlystopping = EarlyStopping(monitor='val_binary_accuracy', patience=10, restore_best_weights=True)

callback = [earlystopping, checkpoint]
# Train the model
history = model.fit(X_train, Y_train, validation_data=(X_val , Y_val) , verbose=1,  batch_size=batchsize, epochs=150,callbacks = callback , class_weight=class_weights)

loss, accuracy = model.evaluate(X_test, Y_test, batch_size=5000)

print(f"Loss: {loss:.4f}")
print(f"Accuracy: {accuracy*100:.2f}%")

filepath = "/content/drive/MyDrive/parameter_tuning_LSTM_60min.csv"
parameters_to_save = pd.read_csv(filepath)

parameters_to_save = parameters_to_save.append({'LSTM_blocks' : LSTM_blocks, 'learning_rate': lr, 'regularizer': regularizer, 'droput': dropout, 
                                                'optimizer': optimizer_func, 'batch size': batchsize, 'train_loss' : history.history['loss'][-1] ,
                                                'val_loss' : history.history['val_loss'][-1] , 'train_accuracy' : history.history['binary_accuracy'][-1] , 
                                                'val_accuracy' : history.history['val_binary_accuracy'][-1],'test_loss' : f"{loss:.4f}" , 
                                                'test_accuracy' : f"{accuracy*100:.2f}%" } , ignore_index = True ) 

parameters_to_save.to_csv(filepath, index=False)
# Out:
# Epoch 1/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 5.3652 - binary_accuracy: 0.8481
# Epoch 1: val_binary_accuracy improved from -inf to 0.86682, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 27s 11ms/step - loss: 5.3614 - binary_accuracy: 0.8481 - val_loss: 1.0807 - val_binary_accuracy: 0.8668
# Epoch 2/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.3865 - binary_accuracy: 0.8926
# Epoch 2: val_binary_accuracy improved from 0.86682 to 0.88598, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.3863 - binary_accuracy: 0.8926 - val_loss: 0.3176 - val_binary_accuracy: 0.8860
# Epoch 3/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.3085 - binary_accuracy: 0.9002
# Epoch 3: val_binary_accuracy improved from 0.88598 to 0.88713, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.3085 - binary_accuracy: 0.9002 - val_loss: 0.3036 - val_binary_accuracy: 0.8871
# Epoch 4/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.2932 - binary_accuracy: 0.9043
# Epoch 4: val_binary_accuracy improved from 0.88713 to 0.89431, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.2932 - binary_accuracy: 0.9043 - val_loss: 0.2916 - val_binary_accuracy: 0.8943
# Epoch 5/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.2815 - binary_accuracy: 0.9062
# Epoch 5: val_binary_accuracy did not improve from 0.89431
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.2815 - binary_accuracy: 0.9062 - val_loss: 0.2866 - val_binary_accuracy: 0.8917
# Epoch 6/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.2742 - binary_accuracy: 0.9071
# Epoch 6: val_binary_accuracy improved from 0.89431 to 0.89509, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 17s 9ms/step - loss: 0.2742 - binary_accuracy: 0.9071 - val_loss: 0.2791 - val_binary_accuracy: 0.8951
# Epoch 7/150
# 1756/1762 [============================>.] - ETA: 0s - loss: 0.2693 - binary_accuracy: 0.9082
# Epoch 7: val_binary_accuracy did not improve from 0.89509
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.2693 - binary_accuracy: 0.9082 - val_loss: 0.2856 - val_binary_accuracy: 0.8917
# Epoch 8/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.2650 - binary_accuracy: 0.9091
# Epoch 8: val_binary_accuracy did not improve from 0.89509
# 1762/1762 [==============================] - 15s 9ms/step - loss: 0.2650 - binary_accuracy: 0.9091 - val_loss: 0.2961 - val_binary_accuracy: 0.8884
# Epoch 9/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.2618 - binary_accuracy: 0.9101
# Epoch 9: val_binary_accuracy improved from 0.89509 to 0.89962, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.2618 - binary_accuracy: 0.9101 - val_loss: 0.2749 - val_binary_accuracy: 0.8996
# Epoch 10/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.2594 - binary_accuracy: 0.9104
# Epoch 10: val_binary_accuracy improved from 0.89962 to 0.90158, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 18s 10ms/step - loss: 0.2594 - binary_accuracy: 0.9104 - val_loss: 0.2644 - val_binary_accuracy: 0.9016
# Epoch 11/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.2576 - binary_accuracy: 0.9108
# Epoch 11: val_binary_accuracy improved from 0.90158 to 0.90273, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.2576 - binary_accuracy: 0.9109 - val_loss: 0.2650 - val_binary_accuracy: 0.9027
# Epoch 12/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.2558 - binary_accuracy: 0.9110
# Epoch 12: val_binary_accuracy did not improve from 0.90273
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.2558 - binary_accuracy: 0.9110 - val_loss: 0.2800 - val_binary_accuracy: 0.8923
# Epoch 13/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.2553 - binary_accuracy: 0.9114
# Epoch 13: val_binary_accuracy did not improve from 0.90273
# 1762/1762 [==============================] - 17s 9ms/step - loss: 0.2553 - binary_accuracy: 0.9113 - val_loss: 0.2737 - val_binary_accuracy: 0.8956
# Epoch 14/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.2524 - binary_accuracy: 0.9115
# Epoch 14: val_binary_accuracy improved from 0.90273 to 0.90353, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.2523 - binary_accuracy: 0.9115 - val_loss: 0.2624 - val_binary_accuracy: 0.9035
# Epoch 15/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.2508 - binary_accuracy: 0.9126
# Epoch 15: val_binary_accuracy did not improve from 0.90353
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.2509 - binary_accuracy: 0.9126 - val_loss: 0.2662 - val_binary_accuracy: 0.9000
# Epoch 16/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.2487 - binary_accuracy: 0.9132
# Epoch 16: val_binary_accuracy did not improve from 0.90353
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.2487 - binary_accuracy: 0.9132 - val_loss: 0.2745 - val_binary_accuracy: 0.8961
# Epoch 17/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.2479 - binary_accuracy: 0.9131
# Epoch 17: val_binary_accuracy did not improve from 0.90353
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.2478 - binary_accuracy: 0.9131 - val_loss: 0.2805 - val_binary_accuracy: 0.8965
# Epoch 18/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.2466 - binary_accuracy: 0.9138
# Epoch 18: val_binary_accuracy did not improve from 0.90353
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.2467 - binary_accuracy: 0.9137 - val_loss: 0.2712 - val_binary_accuracy: 0.8963
# Epoch 19/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.2465 - binary_accuracy: 0.9131
# Epoch 19: val_binary_accuracy did not improve from 0.90353
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.2465 - binary_accuracy: 0.9131 - val_loss: 0.2568 - val_binary_accuracy: 0.9035
# Epoch 20/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.2439 - binary_accuracy: 0.9145
# Epoch 20: val_binary_accuracy did not improve from 0.90353
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.2439 - binary_accuracy: 0.9146 - val_loss: 0.2698 - val_binary_accuracy: 0.8973
# Epoch 21/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.2441 - binary_accuracy: 0.9143
# Epoch 21: val_binary_accuracy improved from 0.90353 to 0.90529, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.2441 - binary_accuracy: 0.9143 - val_loss: 0.2605 - val_binary_accuracy: 0.9053
# Epoch 22/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.2430 - binary_accuracy: 0.9146
# Epoch 22: val_binary_accuracy did not improve from 0.90529
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.2431 - binary_accuracy: 0.9146 - val_loss: 0.2592 - val_binary_accuracy: 0.9032
# Epoch 23/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.2427 - binary_accuracy: 0.9142
# Epoch 23: val_binary_accuracy improved from 0.90529 to 0.90747, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.2427 - binary_accuracy: 0.9143 - val_loss: 0.2482 - val_binary_accuracy: 0.9075
# Epoch 24/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.2429 - binary_accuracy: 0.9144
# Epoch 24: val_binary_accuracy did not improve from 0.90747
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.2429 - binary_accuracy: 0.9144 - val_loss: 0.2472 - val_binary_accuracy: 0.9073
# Epoch 25/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.2401 - binary_accuracy: 0.9148
# Epoch 25: val_binary_accuracy improved from 0.90747 to 0.90811, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.2400 - binary_accuracy: 0.9148 - val_loss: 0.2508 - val_binary_accuracy: 0.9081
# Epoch 26/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.2406 - binary_accuracy: 0.9147
# Epoch 26: val_binary_accuracy did not improve from 0.90811
# 1762/1762 [==============================] - 18s 10ms/step - loss: 0.2407 - binary_accuracy: 0.9147 - val_loss: 0.2590 - val_binary_accuracy: 0.9057
# Epoch 27/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.2390 - binary_accuracy: 0.9149
# Epoch 27: val_binary_accuracy did not improve from 0.90811
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.2390 - binary_accuracy: 0.9149 - val_loss: 0.2609 - val_binary_accuracy: 0.9022
# Epoch 28/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.2393 - binary_accuracy: 0.9150
# Epoch 28: val_binary_accuracy did not improve from 0.90811
# 1762/1762 [==============================] - 15s 9ms/step - loss: 0.2393 - binary_accuracy: 0.9150 - val_loss: 0.2511 - val_binary_accuracy: 0.9034
# Epoch 29/150
# 1756/1762 [============================>.] - ETA: 0s - loss: 0.2387 - binary_accuracy: 0.9151
# Epoch 29: val_binary_accuracy did not improve from 0.90811
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.2387 - binary_accuracy: 0.9151 - val_loss: 0.2576 - val_binary_accuracy: 0.9034
# Epoch 30/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.2388 - binary_accuracy: 0.9151
# Epoch 30: val_binary_accuracy improved from 0.90811 to 0.91198, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.2389 - binary_accuracy: 0.9151 - val_loss: 0.2403 - val_binary_accuracy: 0.9120
# Epoch 31/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.2382 - binary_accuracy: 0.9155
# Epoch 31: val_binary_accuracy improved from 0.91198 to 0.91304, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.2382 - binary_accuracy: 0.9155 - val_loss: 0.2366 - val_binary_accuracy: 0.9130
# Epoch 32/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.2392 - binary_accuracy: 0.9151
# Epoch 32: val_binary_accuracy did not improve from 0.91304
# 1762/1762 [==============================] - 17s 9ms/step - loss: 0.2391 - binary_accuracy: 0.9151 - val_loss: 0.2502 - val_binary_accuracy: 0.9062
# Epoch 33/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.2386 - binary_accuracy: 0.9143
# Epoch 33: val_binary_accuracy did not improve from 0.91304
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.2385 - binary_accuracy: 0.9143 - val_loss: 0.2369 - val_binary_accuracy: 0.9109
# Epoch 34/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.2381 - binary_accuracy: 0.9151
# Epoch 34: val_binary_accuracy did not improve from 0.91304
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.2381 - binary_accuracy: 0.9151 - val_loss: 0.2518 - val_binary_accuracy: 0.9038
# Epoch 35/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.2358 - binary_accuracy: 0.9157
# Epoch 35: val_binary_accuracy did not improve from 0.91304
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.2358 - binary_accuracy: 0.9157 - val_loss: 0.2452 - val_binary_accuracy: 0.9081
# Epoch 36/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.2363 - binary_accuracy: 0.9154
# Epoch 36: val_binary_accuracy did not improve from 0.91304
# 1762/1762 [==============================] - 15s 9ms/step - loss: 0.2363 - binary_accuracy: 0.9154 - val_loss: 0.2611 - val_binary_accuracy: 0.9036
# Epoch 37/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.2378 - binary_accuracy: 0.9150
# Epoch 37: val_binary_accuracy did not improve from 0.91304
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.2379 - binary_accuracy: 0.9150 - val_loss: 0.2598 - val_binary_accuracy: 0.9019
# Epoch 38/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.2358 - binary_accuracy: 0.9152
# Epoch 38: val_binary_accuracy did not improve from 0.91304
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.2358 - binary_accuracy: 0.9152 - val_loss: 0.2442 - val_binary_accuracy: 0.9092
# Epoch 39/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.2367 - binary_accuracy: 0.9150
# Epoch 39: val_binary_accuracy did not improve from 0.91304
# 1762/1762 [==============================] - 18s 10ms/step - loss: 0.2367 - binary_accuracy: 0.9150 - val_loss: 0.2503 - val_binary_accuracy: 0.9049
# Epoch 40/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.2373 - binary_accuracy: 0.9154
# Epoch 40: val_binary_accuracy did not improve from 0.91304
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.2373 - binary_accuracy: 0.9154 - val_loss: 0.2326 - val_binary_accuracy: 0.9128
# Epoch 41/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.2353 - binary_accuracy: 0.9158
# Epoch 41: val_binary_accuracy did not improve from 0.91304
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.2353 - binary_accuracy: 0.9158 - val_loss: 0.2753 - val_binary_accuracy: 0.8963
# 28/28 [==============================] - 1s 17ms/step - loss: 0.2351 - binary_accuracy: 0.9133
# Loss: 0.2351
# Accuracy: 91.33%
# <ipython-input-6-6a9234017a7b>:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parameters_to_save = parameters_to_save.append({'LSTM_blocks' : LSTM_blocks, 'learning_rate': lr, 'regularizer': regularizer, 'droput': dropout,

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2,1, figsize = (15,15))
axs = axs.flatten()
axs[0].plot(history.history['binary_accuracy'])
axs[0].plot(history.history['val_binary_accuracy'])
axs[0].set_title('model accuracy')

axs[0].legend(['train', 'val'], loc='upper left')

# summarize history for loss
axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('model loss')

axs[1].legend(['train', 'val'], loc='upper left')

# %%
import keras.backend as K
def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

def recall(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision
