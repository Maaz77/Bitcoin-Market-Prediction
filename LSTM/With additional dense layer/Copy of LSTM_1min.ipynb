# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle as pkl
import numpy as np
import pandas as pd 


with open('/content/drive/MyDrive/Dataset_with_memory /1min/X_train.pickle', 'rb') as f:
    X_train = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /1min/Y_train.pickle', 'rb') as f:
    Y_train = pkl.load(f)


with open('/content/drive/MyDrive/Dataset_with_memory /1min/Y_val.pickle', 'rb') as f:
    Y_val = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /1min/X_val.pickle', 'rb') as f:
     X_val = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /1min/Y_test.pickle', 'rb') as f:
    Y_test = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /1min/X_test.pickle', 'rb') as f:
     X_test = pkl.load(f)


Y_train = Y_train.reshape((-1,1))
Y_val = Y_val.reshape((-1,1))
Y_test = Y_test.reshape((-1,1))

X_train.shape , Y_train.shape , X_val.shape , Y_val.shape , X_test.shape , Y_test.shape
# Out:
# ((225480, 120, 5),
#  (225480, 1),
#  (45000, 120, 5),
#  (45000, 1),
#  (135240, 120, 5),
#  (135240, 1))

# %%
from sklearn.utils.class_weight import compute_class_weight



class_weights = compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique ( np.reshape( Y_train , (np.shape(Y_train)[0]))),
                                        y = np.reshape(Y_train ,(np.shape(Y_train)[0]))                                                 
                                    )
class_weights = dict(zip(np.unique(np.reshape(Y_train ,(np.shape(Y_train)[0]))), class_weights))
class_weights
# Out:
# {0: 1.173189589685422, 1: 0.8713664082607452}

# %%
import os

filepath = "/content/drive/MyDrive/parameter_tuning_LSTM_1min.csv"

# check if the file exists, create it if not
if not os.path.isfile(filepath):
    columns_name = ['LSTM_blocks', 'learning_rate', 'regularizer', 'droput', 'optimizer', 'batch size' ,
                    'train_loss' , 'val_loss' , 'train_accuracy' , 'val_accuracy', 'test_loss' , 'test_accuracy']
    df = pd.DataFrame(columns=columns_name)  # create an empty dataframe
    df.to_csv(filepath, index=False)  # save as a CSV file with no index

# %%
import tensorflow
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, BatchNormalization
from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import load_model
from tensorflow.keras import regularizers
from tensorflow import keras
import numpy as np 

#reproducibility 
np.random.seed(0)
tensorflow.random.set_seed(0)

#defining hyperparameters

LSTM_blocks = 20
regularizer = 0
lr = 0.0005  
dropout  = 0.5
batchsize = 128
optimizer_func = 'Adam'

# Define the model
def create_model(LSTM_blocks, regularizer, dropout):
    model = Sequential()
    #model.add(BatchNormalization(input_shape=(120, 5)))
    model.add(LSTM(LSTM_blocks, input_shape=(120, 5) , return_sequences=False , activation='tanh', bias_regularizer=regularizers.l1(regularizer),  kernel_regularizer=regularizers.l1(regularizer)))
    model.add(Dropout(dropout))
    model.add(Dense(50, activation='relu'))
    model.add(Dense(1, activation='sigmoid'))

    model.summary()
    return model 


model = create_model(LSTM_blocks, regularizer, dropout)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 20)                2080
#
#  dropout (Dropout)           (None, 20)                0
#
#  dense (Dense)               (None, 50)                1050
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 3,181
# Trainable params: 3,181
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
optimizer = keras.optimizers.Adam(learning_rate=lr,weight_decay=1e-7) if optimizer_func == 'Adam' else keras.optimizers.SGD(learning_rate=lr ,weight_decay=1e-7)

model.compile(loss='binary_crossentropy', optimizer= optimizer, metrics=['binary_accuracy' ])


checkpoint_path = '/content/drive/MyDrive/my_best_model_LSTM_1min.hdf5'

checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             monitor='val_binary_accuracy',
                             verbose=1, 
                             save_best_only=True,
                             mode='max')


earlystopping = EarlyStopping(monitor='val_binary_accuracy', patience=10, restore_best_weights=True)

callback = [earlystopping, checkpoint]
# Train the model
history = model.fit(X_train, Y_train, validation_data=(X_val , Y_val) , verbose=1,  batch_size=batchsize, epochs=150,callbacks = callback , class_weight=class_weights)

loss, accuracy = model.evaluate(X_test, Y_test, batch_size=batchsize)

print(f"Loss: {loss:.4f}")
print(f"Accuracy: {accuracy*100:.2f}%")

filepath = "/content/drive/MyDrive/parameter_tuning_LSTM_1min.csv"
parameters_to_save = pd.read_csv(filepath)

parameters_to_save = parameters_to_save.append({'LSTM_blocks' : LSTM_blocks, 'learning_rate': lr, 'regularizer': regularizer, 'droput': dropout, 
                                                'optimizer': optimizer_func, 'batch size': batchsize, 'train_loss' : history.history['loss'][-1] ,
                                                'val_loss' : history.history['val_loss'][-1] , 'train_accuracy' : history.history['binary_accuracy'][-1] , 
                                                'val_accuracy' : history.history['val_binary_accuracy'][-1],'test_loss' : f"{loss:.4f}" , 
                                                'test_accuracy' : f"{accuracy*100:.2f}%" } , ignore_index = True ) 

parameters_to_save.to_csv(filepath, index=False)
# Out:
# Epoch 1/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.6930 - binary_accuracy: 0.5135
# Epoch 1: val_binary_accuracy improved from -inf to 0.49451, saving model to /content/drive/MyDrive/my_best_model_LSTM_1min.hdf5
# 1762/1762 [==============================] - 29s 10ms/step - loss: 0.6930 - binary_accuracy: 0.5135 - val_loss: 0.6944 - val_binary_accuracy: 0.4945
# Epoch 2/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.6919 - binary_accuracy: 0.5321
# Epoch 2: val_binary_accuracy improved from 0.49451 to 0.49556, saving model to /content/drive/MyDrive/my_best_model_LSTM_1min.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6918 - binary_accuracy: 0.5321 - val_loss: 0.6953 - val_binary_accuracy: 0.4956
# Epoch 3/150
# 1756/1762 [============================>.] - ETA: 0s - loss: 0.6908 - binary_accuracy: 0.5427
# Epoch 3: val_binary_accuracy improved from 0.49556 to 0.50631, saving model to /content/drive/MyDrive/my_best_model_LSTM_1min.hdf5
# 1762/1762 [==============================] - 18s 10ms/step - loss: 0.6908 - binary_accuracy: 0.5426 - val_loss: 0.6943 - val_binary_accuracy: 0.5063
# Epoch 4/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.6901 - binary_accuracy: 0.5464
# Epoch 4: val_binary_accuracy improved from 0.50631 to 0.51193, saving model to /content/drive/MyDrive/my_best_model_LSTM_1min.hdf5
# 1762/1762 [==============================] - 18s 10ms/step - loss: 0.6901 - binary_accuracy: 0.5463 - val_loss: 0.6936 - val_binary_accuracy: 0.5119
# Epoch 5/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.6897 - binary_accuracy: 0.5469
# Epoch 5: val_binary_accuracy did not improve from 0.51193
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6897 - binary_accuracy: 0.5469 - val_loss: 0.6938 - val_binary_accuracy: 0.5118
# Epoch 6/150
# 1756/1762 [============================>.] - ETA: 0s - loss: 0.6890 - binary_accuracy: 0.5507
# Epoch 6: val_binary_accuracy improved from 0.51193 to 0.51293, saving model to /content/drive/MyDrive/my_best_model_LSTM_1min.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6890 - binary_accuracy: 0.5506 - val_loss: 0.6936 - val_binary_accuracy: 0.5129
# Epoch 7/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.6886 - binary_accuracy: 0.5522
# Epoch 7: val_binary_accuracy improved from 0.51293 to 0.51889, saving model to /content/drive/MyDrive/my_best_model_LSTM_1min.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6886 - binary_accuracy: 0.5522 - val_loss: 0.6926 - val_binary_accuracy: 0.5189
# Epoch 8/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.6884 - binary_accuracy: 0.5532
# Epoch 8: val_binary_accuracy improved from 0.51889 to 0.52080, saving model to /content/drive/MyDrive/my_best_model_LSTM_1min.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6884 - binary_accuracy: 0.5532 - val_loss: 0.6928 - val_binary_accuracy: 0.5208
# Epoch 9/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.6881 - binary_accuracy: 0.5552
# Epoch 9: val_binary_accuracy improved from 0.52080 to 0.52378, saving model to /content/drive/MyDrive/my_best_model_LSTM_1min.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6881 - binary_accuracy: 0.5552 - val_loss: 0.6917 - val_binary_accuracy: 0.5238
# Epoch 10/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.6879 - binary_accuracy: 0.5566
# Epoch 10: val_binary_accuracy improved from 0.52378 to 0.52411, saving model to /content/drive/MyDrive/my_best_model_LSTM_1min.hdf5
# 1762/1762 [==============================] - 18s 10ms/step - loss: 0.6879 - binary_accuracy: 0.5565 - val_loss: 0.6915 - val_binary_accuracy: 0.5241
# Epoch 11/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.6877 - binary_accuracy: 0.5563
# Epoch 11: val_binary_accuracy did not improve from 0.52411
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6877 - binary_accuracy: 0.5563 - val_loss: 0.6920 - val_binary_accuracy: 0.5230
# Epoch 12/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.6873 - binary_accuracy: 0.5572
# Epoch 12: val_binary_accuracy did not improve from 0.52411
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6873 - binary_accuracy: 0.5572 - val_loss: 0.6925 - val_binary_accuracy: 0.5232
# Epoch 13/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.6873 - binary_accuracy: 0.5597
# Epoch 13: val_binary_accuracy did not improve from 0.52411
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6873 - binary_accuracy: 0.5596 - val_loss: 0.6929 - val_binary_accuracy: 0.5180
# Epoch 14/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.6871 - binary_accuracy: 0.5597
# Epoch 14: val_binary_accuracy improved from 0.52411 to 0.52551, saving model to /content/drive/MyDrive/my_best_model_LSTM_1min.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6871 - binary_accuracy: 0.5597 - val_loss: 0.6920 - val_binary_accuracy: 0.5255
# Epoch 15/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.6868 - binary_accuracy: 0.5585
# Epoch 15: val_binary_accuracy improved from 0.52551 to 0.52891, saving model to /content/drive/MyDrive/my_best_model_LSTM_1min.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6869 - binary_accuracy: 0.5585 - val_loss: 0.6919 - val_binary_accuracy: 0.5289
# Epoch 16/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.6865 - binary_accuracy: 0.5603
# Epoch 16: val_binary_accuracy did not improve from 0.52891
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6865 - binary_accuracy: 0.5603 - val_loss: 0.6912 - val_binary_accuracy: 0.5277
# Epoch 17/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.6864 - binary_accuracy: 0.5584
# Epoch 17: val_binary_accuracy did not improve from 0.52891
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6864 - binary_accuracy: 0.5584 - val_loss: 0.6925 - val_binary_accuracy: 0.5266
# Epoch 18/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.6865 - binary_accuracy: 0.5608
# Epoch 18: val_binary_accuracy improved from 0.52891 to 0.52998, saving model to /content/drive/MyDrive/my_best_model_LSTM_1min.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6865 - binary_accuracy: 0.5609 - val_loss: 0.6911 - val_binary_accuracy: 0.5300
# Epoch 19/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.6863 - binary_accuracy: 0.5579
# Epoch 19: val_binary_accuracy did not improve from 0.52998
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6863 - binary_accuracy: 0.5578 - val_loss: 0.6913 - val_binary_accuracy: 0.5288
# Epoch 20/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.6860 - binary_accuracy: 0.5605
# Epoch 20: val_binary_accuracy did not improve from 0.52998
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6860 - binary_accuracy: 0.5605 - val_loss: 0.6915 - val_binary_accuracy: 0.5281
# Epoch 21/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.6860 - binary_accuracy: 0.5599
# Epoch 21: val_binary_accuracy did not improve from 0.52998
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6861 - binary_accuracy: 0.5599 - val_loss: 0.6921 - val_binary_accuracy: 0.5241
# Epoch 22/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.6863 - binary_accuracy: 0.5598
# Epoch 22: val_binary_accuracy did not improve from 0.52998
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6863 - binary_accuracy: 0.5598 - val_loss: 0.6920 - val_binary_accuracy: 0.5265
# Epoch 23/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.6858 - binary_accuracy: 0.5592
# Epoch 23: val_binary_accuracy did not improve from 0.52998
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6859 - binary_accuracy: 0.5592 - val_loss: 0.6928 - val_binary_accuracy: 0.5261
# Epoch 24/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.6857 - binary_accuracy: 0.5605
# Epoch 24: val_binary_accuracy improved from 0.52998 to 0.53420, saving model to /content/drive/MyDrive/my_best_model_LSTM_1min.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6857 - binary_accuracy: 0.5604 - val_loss: 0.6908 - val_binary_accuracy: 0.5342
# Epoch 25/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.6857 - binary_accuracy: 0.5603
# Epoch 25: val_binary_accuracy did not improve from 0.53420
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6857 - binary_accuracy: 0.5603 - val_loss: 0.6916 - val_binary_accuracy: 0.5316
# Epoch 26/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.6857 - binary_accuracy: 0.5609
# Epoch 26: val_binary_accuracy did not improve from 0.53420
# 1762/1762 [==============================] - 15s 9ms/step - loss: 0.6857 - binary_accuracy: 0.5609 - val_loss: 0.6914 - val_binary_accuracy: 0.5314
# Epoch 27/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.6856 - binary_accuracy: 0.5604
# Epoch 27: val_binary_accuracy did not improve from 0.53420
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6856 - binary_accuracy: 0.5604 - val_loss: 0.6916 - val_binary_accuracy: 0.5312
# Epoch 28/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.6858 - binary_accuracy: 0.5589
# Epoch 28: val_binary_accuracy did not improve from 0.53420
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6858 - binary_accuracy: 0.5589 - val_loss: 0.6910 - val_binary_accuracy: 0.5341
# Epoch 29/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.6857 - binary_accuracy: 0.5590
# Epoch 29: val_binary_accuracy did not improve from 0.53420
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.6857 - binary_accuracy: 0.5590 - val_loss: 0.6912 - val_binary_accuracy: 0.5316
# Epoch 30/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.6856 - binary_accuracy: 0.5593
# Epoch 30: val_binary_accuracy improved from 0.53420 to 0.53427, saving model to /content/drive/MyDrive/my_best_model_LSTM_1min.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6856 - binary_accuracy: 0.5593 - val_loss: 0.6912 - val_binary_accuracy: 0.5343
# Epoch 31/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.6855 - binary_accuracy: 0.5605
# Epoch 31: val_binary_accuracy did not improve from 0.53427
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6855 - binary_accuracy: 0.5605 - val_loss: 0.6911 - val_binary_accuracy: 0.5327
# Epoch 32/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.6853 - binary_accuracy: 0.5607
# Epoch 32: val_binary_accuracy did not improve from 0.53427
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6853 - binary_accuracy: 0.5608 - val_loss: 0.6918 - val_binary_accuracy: 0.5273
# Epoch 33/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.6852 - binary_accuracy: 0.5598
# Epoch 33: val_binary_accuracy did not improve from 0.53427
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6853 - binary_accuracy: 0.5598 - val_loss: 0.6940 - val_binary_accuracy: 0.5214
# Epoch 34/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.6853 - binary_accuracy: 0.5602
# Epoch 34: val_binary_accuracy did not improve from 0.53427
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.6853 - binary_accuracy: 0.5602 - val_loss: 0.6922 - val_binary_accuracy: 0.5222
# Epoch 35/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.6854 - binary_accuracy: 0.5602
# Epoch 35: val_binary_accuracy improved from 0.53427 to 0.53496, saving model to /content/drive/MyDrive/my_best_model_LSTM_1min.hdf5
# 1762/1762 [==============================] - 17s 9ms/step - loss: 0.6854 - binary_accuracy: 0.5602 - val_loss: 0.6907 - val_binary_accuracy: 0.5350
# Epoch 36/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.6852 - binary_accuracy: 0.5598
# Epoch 36: val_binary_accuracy did not improve from 0.53496
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6852 - binary_accuracy: 0.5598 - val_loss: 0.6928 - val_binary_accuracy: 0.5236
# Epoch 37/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.6852 - binary_accuracy: 0.5605
# Epoch 37: val_binary_accuracy did not improve from 0.53496
# 1762/1762 [==============================] - 15s 9ms/step - loss: 0.6852 - binary_accuracy: 0.5605 - val_loss: 0.6924 - val_binary_accuracy: 0.5231
# Epoch 38/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.6849 - binary_accuracy: 0.5609
# Epoch 38: val_binary_accuracy did not improve from 0.53496
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6849 - binary_accuracy: 0.5609 - val_loss: 0.6920 - val_binary_accuracy: 0.5306
# Epoch 39/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.6850 - binary_accuracy: 0.5605
# Epoch 39: val_binary_accuracy did not improve from 0.53496
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6850 - binary_accuracy: 0.5604 - val_loss: 0.6917 - val_binary_accuracy: 0.5295
# Epoch 40/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.6851 - binary_accuracy: 0.5611
# Epoch 40: val_binary_accuracy did not improve from 0.53496
# 1762/1762 [==============================] - 17s 9ms/step - loss: 0.6851 - binary_accuracy: 0.5610 - val_loss: 0.6916 - val_binary_accuracy: 0.5319
# Epoch 41/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.6849 - binary_accuracy: 0.5607
# Epoch 41: val_binary_accuracy did not improve from 0.53496
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.6849 - binary_accuracy: 0.5607 - val_loss: 0.6916 - val_binary_accuracy: 0.5322
# Epoch 42/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.6848 - binary_accuracy: 0.5618
# Epoch 42: val_binary_accuracy did not improve from 0.53496
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6848 - binary_accuracy: 0.5619 - val_loss: 0.6922 - val_binary_accuracy: 0.5255
# Epoch 43/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.6848 - binary_accuracy: 0.5626
# Epoch 43: val_binary_accuracy improved from 0.53496 to 0.53502, saving model to /content/drive/MyDrive/my_best_model_LSTM_1min.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6848 - binary_accuracy: 0.5626 - val_loss: 0.6913 - val_binary_accuracy: 0.5350
# Epoch 44/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.6848 - binary_accuracy: 0.5608
# Epoch 44: val_binary_accuracy did not improve from 0.53502
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6848 - binary_accuracy: 0.5607 - val_loss: 0.6911 - val_binary_accuracy: 0.5309
# Epoch 45/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.6848 - binary_accuracy: 0.5609
# Epoch 45: val_binary_accuracy did not improve from 0.53502
# 1762/1762 [==============================] - 15s 9ms/step - loss: 0.6848 - binary_accuracy: 0.5609 - val_loss: 0.6925 - val_binary_accuracy: 0.5286
# Epoch 46/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.6848 - binary_accuracy: 0.5612
# Epoch 46: val_binary_accuracy did not improve from 0.53502
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.6848 - binary_accuracy: 0.5612 - val_loss: 0.6923 - val_binary_accuracy: 0.5290
# Epoch 47/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.6847 - binary_accuracy: 0.5608
# Epoch 47: val_binary_accuracy did not improve from 0.53502
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6847 - binary_accuracy: 0.5607 - val_loss: 0.6928 - val_binary_accuracy: 0.5231
# Epoch 48/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.6845 - binary_accuracy: 0.5607
# Epoch 48: val_binary_accuracy did not improve from 0.53502
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6845 - binary_accuracy: 0.5607 - val_loss: 0.6929 - val_binary_accuracy: 0.5291
# Epoch 49/150
# 1756/1762 [============================>.] - ETA: 0s - loss: 0.6847 - binary_accuracy: 0.5614
# Epoch 49: val_binary_accuracy did not improve from 0.53502
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6847 - binary_accuracy: 0.5613 - val_loss: 0.6917 - val_binary_accuracy: 0.5338
# Epoch 50/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.6847 - binary_accuracy: 0.5625
# Epoch 50: val_binary_accuracy did not improve from 0.53502
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6847 - binary_accuracy: 0.5625 - val_loss: 0.6920 - val_binary_accuracy: 0.5297
# Epoch 51/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.6845 - binary_accuracy: 0.5621
# Epoch 51: val_binary_accuracy did not improve from 0.53502
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6845 - binary_accuracy: 0.5621 - val_loss: 0.6913 - val_binary_accuracy: 0.5342
# Epoch 52/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.6847 - binary_accuracy: 0.5611
# Epoch 52: val_binary_accuracy did not improve from 0.53502
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.6846 - binary_accuracy: 0.5612 - val_loss: 0.6924 - val_binary_accuracy: 0.5343
# Epoch 53/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.6845 - binary_accuracy: 0.5611
# Epoch 53: val_binary_accuracy did not improve from 0.53502
# 1762/1762 [==============================] - 18s 10ms/step - loss: 0.6845 - binary_accuracy: 0.5611 - val_loss: 0.6917 - val_binary_accuracy: 0.5342
# 1057/1057 [==============================] - 6s 5ms/step - loss: 0.6938 - binary_accuracy: 0.5259
# Loss: 0.6938
# Accuracy: 52.59%
# <ipython-input-6-628745946f08>:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parameters_to_save = parameters_to_save.append({'LSTM_blocks' : LSTM_blocks, 'learning_rate': lr, 'regularizer': regularizer, 'droput': dropout,

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2,1, figsize = (15,15))
axs = axs.flatten()
axs[0].plot(history.history['binary_accuracy'])
axs[0].plot(history.history['val_binary_accuracy'])
axs[0].set_title('model accuracy')

axs[0].legend(['train', 'val'], loc='upper left')

# summarize history for loss
axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('model loss')

axs[1].legend(['train', 'val'], loc='upper left')

# %%
import numpy as np

# Define the standard deviation of the random noise
noise_std = 100

# Add random noise to the data
X_train_noisy = X_train + np.random.normal(loc=0.0, scale=noise_std, size=X_train.shape)

# Clip the noisy data to ensure that it stays within the same range as the original data
X_train_noisy = np.clip(X_train_noisy, a_min=np.min(X_train), a_max=np.max(X_train))

# %%
import numpy as np
from scipy.fftpack import fft, ifft

# Define the number of samples to generate using Fourier Transform
n_samples = 1000

# Reshape the input data to have shape (N * T, D)
X_train_reshape = np.reshape(X_train, (-1, X_train.shape[-1]))

# Compute the FFT of the input data
X_train_fft = fft(X_train_reshape)

# Generate random samples from the FFT
X_train_fft_samples = np.random.normal(loc=0.0, scale=1.0, size=(n_samples, X_train_fft.shape[1])) + \
                      1j * np.random.normal(loc=0.0, scale=1.0, size=(n_samples, X_train_fft.shape[1]))
                      
# Rescale the samples to have the same variance as the original FFT
X_train_fft_samples = X_train_fft_samples * np.sqrt(np.var(X_train_fft)) / np.sqrt(np.var(X_train_fft_samples))

# Compute the inverse FFT of the samples
X_train_samples = ifft(X_train_fft_samples)

# Reshape the generated samples back to the original shape of the input data
X_train_samples = np.reshape(X_train_samples, (int(5000/600) +1 ,  X_train.shape[1], X_train.shape[2]))

# Stack the generated samples with the original data to obtain the augmented dataset
X_train_augmented = np.concatenate((X_train, X_train_samples), axis=0)

# %%
import numpy as np
from statsmodels.tsa.ar_model import AutoReg

# Define the lag order for the autoregressive model
lag_order = 10

# Load the time series dataset
data = np.reshape(X_train, (-1, X_train.shape[-1])).flatten()
print (data.shape)
# Split the dataset into training and test sets
train_data = data[:1000]
test_data = data[1000:]

# Fit the autoregressive model to the training data
model = AutoReg(train_data, lags=lag_order)
model_fit = model.fit()

# Generate new data using the fitted model
n_samples = 100
new_data = model_fit.predict(start=len(train_data), end=len(train_data)+n_samples-1)

# Print the generated data
dim1 = int(new_data.shape[0] / (X_train.shape[1] * X_train.shape[2]))
new_data = new_data[:dim1]
np.reshape(data , (dim1 , X_train.shape[1] , X_train.shape[2]))

# %%
import numpy as np

# create a function to flip the time series data along its temporal axis
def flip_data(x):
    return np.flip(x, axis=1)

# extract the indices of samples in Y_train that have a value of 1
flip_indices = np.where(Y_train == 1)[0]

# flip the corresponding samples in X_train using boolean indexing
flipped_X_train = flip_data(X_train[flip_indices])

# append the flipped data to X_train and Y_train
X_augmented = np.concatenate([X_train, flipped_X_train], axis=0)
Y_augmented = np.concatenate([Y_train, np.ones((len(flip_indices) , 1))], axis=0)

# shuffle the augmented data
indices = np.arange(X_augmented.shape[0])
np.random.shuffle(indices)
X_augmented = X_augmented[indices]
Y_augmented = Y_augmented[indices]

# %%
import keras.backend as K
def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

def recall(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision
