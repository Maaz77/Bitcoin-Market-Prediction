# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle as pkl
import numpy as np
import pandas as pd 


with open('/content/drive/MyDrive/Dataset_with_memory /60min/X_train_60min.pickle', 'rb') as f:
    X_train = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /60min/Y_train_60min.pickle', 'rb') as f:
    Y_train = pkl.load(f)


with open('/content/drive/MyDrive/Dataset_with_memory /60min/Y_val_60min.pickle', 'rb') as f:
    Y_val = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /60min/X_val_60min.pickle', 'rb') as f:
     X_val = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /60min/Y_test_60min.pickle', 'rb') as f:
    Y_test = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /60min/X_test_60min.pickle', 'rb') as f:
     X_test = pkl.load(f)


Y_train = Y_train.reshape((-1,1))
Y_val = Y_val.reshape((-1,1))
Y_test = Y_test.reshape((-1,1))

X_train.shape , Y_train.shape , X_val.shape , Y_val.shape , X_test.shape , Y_test.shape
# Out:
# ((225480, 120, 5),
#  (225480, 1),
#  (45000, 120, 5),
#  (45000, 1),
#  (135240, 120, 5),
#  (135240, 1))

# %%
from sklearn.utils.class_weight import compute_class_weight



class_weights = compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique ( np.reshape( Y_train , (np.shape(Y_train)[0]))),
                                        y = np.reshape(Y_train ,(np.shape(Y_train)[0]))                                                 
                                    )
class_weights = dict(zip(np.unique(np.reshape(Y_train ,(np.shape(Y_train)[0]))), class_weights))
class_weights
# Out:
# {0: 1.0305961076120045, 1: 0.9711681755924436}

# %%
import os

filepath = "/content/drive/MyDrive/parameter_tuning_LSTM_60min.csv"

# check if the file exists, create it if not
if not os.path.isfile(filepath):
    columns_name = ['LSTM_blocks', 'learning_rate', 'regularizer', 'droput', 'optimizer', 'batch size' ,
                    'train_loss' , 'val_loss' , 'train_accuracy' , 'val_accuracy', 'test_loss' , 'test_accuracy']
    df = pd.DataFrame(columns=columns_name)  # create an empty dataframe
    df.to_csv(filepath, index=False)  # save as a CSV file with no index

# %%
import tensorflow
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, BatchNormalization
from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import load_model
from tensorflow.keras import regularizers
from tensorflow import keras
import numpy as np 

#reproducibility 
np.random.seed(0)
tensorflow.random.set_seed(0)

#defining hyperparameters

LSTM_blocks = 20
regularizer = 0.3
lr = 0.0005  #I think best one is 0.0001
dropout  = 0.5
batchsize = 128
optimizer_func = 'Adam'

# Define the model
def create_model(LSTM_blocks, regularizer, dropout):
    model = Sequential()
    #model.add(BatchNormalization(input_shape=(120, 5)))
    model.add(LSTM(LSTM_blocks, input_shape=(120, 5) , return_sequences=False , activation='tanh', bias_regularizer=regularizers.l1(regularizer),  kernel_regularizer=regularizers.l1(regularizer)))
    model.add(Dropout(dropout))
    model.add(Dense(1, activation='sigmoid'))

    model.summary()
    return model 


model = create_model(LSTM_blocks, regularizer, dropout)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 20)                2080
#
#  dropout_3 (Dropout)         (None, 20)                0
#
#  dense_3 (Dense)             (None, 1)                 21
#
# =================================================================
# Total params: 2,101
# Trainable params: 2,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
optimizer = keras.optimizers.Adam(learning_rate=lr,weight_decay=1e-7) if optimizer_func == 'Adam' else keras.optimizers.SGD(learning_rate=lr ,weight_decay=1e-7)

model.compile(loss='binary_crossentropy', optimizer= optimizer, metrics=['binary_accuracy' ])


checkpoint_path = '/content/drive/MyDrive/my_best_model_LSTM_60min.hdf5'

checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             monitor='val_binary_accuracy',
                             verbose=1, 
                             save_best_only=True,
                             mode='max')


earlystopping = EarlyStopping(monitor='val_binary_accuracy', patience=10, restore_best_weights=True)

callback = [earlystopping, checkpoint]
# Train the model
history = model.fit(X_train, Y_train, validation_data=(X_val , Y_val) , verbose=1,  batch_size=batchsize, epochs=150,callbacks = callback , class_weight=class_weights)

loss, accuracy = model.evaluate(X_test, Y_test, batch_size=5000)

print(f"Loss: {loss:.4f}")
print(f"Accuracy: {accuracy*100:.2f}%")

filepath = "/content/drive/MyDrive/parameter_tuning_LSTM_60min.csv"
parameters_to_save = pd.read_csv(filepath)

parameters_to_save = parameters_to_save.append({'LSTM_blocks' : LSTM_blocks, 'learning_rate': lr, 'regularizer': regularizer, 'droput': dropout, 
                                                'optimizer': optimizer_func, 'batch size': batchsize, 'train_loss' : history.history['loss'][-1] ,
                                                'val_loss' : history.history['val_loss'][-1] , 'train_accuracy' : history.history['binary_accuracy'][-1] , 
                                                'val_accuracy' : history.history['val_binary_accuracy'][-1],'test_loss' : f"{loss:.4f}" , 
                                                'test_accuracy' : f"{accuracy*100:.2f}%" } , ignore_index = True ) 

parameters_to_save.to_csv(filepath, index=False)
# Out:
# Epoch 1/150
# 1762/1762 [==============================] - ETA: 0s - loss: 5.6009 - binary_accuracy: 0.7779
# Epoch 1: val_binary_accuracy improved from -inf to 0.79222, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 21s 11ms/step - loss: 5.6009 - binary_accuracy: 0.7779 - val_loss: 1.2254 - val_binary_accuracy: 0.7922
# Epoch 2/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.5247 - binary_accuracy: 0.8161
# Epoch 2: val_binary_accuracy improved from 0.79222 to 0.82149, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.5246 - binary_accuracy: 0.8162 - val_loss: 0.4457 - val_binary_accuracy: 0.8215
# Epoch 3/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.4259 - binary_accuracy: 0.8444
# Epoch 3: val_binary_accuracy improved from 0.82149 to 0.83613, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.4259 - binary_accuracy: 0.8444 - val_loss: 0.4133 - val_binary_accuracy: 0.8361
# Epoch 4/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.3958 - binary_accuracy: 0.8585
# Epoch 4: val_binary_accuracy improved from 0.83613 to 0.84951, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.3959 - binary_accuracy: 0.8585 - val_loss: 0.3885 - val_binary_accuracy: 0.8495
# Epoch 5/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.3754 - binary_accuracy: 0.8662
# Epoch 5: val_binary_accuracy improved from 0.84951 to 0.85091, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 19s 11ms/step - loss: 0.3754 - binary_accuracy: 0.8662 - val_loss: 0.3748 - val_binary_accuracy: 0.8509
# Epoch 6/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.3618 - binary_accuracy: 0.8713
# Epoch 6: val_binary_accuracy improved from 0.85091 to 0.85564, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.3618 - binary_accuracy: 0.8713 - val_loss: 0.3613 - val_binary_accuracy: 0.8556
# Epoch 7/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.3508 - binary_accuracy: 0.8750
# Epoch 7: val_binary_accuracy improved from 0.85564 to 0.86242, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.3508 - binary_accuracy: 0.8750 - val_loss: 0.3513 - val_binary_accuracy: 0.8624
# Epoch 8/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.3422 - binary_accuracy: 0.8785
# Epoch 8: val_binary_accuracy improved from 0.86242 to 0.86513, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.3422 - binary_accuracy: 0.8785 - val_loss: 0.3452 - val_binary_accuracy: 0.8651
# Epoch 9/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.3350 - binary_accuracy: 0.8812
# Epoch 9: val_binary_accuracy did not improve from 0.86513
# 1762/1762 [==============================] - 18s 10ms/step - loss: 0.3350 - binary_accuracy: 0.8812 - val_loss: 0.3432 - val_binary_accuracy: 0.8638
# Epoch 10/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.3285 - binary_accuracy: 0.8831
# Epoch 10: val_binary_accuracy improved from 0.86513 to 0.87167, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 17s 9ms/step - loss: 0.3286 - binary_accuracy: 0.8831 - val_loss: 0.3325 - val_binary_accuracy: 0.8717
# Epoch 11/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.3241 - binary_accuracy: 0.8850
# Epoch 11: val_binary_accuracy did not improve from 0.87167
# 1762/1762 [==============================] - 17s 9ms/step - loss: 0.3241 - binary_accuracy: 0.8850 - val_loss: 0.3381 - val_binary_accuracy: 0.8662
# Epoch 12/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.3203 - binary_accuracy: 0.8872
# Epoch 12: val_binary_accuracy did not improve from 0.87167
# 1762/1762 [==============================] - 18s 10ms/step - loss: 0.3204 - binary_accuracy: 0.8873 - val_loss: 0.3293 - val_binary_accuracy: 0.8702
# Epoch 13/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.3150 - binary_accuracy: 0.8880
# Epoch 13: val_binary_accuracy improved from 0.87167 to 0.87267, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 19s 11ms/step - loss: 0.3152 - binary_accuracy: 0.8879 - val_loss: 0.3241 - val_binary_accuracy: 0.8727
# Epoch 14/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.3089 - binary_accuracy: 0.8900
# Epoch 14: val_binary_accuracy improved from 0.87267 to 0.87889, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.3089 - binary_accuracy: 0.8900 - val_loss: 0.3119 - val_binary_accuracy: 0.8789
# Epoch 15/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.3023 - binary_accuracy: 0.8914
# Epoch 15: val_binary_accuracy improved from 0.87889 to 0.88449, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.3023 - binary_accuracy: 0.8914 - val_loss: 0.3052 - val_binary_accuracy: 0.8845
# Epoch 16/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.2979 - binary_accuracy: 0.8931
# Epoch 16: val_binary_accuracy did not improve from 0.88449
# 1762/1762 [==============================] - 18s 10ms/step - loss: 0.2978 - binary_accuracy: 0.8931 - val_loss: 0.3089 - val_binary_accuracy: 0.8801
# Epoch 17/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.2928 - binary_accuracy: 0.8951
# Epoch 17: val_binary_accuracy did not improve from 0.88449
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.2927 - binary_accuracy: 0.8952 - val_loss: 0.3057 - val_binary_accuracy: 0.8788
# Epoch 18/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.2883 - binary_accuracy: 0.8970
# Epoch 18: val_binary_accuracy improved from 0.88449 to 0.88513, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.2883 - binary_accuracy: 0.8970 - val_loss: 0.2977 - val_binary_accuracy: 0.8851
# Epoch 19/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.2840 - binary_accuracy: 0.8985
# Epoch 19: val_binary_accuracy improved from 0.88513 to 0.88549, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.2840 - binary_accuracy: 0.8985 - val_loss: 0.2950 - val_binary_accuracy: 0.8855
# Epoch 20/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.2812 - binary_accuracy: 0.9004
# Epoch 20: val_binary_accuracy improved from 0.88549 to 0.88607, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 18s 10ms/step - loss: 0.2812 - binary_accuracy: 0.9004 - val_loss: 0.2932 - val_binary_accuracy: 0.8861
# Epoch 21/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.2789 - binary_accuracy: 0.9002
# Epoch 21: val_binary_accuracy improved from 0.88607 to 0.88964, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.2790 - binary_accuracy: 0.9002 - val_loss: 0.2876 - val_binary_accuracy: 0.8896
# Epoch 22/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.2769 - binary_accuracy: 0.9009
# Epoch 22: val_binary_accuracy did not improve from 0.88964
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.2769 - binary_accuracy: 0.9009 - val_loss: 0.3016 - val_binary_accuracy: 0.8820
# Epoch 23/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.2759 - binary_accuracy: 0.9014
# Epoch 23: val_binary_accuracy improved from 0.88964 to 0.89173, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.2759 - binary_accuracy: 0.9014 - val_loss: 0.2796 - val_binary_accuracy: 0.8917
# Epoch 24/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.2749 - binary_accuracy: 0.9012
# Epoch 24: val_binary_accuracy did not improve from 0.89173
# 1762/1762 [==============================] - 18s 10ms/step - loss: 0.2750 - binary_accuracy: 0.9012 - val_loss: 0.2869 - val_binary_accuracy: 0.8886
# Epoch 25/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.2730 - binary_accuracy: 0.9016
# Epoch 25: val_binary_accuracy did not improve from 0.89173
# 1762/1762 [==============================] - 18s 10ms/step - loss: 0.2730 - binary_accuracy: 0.9016 - val_loss: 0.2984 - val_binary_accuracy: 0.8859
# Epoch 26/150
# 1756/1762 [============================>.] - ETA: 0s - loss: 0.2736 - binary_accuracy: 0.9021
# Epoch 26: val_binary_accuracy improved from 0.89173 to 0.89440, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.2737 - binary_accuracy: 0.9021 - val_loss: 0.2752 - val_binary_accuracy: 0.8944
# Epoch 27/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.2687 - binary_accuracy: 0.9027
# Epoch 27: val_binary_accuracy did not improve from 0.89440
# 1762/1762 [==============================] - 17s 9ms/step - loss: 0.2687 - binary_accuracy: 0.9028 - val_loss: 0.2819 - val_binary_accuracy: 0.8907
# Epoch 28/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.2668 - binary_accuracy: 0.9028
# Epoch 28: val_binary_accuracy did not improve from 0.89440
# 1762/1762 [==============================] - 19s 11ms/step - loss: 0.2668 - binary_accuracy: 0.9028 - val_loss: 0.2789 - val_binary_accuracy: 0.8923
# Epoch 29/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.2669 - binary_accuracy: 0.9027
# Epoch 29: val_binary_accuracy did not improve from 0.89440
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.2669 - binary_accuracy: 0.9027 - val_loss: 0.2812 - val_binary_accuracy: 0.8918
# Epoch 30/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.2655 - binary_accuracy: 0.9036
# Epoch 30: val_binary_accuracy improved from 0.89440 to 0.89856, saving model to /content/drive/MyDrive/my_best_model_LSTM_60min.hdf5
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.2656 - binary_accuracy: 0.9036 - val_loss: 0.2689 - val_binary_accuracy: 0.8986
# Epoch 31/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.2645 - binary_accuracy: 0.9036
# Epoch 31: val_binary_accuracy did not improve from 0.89856
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.2645 - binary_accuracy: 0.9036 - val_loss: 0.2751 - val_binary_accuracy: 0.8927
# Epoch 32/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.4488 - binary_accuracy: 0.8836
# Epoch 32: val_binary_accuracy did not improve from 0.89856
# 1762/1762 [==============================] - 18s 10ms/step - loss: 0.4484 - binary_accuracy: 0.8836 - val_loss: 0.2898 - val_binary_accuracy: 0.8874
# Epoch 33/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.4438 - binary_accuracy: 0.8623
# Epoch 33: val_binary_accuracy did not improve from 0.89856
# 1762/1762 [==============================] - 17s 9ms/step - loss: 0.4436 - binary_accuracy: 0.8623 - val_loss: 0.2853 - val_binary_accuracy: 0.8951
# Epoch 34/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.2763 - binary_accuracy: 0.9062
# Epoch 34: val_binary_accuracy did not improve from 0.89856
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.2763 - binary_accuracy: 0.9062 - val_loss: 0.2893 - val_binary_accuracy: 0.8862
# Epoch 35/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.2697 - binary_accuracy: 0.9050
# Epoch 35: val_binary_accuracy did not improve from 0.89856
# 1762/1762 [==============================] - 18s 10ms/step - loss: 0.2696 - binary_accuracy: 0.9051 - val_loss: 0.2878 - val_binary_accuracy: 0.8884
# Epoch 36/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.3281 - binary_accuracy: 0.8990
# Epoch 36: val_binary_accuracy did not improve from 0.89856
# 1762/1762 [==============================] - 18s 10ms/step - loss: 0.3280 - binary_accuracy: 0.8990 - val_loss: 0.3129 - val_binary_accuracy: 0.8900
# Epoch 37/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.2646 - binary_accuracy: 0.9060
# Epoch 37: val_binary_accuracy did not improve from 0.89856
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.2646 - binary_accuracy: 0.9061 - val_loss: 0.2794 - val_binary_accuracy: 0.8900
# Epoch 38/150
# 1756/1762 [============================>.] - ETA: 0s - loss: 0.2600 - binary_accuracy: 0.9050
# Epoch 38: val_binary_accuracy did not improve from 0.89856
# 1762/1762 [==============================] - 18s 10ms/step - loss: 0.2600 - binary_accuracy: 0.9050 - val_loss: 0.2814 - val_binary_accuracy: 0.8909
# Epoch 39/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.3750 - binary_accuracy: 0.8902
# Epoch 39: val_binary_accuracy did not improve from 0.89856
# 1762/1762 [==============================] - 19s 11ms/step - loss: 0.3748 - binary_accuracy: 0.8903 - val_loss: 0.2890 - val_binary_accuracy: 0.8916
# Epoch 40/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.2659 - binary_accuracy: 0.9055
# Epoch 40: val_binary_accuracy did not improve from 0.89856
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.2659 - binary_accuracy: 0.9055 - val_loss: 0.2736 - val_binary_accuracy: 0.8931
# 28/28 [==============================] - 1s 20ms/step - loss: 0.2693 - binary_accuracy: 0.9005
# Loss: 0.2693
# Accuracy: 90.05%
# <ipython-input-14-6a9234017a7b>:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parameters_to_save = parameters_to_save.append({'LSTM_blocks' : LSTM_blocks, 'learning_rate': lr, 'regularizer': regularizer, 'droput': dropout,

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2,1, figsize = (15,15))
axs = axs.flatten()
axs[0].plot(history.history['binary_accuracy'])
axs[0].plot(history.history['val_binary_accuracy'])
axs[0].set_title('model accuracy')

axs[0].legend(['train', 'val'], loc='upper left')

# summarize history for loss
axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('model loss')

axs[1].legend(['train', 'val'], loc='upper left')

# %%
import keras.backend as K
def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

def recall(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision
