# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle as pkl
import numpy as np
import pandas as pd 


with open('/content/drive/MyDrive/Dataset_with_memory /5min/X_train_5min.pickle', 'rb') as f:
    X_train = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /5min/Y_train_5min.pickle', 'rb') as f:
    Y_train = pkl.load(f)


with open('/content/drive/MyDrive/Dataset_with_memory /5min/Y_val_5min.pickle', 'rb') as f:
    Y_val = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /5min/X_val_5min.pickle', 'rb') as f:
     X_val = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /5min/Y_test_5min.pickle', 'rb') as f:
    Y_test = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_with_memory /5min/X_test_5min.pickle', 'rb') as f:
     X_test = pkl.load(f)


Y_train = Y_train.reshape((-1,1))
Y_val = Y_val.reshape((-1,1))
Y_test = Y_test.reshape((-1,1))

X_train.shape , Y_train.shape , X_val.shape , Y_val.shape , X_test.shape , Y_test.shape
# Out:
# ((225480, 120, 5),
#  (225480, 1),
#  (45000, 120, 5),
#  (45000, 1),
#  (135240, 120, 5),
#  (135240, 1))

# %%
from sklearn.utils.class_weight import compute_class_weight



class_weights = compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique ( np.reshape( Y_train , (np.shape(Y_train)[0]))),
                                        y = np.reshape(Y_train ,(np.shape(Y_train)[0]))                                                 
                                    )
class_weights = dict(zip(np.unique(np.reshape(Y_train ,(np.shape(Y_train)[0]))), class_weights))
class_weights
# Out:
# {0: 1.0362703825578616, 1: 0.9661827468590919}

# %%
import os

filepath = "/content/drive/MyDrive/parameter_tuning_LSTM_5min.csv"

# check if the file exists, create it if not
if not os.path.isfile(filepath):
    columns_name = ['LSTM_blocks', 'learning_rate', 'regularizer', 'droput', 'optimizer', 'batch size' ,
                    'train_loss' , 'val_loss' , 'train_accuracy' , 'val_accuracy', 'test_loss' , 'test_accuracy']
    df = pd.DataFrame(columns=columns_name)  # create an empty dataframe
    df.to_csv(filepath, index=False)  # save as a CSV file with no index

# %%
import tensorflow
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, BatchNormalization , Flatten
from keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.models import load_model
from tensorflow.keras import regularizers
from tensorflow import keras
import numpy as np 

#reproducibility 
np.random.seed(0)
tensorflow.random.set_seed(0)

#defining hyperparameters

LSTM_blocks = 20
regularizer = 0
lr = 0.005  
dropout  = 0.5
batchsize = 128
optimizer_func = 'Adam'

# Define the model
def create_model(LSTM_blocks, regularizer, dropout):
    model = Sequential()
    #model.add(BatchNormalization(input_shape=(120, 5)))
    model.add(LSTM(LSTM_blocks, input_shape=(120, 5) , return_sequences=True , activation='tanh', bias_regularizer=regularizers.l1(regularizer),  kernel_regularizer=regularizers.l1(regularizer)))
    model.add(Flatten())
    model.add(Dropout(dropout))
    model.add(Dense(1, activation='sigmoid'))

    model.summary()
    return model 


model = create_model(LSTM_blocks, regularizer, dropout)
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_9 (LSTM)               (None, 120, 20)           2080
#
#  flatten (Flatten)           (None, 2400)              0
#
#  dropout_8 (Dropout)         (None, 2400)              0
#
#  dense_8 (Dense)             (None, 1)                 2401
#
# =================================================================
# Total params: 4,481
# Trainable params: 4,481
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
optimizer = keras.optimizers.Adam(learning_rate=lr,weight_decay=1e-7) if optimizer_func == 'Adam' else keras.optimizers.SGD(learning_rate=lr ,weight_decay=1e-7)

model.compile(loss='binary_crossentropy', optimizer= optimizer, metrics=['binary_accuracy' ])


checkpoint_path = '/content/drive/MyDrive/my_best_model_LSTM_5min.hdf5'

checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             monitor='val_binary_accuracy',
                             verbose=1, 
                             save_best_only=True,
                             mode='max')


earlystopping = EarlyStopping(monitor='val_binary_accuracy', patience=10, restore_best_weights=True)

callback = [earlystopping, checkpoint]
# Train the model
history = model.fit(X_train, Y_train, validation_data=(X_val , Y_val) , verbose=1,  batch_size=batchsize, epochs=150,callbacks = callback , class_weight=class_weights)

loss, accuracy = model.evaluate(X_test, Y_test, batch_size= batchsize)

print(f"Loss: {loss:.4f}")
print(f"Accuracy: {accuracy*100:.2f}%")

filepath = "/content/drive/MyDrive/parameter_tuning_LSTM_5min.csv"
parameters_to_save = pd.read_csv(filepath)

parameters_to_save = parameters_to_save.append({'LSTM_blocks' : LSTM_blocks, 'learning_rate': lr, 'regularizer': regularizer, 'droput': dropout, 
                                                'optimizer': optimizer_func, 'batch size': batchsize, 'train_loss' : history.history['loss'][-1] ,
                                                'val_loss' : history.history['val_loss'][-1] , 'train_accuracy' : history.history['binary_accuracy'][-1] , 
                                                'val_accuracy' : history.history['val_binary_accuracy'][-1],'test_loss' : f"{loss:.4f}" , 
                                                'test_accuracy' : f"{accuracy*100:.2f}%" } , ignore_index = True ) 

parameters_to_save.to_csv(filepath, index=False)
# Out:
# Epoch 1/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.4452 - binary_accuracy: 0.7943
# Epoch 1: val_binary_accuracy improved from -inf to 0.81204, saving model to /content/drive/MyDrive/my_best_model_LSTM_5min.hdf5
# 1762/1762 [==============================] - 17s 9ms/step - loss: 0.4453 - binary_accuracy: 0.7943 - val_loss: 0.4032 - val_binary_accuracy: 0.8120
# Epoch 2/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.4047 - binary_accuracy: 0.8161
# Epoch 2: val_binary_accuracy improved from 0.81204 to 0.81718, saving model to /content/drive/MyDrive/my_best_model_LSTM_5min.hdf5
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.4047 - binary_accuracy: 0.8161 - val_loss: 0.3961 - val_binary_accuracy: 0.8172
# Epoch 3/150
# 1756/1762 [============================>.] - ETA: 0s - loss: 0.3949 - binary_accuracy: 0.8201
# Epoch 3: val_binary_accuracy improved from 0.81718 to 0.82400, saving model to /content/drive/MyDrive/my_best_model_LSTM_5min.hdf5
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3949 - binary_accuracy: 0.8202 - val_loss: 0.3890 - val_binary_accuracy: 0.8240
# Epoch 4/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.3847 - binary_accuracy: 0.8265
# Epoch 4: val_binary_accuracy improved from 0.82400 to 0.82500, saving model to /content/drive/MyDrive/my_best_model_LSTM_5min.hdf5
# 1762/1762 [==============================] - 17s 10ms/step - loss: 0.3847 - binary_accuracy: 0.8265 - val_loss: 0.3879 - val_binary_accuracy: 0.8250
# Epoch 5/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.3776 - binary_accuracy: 0.8310
# Epoch 5: val_binary_accuracy improved from 0.82500 to 0.83027, saving model to /content/drive/MyDrive/my_best_model_LSTM_5min.hdf5
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3775 - binary_accuracy: 0.8310 - val_loss: 0.3774 - val_binary_accuracy: 0.8303
# Epoch 6/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.3728 - binary_accuracy: 0.8338
# Epoch 6: val_binary_accuracy did not improve from 0.83027
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.3728 - binary_accuracy: 0.8338 - val_loss: 0.3764 - val_binary_accuracy: 0.8302
# Epoch 7/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.3711 - binary_accuracy: 0.8348
# Epoch 7: val_binary_accuracy did not improve from 0.83027
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.3711 - binary_accuracy: 0.8348 - val_loss: 0.3764 - val_binary_accuracy: 0.8295
# Epoch 8/150
# 1756/1762 [============================>.] - ETA: 0s - loss: 0.3695 - binary_accuracy: 0.8364
# Epoch 8: val_binary_accuracy did not improve from 0.83027
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.3695 - binary_accuracy: 0.8364 - val_loss: 0.3800 - val_binary_accuracy: 0.8292
# Epoch 9/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.3690 - binary_accuracy: 0.8364
# Epoch 9: val_binary_accuracy did not improve from 0.83027
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.3689 - binary_accuracy: 0.8364 - val_loss: 0.3795 - val_binary_accuracy: 0.8287
# Epoch 10/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.3675 - binary_accuracy: 0.8371
# Epoch 10: val_binary_accuracy improved from 0.83027 to 0.83473, saving model to /content/drive/MyDrive/my_best_model_LSTM_5min.hdf5
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3676 - binary_accuracy: 0.8370 - val_loss: 0.3698 - val_binary_accuracy: 0.8347
# Epoch 11/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.3660 - binary_accuracy: 0.8386
# Epoch 11: val_binary_accuracy did not improve from 0.83473
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.3661 - binary_accuracy: 0.8385 - val_loss: 0.3767 - val_binary_accuracy: 0.8315
# Epoch 12/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.3656 - binary_accuracy: 0.8383
# Epoch 12: val_binary_accuracy did not improve from 0.83473
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3656 - binary_accuracy: 0.8383 - val_loss: 0.3759 - val_binary_accuracy: 0.8330
# Epoch 13/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.3642 - binary_accuracy: 0.8391
# Epoch 13: val_binary_accuracy improved from 0.83473 to 0.83520, saving model to /content/drive/MyDrive/my_best_model_LSTM_5min.hdf5
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.3642 - binary_accuracy: 0.8391 - val_loss: 0.3737 - val_binary_accuracy: 0.8352
# Epoch 14/150
# 1756/1762 [============================>.] - ETA: 0s - loss: 0.3647 - binary_accuracy: 0.8395
# Epoch 14: val_binary_accuracy did not improve from 0.83520
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.3648 - binary_accuracy: 0.8395 - val_loss: 0.3757 - val_binary_accuracy: 0.8311
# Epoch 15/150
# 1755/1762 [============================>.] - ETA: 0s - loss: 0.3635 - binary_accuracy: 0.8394
# Epoch 15: val_binary_accuracy improved from 0.83520 to 0.83569, saving model to /content/drive/MyDrive/my_best_model_LSTM_5min.hdf5
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3634 - binary_accuracy: 0.8394 - val_loss: 0.3696 - val_binary_accuracy: 0.8357
# Epoch 16/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.3638 - binary_accuracy: 0.8406
# Epoch 16: val_binary_accuracy did not improve from 0.83569
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3638 - binary_accuracy: 0.8406 - val_loss: 0.3737 - val_binary_accuracy: 0.8322
# Epoch 17/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.3629 - binary_accuracy: 0.8405
# Epoch 17: val_binary_accuracy did not improve from 0.83569
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.3629 - binary_accuracy: 0.8405 - val_loss: 0.3685 - val_binary_accuracy: 0.8356
# Epoch 18/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.3626 - binary_accuracy: 0.8410
# Epoch 18: val_binary_accuracy did not improve from 0.83569
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3626 - binary_accuracy: 0.8410 - val_loss: 0.3735 - val_binary_accuracy: 0.8320
# Epoch 19/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.3629 - binary_accuracy: 0.8402
# Epoch 19: val_binary_accuracy did not improve from 0.83569
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3629 - binary_accuracy: 0.8403 - val_loss: 0.3731 - val_binary_accuracy: 0.8335
# Epoch 20/150
# 1757/1762 [============================>.] - ETA: 0s - loss: 0.3618 - binary_accuracy: 0.8408
# Epoch 20: val_binary_accuracy did not improve from 0.83569
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3618 - binary_accuracy: 0.8408 - val_loss: 0.3749 - val_binary_accuracy: 0.8341
# Epoch 21/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.3623 - binary_accuracy: 0.8406
# Epoch 21: val_binary_accuracy did not improve from 0.83569
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.3624 - binary_accuracy: 0.8406 - val_loss: 0.3731 - val_binary_accuracy: 0.8315
# Epoch 22/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.3610 - binary_accuracy: 0.8411
# Epoch 22: val_binary_accuracy did not improve from 0.83569
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.3610 - binary_accuracy: 0.8411 - val_loss: 0.3726 - val_binary_accuracy: 0.8322
# Epoch 23/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.3610 - binary_accuracy: 0.8411
# Epoch 23: val_binary_accuracy did not improve from 0.83569
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.3610 - binary_accuracy: 0.8411 - val_loss: 0.3694 - val_binary_accuracy: 0.8344
# Epoch 24/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.3608 - binary_accuracy: 0.8418
# Epoch 24: val_binary_accuracy improved from 0.83569 to 0.83578, saving model to /content/drive/MyDrive/my_best_model_LSTM_5min.hdf5
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3609 - binary_accuracy: 0.8417 - val_loss: 0.3693 - val_binary_accuracy: 0.8358
# Epoch 25/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.3611 - binary_accuracy: 0.8419
# Epoch 25: val_binary_accuracy did not improve from 0.83578
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.3611 - binary_accuracy: 0.8419 - val_loss: 0.3736 - val_binary_accuracy: 0.8318
# Epoch 26/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.3604 - binary_accuracy: 0.8417
# Epoch 26: val_binary_accuracy did not improve from 0.83578
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.3604 - binary_accuracy: 0.8416 - val_loss: 0.3705 - val_binary_accuracy: 0.8341
# Epoch 27/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.3601 - binary_accuracy: 0.8421
# Epoch 27: val_binary_accuracy improved from 0.83578 to 0.83822, saving model to /content/drive/MyDrive/my_best_model_LSTM_5min.hdf5
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3601 - binary_accuracy: 0.8421 - val_loss: 0.3670 - val_binary_accuracy: 0.8382
# Epoch 28/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.3600 - binary_accuracy: 0.8420
# Epoch 28: val_binary_accuracy did not improve from 0.83822
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3600 - binary_accuracy: 0.8421 - val_loss: 0.3701 - val_binary_accuracy: 0.8353
# Epoch 29/150
# 1758/1762 [============================>.] - ETA: 0s - loss: 0.3597 - binary_accuracy: 0.8428
# Epoch 29: val_binary_accuracy did not improve from 0.83822
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3596 - binary_accuracy: 0.8428 - val_loss: 0.3710 - val_binary_accuracy: 0.8345
# Epoch 30/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.3599 - binary_accuracy: 0.8421
# Epoch 30: val_binary_accuracy did not improve from 0.83822
# 1762/1762 [==============================] - 16s 9ms/step - loss: 0.3599 - binary_accuracy: 0.8422 - val_loss: 0.3693 - val_binary_accuracy: 0.8349
# Epoch 31/150
# 1761/1762 [============================>.] - ETA: 0s - loss: 0.3592 - binary_accuracy: 0.8427
# Epoch 31: val_binary_accuracy did not improve from 0.83822
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.3592 - binary_accuracy: 0.8427 - val_loss: 0.3697 - val_binary_accuracy: 0.8348
# Epoch 32/150
# 1762/1762 [==============================] - ETA: 0s - loss: 0.3593 - binary_accuracy: 0.8424
# Epoch 32: val_binary_accuracy did not improve from 0.83822
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.3593 - binary_accuracy: 0.8424 - val_loss: 0.3663 - val_binary_accuracy: 0.8378
# Epoch 33/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.3596 - binary_accuracy: 0.8424
# Epoch 33: val_binary_accuracy did not improve from 0.83822
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.3595 - binary_accuracy: 0.8424 - val_loss: 0.3703 - val_binary_accuracy: 0.8346
# Epoch 34/150
# 1756/1762 [============================>.] - ETA: 0s - loss: 0.3596 - binary_accuracy: 0.8419
# Epoch 34: val_binary_accuracy did not improve from 0.83822
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.3596 - binary_accuracy: 0.8419 - val_loss: 0.3674 - val_binary_accuracy: 0.8380
# Epoch 35/150
# 1756/1762 [============================>.] - ETA: 0s - loss: 0.3580 - binary_accuracy: 0.8439
# Epoch 35: val_binary_accuracy did not improve from 0.83822
# 1762/1762 [==============================] - 15s 8ms/step - loss: 0.3581 - binary_accuracy: 0.8438 - val_loss: 0.3667 - val_binary_accuracy: 0.8369
# Epoch 36/150
# 1759/1762 [============================>.] - ETA: 0s - loss: 0.3582 - binary_accuracy: 0.8431
# Epoch 36: val_binary_accuracy did not improve from 0.83822
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.3581 - binary_accuracy: 0.8431 - val_loss: 0.3730 - val_binary_accuracy: 0.8330
# Epoch 37/150
# 1760/1762 [============================>.] - ETA: 0s - loss: 0.3584 - binary_accuracy: 0.8426
# Epoch 37: val_binary_accuracy did not improve from 0.83822
# 1762/1762 [==============================] - 14s 8ms/step - loss: 0.3584 - binary_accuracy: 0.8427 - val_loss: 0.3706 - val_binary_accuracy: 0.8340
# 1057/1057 [==============================] - 4s 4ms/step - loss: 0.3891 - binary_accuracy: 0.8246
# Loss: 0.3891
# Accuracy: 82.46%
# <ipython-input-33-81fd9d9b3cdf>:30: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   parameters_to_save = parameters_to_save.append({'LSTM_blocks' : LSTM_blocks, 'learning_rate': lr, 'regularizer': regularizer, 'droput': dropout,

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2,1, figsize = (15,15))
axs = axs.flatten()
axs[0].plot(history.history['binary_accuracy'])
axs[0].plot(history.history['val_binary_accuracy'])
axs[0].set_title('model accuracy')

axs[0].legend(['train', 'val'], loc='upper left')

# summarize history for loss
axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('model loss')

axs[1].legend(['train', 'val'], loc='upper left')

# %%
import keras.backend as K
def get_f1(y_true, y_pred): #taken from old keras source code
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    recall = true_positives / (possible_positives + K.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+K.epsilon())
    return f1_val

def recall(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision
