# %%
import pickle as pkl

with open('/content/drive/MyDrive/Dataset_without_memory/dataset.pickle', 'rb') as f:
    dataset = pkl.load(f)

with open('/content/drive/MyDrive/Dataset_without_memory/labels.pickle', 'rb') as f:
    labels = pkl.load(f)

dataset.shape , labels.shape
# Out:
# ((405960, 50), (405960, 5))

# %%
labels = labels['5m class']
dataset = dataset.iloc[: , 1:]

# %%
import numpy as np
index1 = int(len(dataset) * 7/9)
index2 = int (len(dataset) * 8/9)


dataset_train , labels_train  = np.asarray(dataset[: index1]).astype('float32') , np.asarray(labels[:index1 ]).astype('float32')

dataset_val , labels_val = np.asarray(dataset[index1 : index2 ]).astype('float32') , np.asarray(labels[index1 : index2]).astype('float32')

dataset_test , labels_test = np.asarray(dataset[index2 :  ]).astype('float32') , np.asarray(labels[index2:]).astype('float32')

# %%
from sklearn.utils.class_weight import compute_class_weight



class_weights = compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique ( np.reshape( labels_train , (np.shape(labels_train)[0]))),
                                        y = np.reshape(labels_train ,(np.shape(labels_train)[0]))                                                 
                                    )
class_weights = dict(zip(np.unique(np.reshape(labels_train ,(np.shape(labels_train)[0]))), class_weights))
class_weights
# Out:
# {0.0: 1.0339310507426716, 1.0: 0.9682252505304991}

# %%
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

def standardization( dataframe1, dataframe2, dataframe3  ):
  ###we start the for loop form the second column because the first column is timesteps 
  for i in range (dataframe1.shape[1]):
    
    retrn_data = dataframe1[:, i].reshape(-1, 1)

    scaler = StandardScaler()
    retrn_data_standardized = scaler.fit_transform(retrn_data)

    dataframe1[: , i] = retrn_data_standardized.flatten()


##########validation data
    retrn_data = dataframe2[:, i].reshape(-1, 1)

    retrn_data_standardized = scaler.transform(retrn_data)

    dataframe2[: , i] = retrn_data_standardized.flatten()

##########test data

    retrn_data = dataframe3[:, i].reshape(-1, 1)

    retrn_data_standardized = scaler.transform(retrn_data)

    dataframe3[: , i] = retrn_data_standardized.flatten()




  return dataframe1 , dataframe2, dataframe3

dataset_train , dataset_val , dataset_test = standardization(dataset_train , dataset_val , dataset_test)

# %%
import pandas as pd
import os


filepath = "/content/drive/MyDrive/parameter_tuning_5min.csv"

# check if the file exists, create it if not
if not os.path.isfile(filepath):
    columns_name = ['learning_rate' , 'num_hidden_layers', 'regularizer', 'num_neurons', 'droput' , 'optimizer' , 
                    'train_loss' , 'val_loss' , 'train_accuracy' , 'val_accuracy', 'test_loss' , 'test_accuracy']
    df = pd.DataFrame(columns=columns_name)  # create an empty dataframe
    df.to_csv(filepath, index=False)  # save as a CSV file with no index

# %%
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from tensorflow import keras
from keras import regularizers
import tensorflow

#reproducibility 
np.random.seed(0)
tensorflow.random.set_seed(0)

def Create_model(my_learning_rate , num_hidden_layers, regularizer, num_neurons, droput , optimizer_fun):
    # Define the model
    model = Sequential()

    
    # Add layers
    model.add(Dense(num_neurons, activation='relu', input_shape=(dataset_train.shape[1],) ,kernel_regularizer=regularizers.l1(regularizer), bias_regularizer=regularizers.l1(regularizer)))
    model.add(BatchNormalization())
    model.add(Dropout(droput))
    num_neurons = int(num_neurons/2)


    for i in range(num_hidden_layers):
        model.add(Dense(num_neurons, activation='relu', kernel_regularizer=regularizers.l1(regularizer), bias_regularizer=regularizers.l1(regularizer)))
        model.add(BatchNormalization())
        model.add(Dropout(droput))
        num_neurons = int(num_neurons/2)

# model.add(Dense(128,kernel_regularizer=regularizers.l1(0.5), bias_regularizer=regularizers.l1(0.5)))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))

# model.add(Dense(64,kernel_regularizer=regularizers.l1(0.5), bias_regularizer=regularizers.l1(0.5)))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))

# model.add(Dense(32,kernel_regularizer=regularizers.l1(0.5), bias_regularizer=regularizers.l1(0.5)))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))

    model.add(Dense(1, activation='sigmoid'))

    if (optimizer_fun == 'SGD'):
      optimizer = keras.optimizers.SGD(learning_rate=my_learning_rate)
    else:
      optimizer = keras.optimizers.Adam(learning_rate=my_learning_rate)



    # Compile the model
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['binary_accuracy'] )

    # Print the summary of the model
    model.summary()

    return model

my_learning_rate = 0.0005
num_hidden_layers  = 4
regularizer = 0
num_neurons = 512
dropout = 0.5
optimizer = 'Adam'

model = Create_model(my_learning_rate, num_hidden_layers , regularizer , num_neurons , dropout , optimizer)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_6 (Dense)             (None, 512)               25600
#
#  batch_normalization_5 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_5 (Dropout)         (None, 512)               0
#
#  dense_7 (Dense)             (None, 256)               131328
#
#  batch_normalization_6 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_8 (Dense)             (None, 128)               32896
#
#  batch_normalization_7 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_7 (Dropout)         (None, 128)               0
#
#  dense_9 (Dense)             (None, 64)                8256
#
#  batch_normalization_8 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_8 (Dropout)         (None, 64)                0
#
#  dense_10 (Dense)            (None, 32)                2080
#
#  batch_normalization_9 (Batc  (None, 32)               128
#  hNormalization)
#
#  dropout_9 (Dropout)         (None, 32)                0
#
#  dense_11 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 204,161
# Trainable params: 202,177
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping


checkpoint_path = '/content/drive/MyDrive/my_best_model_FNN_5min.hdf5'

checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             monitor='val_binary_accuracy',
                             verbose=1, 
                             save_best_only=True,
                             mode='max')


earlystopping = EarlyStopping(monitor='val_binary_accuracy', patience=10, restore_best_weights=True)

callback = [checkpoint, earlystopping]

# Train the model
history = model.fit(dataset_train, labels_train, validation_data=[dataset_val , labels_val], epochs=150, batch_size=128, callbacks=callback, class_weight=class_weights)

# Evaluate the model
loss, accuracy = model.evaluate(dataset_test, labels_test, batch_size=128)

print(f"Loss: {loss:.4f}")
print(f"Accuracy: {accuracy*100:.2f}%")
# Out:
# Epoch 1/150
# 2463/2467 [============================>.] - ETA: 0s - loss: 0.7264 - binary_accuracy: 0.5007
# Epoch 1: val_binary_accuracy improved from -inf to 0.50553, saving model to /content/drive/MyDrive/my_best_model_FNN_5min.hdf5
# 2467/2467 [==============================] - 27s 9ms/step - loss: 0.7263 - binary_accuracy: 0.5007 - val_loss: 0.6931 - val_binary_accuracy: 0.5055
# Epoch 2/150
# 2461/2467 [============================>.] - ETA: 0s - loss: 0.6933 - binary_accuracy: 0.5007
# Epoch 2: val_binary_accuracy improved from 0.50553 to 0.51475, saving model to /content/drive/MyDrive/my_best_model_FNN_5min.hdf5
# 2467/2467 [==============================] - 21s 8ms/step - loss: 0.6933 - binary_accuracy: 0.5007 - val_loss: 0.6930 - val_binary_accuracy: 0.5148
# Epoch 3/150
# 2464/2467 [============================>.] - ETA: 0s - loss: 0.6925 - binary_accuracy: 0.5161
# Epoch 3: val_binary_accuracy improved from 0.51475 to 0.52407, saving model to /content/drive/MyDrive/my_best_model_FNN_5min.hdf5
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6925 - binary_accuracy: 0.5161 - val_loss: 0.6914 - val_binary_accuracy: 0.5241
# Epoch 4/150
# 2464/2467 [============================>.] - ETA: 0s - loss: 0.6910 - binary_accuracy: 0.5290
# Epoch 4: val_binary_accuracy improved from 0.52407 to 0.53036, saving model to /content/drive/MyDrive/my_best_model_FNN_5min.hdf5
# 2467/2467 [==============================] - 23s 9ms/step - loss: 0.6910 - binary_accuracy: 0.5290 - val_loss: 0.6904 - val_binary_accuracy: 0.5304
# Epoch 5/150
# 2463/2467 [============================>.] - ETA: 0s - loss: 0.6904 - binary_accuracy: 0.5323
# Epoch 5: val_binary_accuracy improved from 0.53036 to 0.53497, saving model to /content/drive/MyDrive/my_best_model_FNN_5min.hdf5
# 2467/2467 [==============================] - 21s 9ms/step - loss: 0.6904 - binary_accuracy: 0.5323 - val_loss: 0.6896 - val_binary_accuracy: 0.5350
# Epoch 6/150
# 2464/2467 [============================>.] - ETA: 0s - loss: 0.6901 - binary_accuracy: 0.5347
# Epoch 6: val_binary_accuracy did not improve from 0.53497
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6901 - binary_accuracy: 0.5346 - val_loss: 0.6900 - val_binary_accuracy: 0.5337
# Epoch 7/150
# 2464/2467 [============================>.] - ETA: 0s - loss: 0.6894 - binary_accuracy: 0.5388
# Epoch 7: val_binary_accuracy did not improve from 0.53497
# 2467/2467 [==============================] - 20s 8ms/step - loss: 0.6894 - binary_accuracy: 0.5387 - val_loss: 0.6897 - val_binary_accuracy: 0.5331
# Epoch 8/150
# 2462/2467 [============================>.] - ETA: 0s - loss: 0.6890 - binary_accuracy: 0.5401
# Epoch 8: val_binary_accuracy did not improve from 0.53497
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6890 - binary_accuracy: 0.5401 - val_loss: 0.6894 - val_binary_accuracy: 0.5341
# Epoch 9/150
# 2463/2467 [============================>.] - ETA: 0s - loss: 0.6888 - binary_accuracy: 0.5407
# Epoch 9: val_binary_accuracy improved from 0.53497 to 0.53613, saving model to /content/drive/MyDrive/my_best_model_FNN_5min.hdf5
# 2467/2467 [==============================] - 21s 9ms/step - loss: 0.6888 - binary_accuracy: 0.5407 - val_loss: 0.6893 - val_binary_accuracy: 0.5361
# Epoch 10/150
# 2462/2467 [============================>.] - ETA: 0s - loss: 0.6884 - binary_accuracy: 0.5424
# Epoch 10: val_binary_accuracy did not improve from 0.53613
# 2467/2467 [==============================] - 21s 9ms/step - loss: 0.6884 - binary_accuracy: 0.5424 - val_loss: 0.6898 - val_binary_accuracy: 0.5336
# Epoch 11/150
# 2467/2467 [==============================] - ETA: 0s - loss: 0.6881 - binary_accuracy: 0.5439
# Epoch 11: val_binary_accuracy did not improve from 0.53613
# 2467/2467 [==============================] - 21s 9ms/step - loss: 0.6881 - binary_accuracy: 0.5439 - val_loss: 0.6893 - val_binary_accuracy: 0.5348
# Epoch 12/150
# 2462/2467 [============================>.] - ETA: 0s - loss: 0.6876 - binary_accuracy: 0.5446
# Epoch 12: val_binary_accuracy improved from 0.53613 to 0.53681, saving model to /content/drive/MyDrive/my_best_model_FNN_5min.hdf5
# 2467/2467 [==============================] - 23s 9ms/step - loss: 0.6876 - binary_accuracy: 0.5445 - val_loss: 0.6894 - val_binary_accuracy: 0.5368
# Epoch 13/150
# 2467/2467 [==============================] - ETA: 0s - loss: 0.6874 - binary_accuracy: 0.5455
# Epoch 13: val_binary_accuracy did not improve from 0.53681
# 2467/2467 [==============================] - 23s 9ms/step - loss: 0.6874 - binary_accuracy: 0.5455 - val_loss: 0.6893 - val_binary_accuracy: 0.5364
# Epoch 14/150
# 2467/2467 [==============================] - ETA: 0s - loss: 0.6871 - binary_accuracy: 0.5474
# Epoch 14: val_binary_accuracy did not improve from 0.53681
# 2467/2467 [==============================] - 23s 9ms/step - loss: 0.6871 - binary_accuracy: 0.5474 - val_loss: 0.6895 - val_binary_accuracy: 0.5364
# Epoch 15/150
# 2464/2467 [============================>.] - ETA: 0s - loss: 0.6869 - binary_accuracy: 0.5482
# Epoch 15: val_binary_accuracy did not improve from 0.53681
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6869 - binary_accuracy: 0.5481 - val_loss: 0.6897 - val_binary_accuracy: 0.5342
# Epoch 16/150
# 2463/2467 [============================>.] - ETA: 0s - loss: 0.6866 - binary_accuracy: 0.5490
# Epoch 16: val_binary_accuracy improved from 0.53681 to 0.53726, saving model to /content/drive/MyDrive/my_best_model_FNN_5min.hdf5
# 2467/2467 [==============================] - 23s 9ms/step - loss: 0.6866 - binary_accuracy: 0.5489 - val_loss: 0.6892 - val_binary_accuracy: 0.5373
# Epoch 17/150
# 2467/2467 [==============================] - ETA: 0s - loss: 0.6860 - binary_accuracy: 0.5508
# Epoch 17: val_binary_accuracy did not improve from 0.53726
# 2467/2467 [==============================] - 21s 9ms/step - loss: 0.6860 - binary_accuracy: 0.5508 - val_loss: 0.6896 - val_binary_accuracy: 0.5342
# Epoch 18/150
# 2463/2467 [============================>.] - ETA: 0s - loss: 0.6858 - binary_accuracy: 0.5517
# Epoch 18: val_binary_accuracy did not improve from 0.53726
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6858 - binary_accuracy: 0.5517 - val_loss: 0.6896 - val_binary_accuracy: 0.5344
# Epoch 19/150
# 2466/2467 [============================>.] - ETA: 0s - loss: 0.6856 - binary_accuracy: 0.5530
# Epoch 19: val_binary_accuracy did not improve from 0.53726
# 2467/2467 [==============================] - 24s 10ms/step - loss: 0.6856 - binary_accuracy: 0.5530 - val_loss: 0.6895 - val_binary_accuracy: 0.5358
# Epoch 20/150
# 2461/2467 [============================>.] - ETA: 0s - loss: 0.6852 - binary_accuracy: 0.5533
# Epoch 20: val_binary_accuracy did not improve from 0.53726
# 2467/2467 [==============================] - 20s 8ms/step - loss: 0.6852 - binary_accuracy: 0.5533 - val_loss: 0.6895 - val_binary_accuracy: 0.5358
# Epoch 21/150
# 2466/2467 [============================>.] - ETA: 0s - loss: 0.6849 - binary_accuracy: 0.5532
# Epoch 21: val_binary_accuracy did not improve from 0.53726
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6849 - binary_accuracy: 0.5532 - val_loss: 0.6899 - val_binary_accuracy: 0.5349
# Epoch 22/150
# 2465/2467 [============================>.] - ETA: 0s - loss: 0.6846 - binary_accuracy: 0.5543
# Epoch 22: val_binary_accuracy did not improve from 0.53726
# 2467/2467 [==============================] - 21s 9ms/step - loss: 0.6846 - binary_accuracy: 0.5542 - val_loss: 0.6897 - val_binary_accuracy: 0.5353
# Epoch 23/150
# 2461/2467 [============================>.] - ETA: 0s - loss: 0.6840 - binary_accuracy: 0.5553
# Epoch 23: val_binary_accuracy did not improve from 0.53726
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6840 - binary_accuracy: 0.5554 - val_loss: 0.6907 - val_binary_accuracy: 0.5361
# Epoch 24/150
# 2465/2467 [============================>.] - ETA: 0s - loss: 0.6841 - binary_accuracy: 0.5556
# Epoch 24: val_binary_accuracy did not improve from 0.53726
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6841 - binary_accuracy: 0.5556 - val_loss: 0.6905 - val_binary_accuracy: 0.5336
# Epoch 25/150
# 2462/2467 [============================>.] - ETA: 0s - loss: 0.6837 - binary_accuracy: 0.5574
# Epoch 25: val_binary_accuracy improved from 0.53726 to 0.53770, saving model to /content/drive/MyDrive/my_best_model_FNN_5min.hdf5
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6837 - binary_accuracy: 0.5574 - val_loss: 0.6905 - val_binary_accuracy: 0.5377
# Epoch 26/150
# 2461/2467 [============================>.] - ETA: 0s - loss: 0.6836 - binary_accuracy: 0.5577
# Epoch 26: val_binary_accuracy did not improve from 0.53770
# 2467/2467 [==============================] - 23s 10ms/step - loss: 0.6836 - binary_accuracy: 0.5578 - val_loss: 0.6911 - val_binary_accuracy: 0.5362
# Epoch 27/150
# 2467/2467 [==============================] - ETA: 0s - loss: 0.6830 - binary_accuracy: 0.5590
# Epoch 27: val_binary_accuracy did not improve from 0.53770
# 2467/2467 [==============================] - 21s 9ms/step - loss: 0.6830 - binary_accuracy: 0.5590 - val_loss: 0.6901 - val_binary_accuracy: 0.5362
# Epoch 28/150
# 2461/2467 [============================>.] - ETA: 0s - loss: 0.6831 - binary_accuracy: 0.5592
# Epoch 28: val_binary_accuracy did not improve from 0.53770
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6830 - binary_accuracy: 0.5592 - val_loss: 0.6905 - val_binary_accuracy: 0.5377
# Epoch 29/150
# 2467/2467 [==============================] - ETA: 0s - loss: 0.6821 - binary_accuracy: 0.5612
# Epoch 29: val_binary_accuracy did not improve from 0.53770
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6821 - binary_accuracy: 0.5612 - val_loss: 0.6912 - val_binary_accuracy: 0.5353
# Epoch 30/150
# 2467/2467 [==============================] - ETA: 0s - loss: 0.6821 - binary_accuracy: 0.5613
# Epoch 30: val_binary_accuracy did not improve from 0.53770
# 2467/2467 [==============================] - 21s 9ms/step - loss: 0.6821 - binary_accuracy: 0.5613 - val_loss: 0.6905 - val_binary_accuracy: 0.5359
# Epoch 31/150
# 2466/2467 [============================>.] - ETA: 0s - loss: 0.6818 - binary_accuracy: 0.5627
# Epoch 31: val_binary_accuracy improved from 0.53770 to 0.53785, saving model to /content/drive/MyDrive/my_best_model_FNN_5min.hdf5
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6818 - binary_accuracy: 0.5627 - val_loss: 0.6904 - val_binary_accuracy: 0.5379
# Epoch 32/150
# 2464/2467 [============================>.] - ETA: 0s - loss: 0.6818 - binary_accuracy: 0.5618
# Epoch 32: val_binary_accuracy did not improve from 0.53785
# 2467/2467 [==============================] - 21s 9ms/step - loss: 0.6818 - binary_accuracy: 0.5618 - val_loss: 0.6909 - val_binary_accuracy: 0.5346
# Epoch 33/150
# 2463/2467 [============================>.] - ETA: 0s - loss: 0.6811 - binary_accuracy: 0.5637
# Epoch 33: val_binary_accuracy did not improve from 0.53785
# 2467/2467 [==============================] - 23s 9ms/step - loss: 0.6811 - binary_accuracy: 0.5637 - val_loss: 0.6918 - val_binary_accuracy: 0.5358
# Epoch 34/150
# 2465/2467 [============================>.] - ETA: 0s - loss: 0.6809 - binary_accuracy: 0.5644
# Epoch 34: val_binary_accuracy did not improve from 0.53785
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6809 - binary_accuracy: 0.5644 - val_loss: 0.6912 - val_binary_accuracy: 0.5331
# Epoch 35/150
# 2467/2467 [==============================] - ETA: 0s - loss: 0.6806 - binary_accuracy: 0.5650
# Epoch 35: val_binary_accuracy did not improve from 0.53785
# 2467/2467 [==============================] - 21s 8ms/step - loss: 0.6806 - binary_accuracy: 0.5650 - val_loss: 0.6927 - val_binary_accuracy: 0.5335
# Epoch 36/150
# 2465/2467 [============================>.] - ETA: 0s - loss: 0.6805 - binary_accuracy: 0.5652
# Epoch 36: val_binary_accuracy did not improve from 0.53785
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6805 - binary_accuracy: 0.5652 - val_loss: 0.6910 - val_binary_accuracy: 0.5359
# Epoch 37/150
# 2464/2467 [============================>.] - ETA: 0s - loss: 0.6801 - binary_accuracy: 0.5668
# Epoch 37: val_binary_accuracy did not improve from 0.53785
# 2467/2467 [==============================] - 21s 9ms/step - loss: 0.6801 - binary_accuracy: 0.5668 - val_loss: 0.6924 - val_binary_accuracy: 0.5365
# Epoch 38/150
# 2461/2467 [============================>.] - ETA: 0s - loss: 0.6800 - binary_accuracy: 0.5667
# Epoch 38: val_binary_accuracy did not improve from 0.53785
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6800 - binary_accuracy: 0.5666 - val_loss: 0.6914 - val_binary_accuracy: 0.5348
# Epoch 39/150
# 2467/2467 [==============================] - ETA: 0s - loss: 0.6795 - binary_accuracy: 0.5672
# Epoch 39: val_binary_accuracy did not improve from 0.53785
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6795 - binary_accuracy: 0.5672 - val_loss: 0.6915 - val_binary_accuracy: 0.5328
# Epoch 40/150
# 2466/2467 [============================>.] - ETA: 0s - loss: 0.6794 - binary_accuracy: 0.5690
# Epoch 40: val_binary_accuracy did not improve from 0.53785
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6794 - binary_accuracy: 0.5690 - val_loss: 0.6925 - val_binary_accuracy: 0.5331
# Epoch 41/150
# 2461/2467 [============================>.] - ETA: 0s - loss: 0.6794 - binary_accuracy: 0.5686
# Epoch 41: val_binary_accuracy did not improve from 0.53785
# 2467/2467 [==============================] - 23s 9ms/step - loss: 0.6793 - binary_accuracy: 0.5687 - val_loss: 0.6932 - val_binary_accuracy: 0.5335
# 353/353 [==============================] - 1s 3ms/step - loss: 0.6883 - binary_accuracy: 0.5412
# Loss: 0.6883
# Accuracy: 54.12%

# %%
import pandas as pd
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2,1, figsize = (15,15))
axs = axs.flatten()
axs[0].plot(history.history['binary_accuracy'])
axs[0].plot(history.history['val_binary_accuracy'])
axs[0].set_title('model accuracy')

axs[0].legend(['train', 'val'], loc='upper left')

# summarize history for loss
axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('model loss')

axs[1].legend(['train', 'val'], loc='upper left')


parameters_to_save = pd.read_csv(filepath)

parameters_to_save = parameters_to_save.append({'learning_rate' : my_learning_rate , 'num_hidden_layers' : num_hidden_layers  , 'regularizer' : regularizer, 
                              'num_neurons' : num_neurons, 'droput': dropout , 'optimizer' : optimizer, 
                              'train_loss' : history.history['loss'][-1] , 'val_loss' : history.history['val_loss'][-1] 
                              , 'train_accuracy' : history.history['binary_accuracy'][-1] , 'val_accuracy' : history.history['val_binary_accuracy'][-1],
                             'test_loss' : f"{loss:.4f}" , 'test_accuracy' : f"{accuracy*100:.2f}%" } , ignore_index = True ) 

parameters_to_save.to_csv(filepath, index=False)
