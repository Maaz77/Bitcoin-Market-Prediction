# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle as pkl

with open('/content/drive/MyDrive/Colab Notebooks/Dataset_without_memory/dataset.pickle', 'rb') as f:
    dataset = pkl.load(f)

with open('/content/drive/MyDrive/Colab Notebooks/Dataset_without_memory/labels.pickle', 'rb') as f:
    labels = pkl.load(f)

dataset.shape , labels.shape
# Out:
# ((405960, 50), (405960, 5))

# %%
labels = labels['60m class']
dataset = dataset.iloc[: , 1:]

# %%
import numpy as np
index1 = int(len(dataset) * 7/9)
index2 = int (len(dataset) * 8/9)


dataset_train , labels_train  = np.asarray(dataset[: index1]).astype('float32') , np.asarray(labels[:index1 ]).astype('float32')

dataset_val , labels_val = np.asarray(dataset[index1 : index2 ]).astype('float32') , np.asarray(labels[index1 : index2]).astype('float32')

dataset_test , labels_test = np.asarray(dataset[index2 :  ]).astype('float32') , np.asarray(labels[index2:]).astype('float32')

# %%
from sklearn.utils.class_weight import compute_class_weight



class_weights = compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique ( np.reshape( labels_train , (np.shape(labels_train)[0]))),
                                        y = np.reshape(labels_train ,(np.shape(labels_train)[0]))                                                 
                                    )
class_weights = dict(zip(np.unique(np.reshape(labels_train ,(np.shape(labels_train)[0]))), class_weights))
class_weights
# Out:
# {0.0: 1.0300655727008776, 1.0: 0.9716397609566657}

# %%
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

def standardization( dataframe1, dataframe2, dataframe3  ):
  ###we start the for loop form the second column because the first column is timesteps 
  for i in range (dataframe1.shape[1]):
    
    retrn_data = dataframe1[:, i].reshape(-1, 1)

    scaler = StandardScaler()
    retrn_data_standardized = scaler.fit_transform(retrn_data)

    dataframe1[: , i] = retrn_data_standardized.flatten()


##########validation data
    retrn_data = dataframe2[:, i].reshape(-1, 1)

    retrn_data_standardized = scaler.transform(retrn_data)

    dataframe2[: , i] = retrn_data_standardized.flatten()

##########test data

    retrn_data = dataframe3[:, i].reshape(-1, 1)

    retrn_data_standardized = scaler.transform(retrn_data)

    dataframe3[: , i] = retrn_data_standardized.flatten()




  return dataframe1 , dataframe2, dataframe3

dataset_train , dataset_val , dataset_test = standardization(dataset_train , dataset_val , dataset_test)

# %%
import pandas as pd
import os


filepath = "/content/drive/MyDrive/parameter_tuning_60min.csv"

# check if the file exists, create it if not
if not os.path.isfile(filepath):
    columns_name = ['learning_rate' , 'num_hidden_layers', 'regularizer', 'num_neurons', 'droput' , 'optimizer' , 
                    'train_loss' , 'val_loss' , 'train_accuracy' , 'val_accuracy', 'test_loss' , 'test_accuracy']
    df = pd.DataFrame(columns=columns_name)  # create an empty dataframe
    df.to_csv(filepath, index=False)  # save as a CSV file with no index

# %%
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from tensorflow import keras
from keras import regularizers
import tensorflow

#reproducibility 
np.random.seed(0)
tensorflow.random.set_seed(0)

def Create_model(my_learning_rate , num_hidden_layers, regularizer, num_neurons, droput , optimizer_fun):
    # Define the model
    model = Sequential()

    
    # Add layers
    model.add(Dense(num_neurons, activation='relu', input_shape=(dataset_train.shape[1],) ,kernel_regularizer=regularizers.l1(regularizer), bias_regularizer=regularizers.l1(regularizer)))
    model.add(BatchNormalization())
    model.add(Dropout(droput))
    num_neurons = int(num_neurons/2)


    for i in range(num_hidden_layers):
        model.add(Dense(num_neurons, activation='relu', kernel_regularizer=regularizers.l1(regularizer), bias_regularizer=regularizers.l1(regularizer)))
        model.add(BatchNormalization())
        model.add(Dropout(droput))
        num_neurons = int(num_neurons/2)

# model.add(Dense(128,kernel_regularizer=regularizers.l1(0.5), bias_regularizer=regularizers.l1(0.5)))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))

# model.add(Dense(64,kernel_regularizer=regularizers.l1(0.5), bias_regularizer=regularizers.l1(0.5)))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))

# model.add(Dense(32,kernel_regularizer=regularizers.l1(0.5), bias_regularizer=regularizers.l1(0.5)))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))

    model.add(Dense(1, activation='sigmoid'))

    if (optimizer_fun == 'SGD'):
      optimizer = keras.optimizers.SGD(learning_rate=my_learning_rate)
    else:
      optimizer = keras.optimizers.Adam(learning_rate=my_learning_rate)



    # Compile the model
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['binary_accuracy'] )

    # Print the summary of the model
    model.summary()

    return model

my_learning_rate = 0.0001
num_hidden_layers  = 4
regularizer = 0
num_neurons = 512
dropout = 0.5
optimizer = 'Adam'

model = Create_model(my_learning_rate, num_hidden_layers , regularizer , num_neurons , dropout , optimizer)
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 512)               25600
#
#  batch_normalization_20 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dropout_20 (Dropout)        (None, 512)               0
#
#  dense_25 (Dense)            (None, 256)               131328
#
#  batch_normalization_21 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_21 (Dropout)        (None, 256)               0
#
#  dense_26 (Dense)            (None, 128)               32896
#
#  batch_normalization_22 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_22 (Dropout)        (None, 128)               0
#
#  dense_27 (Dense)            (None, 64)                8256
#
#  batch_normalization_23 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_23 (Dropout)        (None, 64)                0
#
#  dense_28 (Dense)            (None, 32)                2080
#
#  batch_normalization_24 (Bat  (None, 32)               128
#  chNormalization)
#
#  dropout_24 (Dropout)        (None, 32)                0
#
#  dense_29 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 204,161
# Trainable params: 202,177
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping


checkpoint_path = '/content/drive/MyDrive/my_best_model_FNN_60min.hdf5'

checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             monitor='val_binary_accuracy',
                             verbose=1, 
                             save_best_only=True,
                             mode='max')


earlystopping = EarlyStopping(monitor='val_binary_accuracy', patience=10, restore_best_weights=True)

callback = [checkpoint, earlystopping]

# Train the model
history = model.fit(dataset_train, labels_train, validation_data=[dataset_val , labels_val], epochs=150, batch_size=128, callbacks=callback, class_weight=class_weights)

# Evaluate the model
loss, accuracy = model.evaluate(dataset_test, labels_test, batch_size=128)

print(f"Loss: {loss:.4f}")
print(f"Accuracy: {accuracy*100:.2f}%")
# Out:
# Epoch 1/150
# 2465/2467 [============================>.] - ETA: 0s - loss: 0.8381 - binary_accuracy: 0.5027
# Epoch 1: val_binary_accuracy improved from -inf to 0.49671, saving model to /content/drive/MyDrive/my_best_model_FNN_60min.hdf5
# 2467/2467 [==============================] - 28s 9ms/step - loss: 0.8380 - binary_accuracy: 0.5027 - val_loss: 0.6970 - val_binary_accuracy: 0.4967
# Epoch 2/150
# 2464/2467 [============================>.] - ETA: 0s - loss: 0.7253 - binary_accuracy: 0.5024
# Epoch 2: val_binary_accuracy did not improve from 0.49671
# 2467/2467 [==============================] - 23s 9ms/step - loss: 0.7253 - binary_accuracy: 0.5024 - val_loss: 0.6943 - val_binary_accuracy: 0.4925
# Epoch 3/150
# 2464/2467 [============================>.] - ETA: 0s - loss: 0.6996 - binary_accuracy: 0.5046
# Epoch 3: val_binary_accuracy did not improve from 0.49671
# 2467/2467 [==============================] - 23s 9ms/step - loss: 0.6996 - binary_accuracy: 0.5046 - val_loss: 0.6935 - val_binary_accuracy: 0.4907
# Epoch 4/150
# 2466/2467 [============================>.] - ETA: 0s - loss: 0.6941 - binary_accuracy: 0.5087
# Epoch 4: val_binary_accuracy improved from 0.49671 to 0.49708, saving model to /content/drive/MyDrive/my_best_model_FNN_60min.hdf5
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6941 - binary_accuracy: 0.5087 - val_loss: 0.6929 - val_binary_accuracy: 0.4971
# Epoch 5/150
# 2467/2467 [==============================] - ETA: 0s - loss: 0.6921 - binary_accuracy: 0.5211
# Epoch 5: val_binary_accuracy improved from 0.49708 to 0.53358, saving model to /content/drive/MyDrive/my_best_model_FNN_60min.hdf5
# 2467/2467 [==============================] - 24s 10ms/step - loss: 0.6921 - binary_accuracy: 0.5211 - val_loss: 0.6905 - val_binary_accuracy: 0.5336
# Epoch 6/150
# 2463/2467 [============================>.] - ETA: 0s - loss: 0.6896 - binary_accuracy: 0.5373
# Epoch 6: val_binary_accuracy improved from 0.53358 to 0.54446, saving model to /content/drive/MyDrive/my_best_model_FNN_60min.hdf5
# 2467/2467 [==============================] - 23s 9ms/step - loss: 0.6896 - binary_accuracy: 0.5373 - val_loss: 0.6877 - val_binary_accuracy: 0.5445
# Epoch 7/150
# 2464/2467 [============================>.] - ETA: 0s - loss: 0.6877 - binary_accuracy: 0.5463
# Epoch 7: val_binary_accuracy improved from 0.54446 to 0.54681, saving model to /content/drive/MyDrive/my_best_model_FNN_60min.hdf5
# 2467/2467 [==============================] - 23s 9ms/step - loss: 0.6877 - binary_accuracy: 0.5463 - val_loss: 0.6870 - val_binary_accuracy: 0.5468
# Epoch 8/150
# 2461/2467 [============================>.] - ETA: 0s - loss: 0.6866 - binary_accuracy: 0.5506
# Epoch 8: val_binary_accuracy improved from 0.54681 to 0.54934, saving model to /content/drive/MyDrive/my_best_model_FNN_60min.hdf5
# 2467/2467 [==============================] - 23s 9ms/step - loss: 0.6866 - binary_accuracy: 0.5506 - val_loss: 0.6859 - val_binary_accuracy: 0.5493
# Epoch 9/150
# 2467/2467 [==============================] - ETA: 0s - loss: 0.6857 - binary_accuracy: 0.5537
# Epoch 9: val_binary_accuracy did not improve from 0.54934
# 2467/2467 [==============================] - 23s 9ms/step - loss: 0.6857 - binary_accuracy: 0.5537 - val_loss: 0.6858 - val_binary_accuracy: 0.5477
# Epoch 10/150
# 2466/2467 [============================>.] - ETA: 0s - loss: 0.6850 - binary_accuracy: 0.5558
# Epoch 10: val_binary_accuracy improved from 0.54934 to 0.55167, saving model to /content/drive/MyDrive/my_best_model_FNN_60min.hdf5
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6850 - binary_accuracy: 0.5558 - val_loss: 0.6850 - val_binary_accuracy: 0.5517
# Epoch 11/150
# 2462/2467 [============================>.] - ETA: 0s - loss: 0.6846 - binary_accuracy: 0.5570
# Epoch 11: val_binary_accuracy did not improve from 0.55167
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6846 - binary_accuracy: 0.5570 - val_loss: 0.6850 - val_binary_accuracy: 0.5509
# Epoch 12/150
# 2465/2467 [============================>.] - ETA: 0s - loss: 0.6838 - binary_accuracy: 0.5587
# Epoch 12: val_binary_accuracy did not improve from 0.55167
# 2467/2467 [==============================] - 23s 9ms/step - loss: 0.6838 - binary_accuracy: 0.5586 - val_loss: 0.6851 - val_binary_accuracy: 0.5508
# Epoch 13/150
# 2466/2467 [============================>.] - ETA: 0s - loss: 0.6831 - binary_accuracy: 0.5612
# Epoch 13: val_binary_accuracy improved from 0.55167 to 0.55355, saving model to /content/drive/MyDrive/my_best_model_FNN_60min.hdf5
# 2467/2467 [==============================] - 24s 10ms/step - loss: 0.6831 - binary_accuracy: 0.5611 - val_loss: 0.6847 - val_binary_accuracy: 0.5536
# Epoch 14/150
# 2462/2467 [============================>.] - ETA: 0s - loss: 0.6827 - binary_accuracy: 0.5618
# Epoch 14: val_binary_accuracy did not improve from 0.55355
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6827 - binary_accuracy: 0.5619 - val_loss: 0.6846 - val_binary_accuracy: 0.5518
# Epoch 15/150
# 2461/2467 [============================>.] - ETA: 0s - loss: 0.6820 - binary_accuracy: 0.5630
# Epoch 15: val_binary_accuracy did not improve from 0.55355
# 2467/2467 [==============================] - 23s 10ms/step - loss: 0.6820 - binary_accuracy: 0.5631 - val_loss: 0.6846 - val_binary_accuracy: 0.5522
# Epoch 16/150
# 2466/2467 [============================>.] - ETA: 0s - loss: 0.6809 - binary_accuracy: 0.5662
# Epoch 16: val_binary_accuracy did not improve from 0.55355
# 2467/2467 [==============================] - 23s 9ms/step - loss: 0.6809 - binary_accuracy: 0.5662 - val_loss: 0.6847 - val_binary_accuracy: 0.5535
# Epoch 17/150
# 2463/2467 [============================>.] - ETA: 0s - loss: 0.6809 - binary_accuracy: 0.5659
# Epoch 17: val_binary_accuracy did not improve from 0.55355
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6809 - binary_accuracy: 0.5658 - val_loss: 0.6850 - val_binary_accuracy: 0.5496
# Epoch 18/150
# 2467/2467 [==============================] - ETA: 0s - loss: 0.6802 - binary_accuracy: 0.5676
# Epoch 18: val_binary_accuracy improved from 0.55355 to 0.55422, saving model to /content/drive/MyDrive/my_best_model_FNN_60min.hdf5
# 2467/2467 [==============================] - 24s 10ms/step - loss: 0.6802 - binary_accuracy: 0.5676 - val_loss: 0.6844 - val_binary_accuracy: 0.5542
# Epoch 19/150
# 2464/2467 [============================>.] - ETA: 0s - loss: 0.6798 - binary_accuracy: 0.5677
# Epoch 19: val_binary_accuracy did not improve from 0.55422
# 2467/2467 [==============================] - 23s 9ms/step - loss: 0.6798 - binary_accuracy: 0.5677 - val_loss: 0.6850 - val_binary_accuracy: 0.5520
# Epoch 20/150
# 2463/2467 [============================>.] - ETA: 0s - loss: 0.6790 - binary_accuracy: 0.5703
# Epoch 20: val_binary_accuracy did not improve from 0.55422
# 2467/2467 [==============================] - 24s 10ms/step - loss: 0.6790 - binary_accuracy: 0.5703 - val_loss: 0.6848 - val_binary_accuracy: 0.5508
# Epoch 21/150
# 2462/2467 [============================>.] - ETA: 0s - loss: 0.6785 - binary_accuracy: 0.5706
# Epoch 21: val_binary_accuracy did not improve from 0.55422
# 2467/2467 [==============================] - 23s 9ms/step - loss: 0.6785 - binary_accuracy: 0.5706 - val_loss: 0.6855 - val_binary_accuracy: 0.5504
# Epoch 22/150
# 2467/2467 [==============================] - ETA: 0s - loss: 0.6779 - binary_accuracy: 0.5719
# Epoch 22: val_binary_accuracy did not improve from 0.55422
# 2467/2467 [==============================] - 23s 9ms/step - loss: 0.6779 - binary_accuracy: 0.5719 - val_loss: 0.6848 - val_binary_accuracy: 0.5539
# Epoch 23/150
# 2462/2467 [============================>.] - ETA: 0s - loss: 0.6774 - binary_accuracy: 0.5727
# Epoch 23: val_binary_accuracy did not improve from 0.55422
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6774 - binary_accuracy: 0.5728 - val_loss: 0.6857 - val_binary_accuracy: 0.5517
# Epoch 24/150
# 2465/2467 [============================>.] - ETA: 0s - loss: 0.6769 - binary_accuracy: 0.5737
# Epoch 24: val_binary_accuracy did not improve from 0.55422
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6768 - binary_accuracy: 0.5737 - val_loss: 0.6864 - val_binary_accuracy: 0.5498
# Epoch 25/150
# 2467/2467 [==============================] - ETA: 0s - loss: 0.6764 - binary_accuracy: 0.5746
# Epoch 25: val_binary_accuracy did not improve from 0.55422
# 2467/2467 [==============================] - 21s 9ms/step - loss: 0.6764 - binary_accuracy: 0.5746 - val_loss: 0.6870 - val_binary_accuracy: 0.5492
# Epoch 26/150
# 2464/2467 [============================>.] - ETA: 0s - loss: 0.6756 - binary_accuracy: 0.5766
# Epoch 26: val_binary_accuracy did not improve from 0.55422
# 2467/2467 [==============================] - 23s 9ms/step - loss: 0.6756 - binary_accuracy: 0.5766 - val_loss: 0.6874 - val_binary_accuracy: 0.5484
# Epoch 27/150
# 2463/2467 [============================>.] - ETA: 0s - loss: 0.6755 - binary_accuracy: 0.5759
# Epoch 27: val_binary_accuracy did not improve from 0.55422
# 2467/2467 [==============================] - 24s 10ms/step - loss: 0.6755 - binary_accuracy: 0.5759 - val_loss: 0.6863 - val_binary_accuracy: 0.5496
# Epoch 28/150
# 2462/2467 [============================>.] - ETA: 0s - loss: 0.6748 - binary_accuracy: 0.5779
# Epoch 28: val_binary_accuracy did not improve from 0.55422
# 2467/2467 [==============================] - 21s 8ms/step - loss: 0.6748 - binary_accuracy: 0.5779 - val_loss: 0.6873 - val_binary_accuracy: 0.5497
# 353/353 [==============================] - 1s 3ms/step - loss: 0.6915 - binary_accuracy: 0.5369
# Loss: 0.6915
# Accuracy: 53.69%

# %%
import pandas as pd
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2,1, figsize = (15,15))
axs = axs.flatten()
axs[0].plot(history.history['binary_accuracy'])
axs[0].plot(history.history['val_binary_accuracy'])
axs[0].set_title('model accuracy')

axs[0].legend(['train', 'val'], loc='upper left')

# summarize history for loss
axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('model loss')

axs[1].legend(['train', 'val'], loc='upper left')


parameters_to_save = pd.read_csv(filepath)

parameters_to_save = parameters_to_save.append({'learning_rate' : my_learning_rate , 'num_hidden_layers' : num_hidden_layers  , 'regularizer' : regularizer, 
                              'num_neurons' : num_neurons, 'droput': dropout , 'optimizer' : optimizer, 
                              'train_loss' : history.history['loss'][-1] , 'val_loss' : history.history['val_loss'][-1] 
                              , 'train_accuracy' : history.history['binary_accuracy'][-1] , 'val_accuracy' : history.history['val_binary_accuracy'][-1],
                             'test_loss' : f"{loss:.4f}" , 'test_accuracy' : f"{accuracy*100:.2f}%" } , ignore_index = True ) 

parameters_to_save.to_csv(filepath, index=False)
