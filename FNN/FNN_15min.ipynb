# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pickle as pkl

with open('/content/drive/MyDrive/Colab Notebooks/Dataset_without_memory/dataset.pickle', 'rb') as f:
    dataset = pkl.load(f)

with open('/content/drive/MyDrive/Colab Notebooks/Dataset_without_memory/labels.pickle', 'rb') as f:
    labels = pkl.load(f)

dataset.shape , labels.shape
# Out:
# ((405960, 50), (405960, 5))

# %%
labels = labels['15m class']
dataset = dataset.iloc[: , 1:]

# %%
import numpy as np
index1 = int(len(dataset) * 7/9)
index2 = int (len(dataset) * 8/9)


dataset_train , labels_train  = np.asarray(dataset[: index1]).astype('float32') , np.asarray(labels[:index1 ]).astype('float32')

dataset_val , labels_val = np.asarray(dataset[index1 : index2 ]).astype('float32') , np.asarray(labels[index1 : index2]).astype('float32')

dataset_test , labels_test = np.asarray(dataset[index2 :  ]).astype('float32') , np.asarray(labels[index2:]).astype('float32')

# %%
from sklearn.utils.class_weight import compute_class_weight



class_weights = compute_class_weight(
                                        class_weight = "balanced",
                                        classes = np.unique ( np.reshape( labels_train , (np.shape(labels_train)[0]))),
                                        y = np.reshape(labels_train ,(np.shape(labels_train)[0]))                                                 
                                    )
class_weights = dict(zip(np.unique(np.reshape(labels_train ,(np.shape(labels_train)[0]))), class_weights))
class_weights
# Out:
# {0.0: 1.0256088767044975, 1.0: 0.9756388468312579}

# %%
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings('ignore')

def standardization( dataframe1, dataframe2, dataframe3  ):
  ###we start the for loop form the second column because the first column is timesteps 
  for i in range (dataframe1.shape[1]):
    
    retrn_data = dataframe1[:, i].reshape(-1, 1)

    scaler = StandardScaler()
    retrn_data_standardized = scaler.fit_transform(retrn_data)

    dataframe1[: , i] = retrn_data_standardized.flatten()


##########validation data
    retrn_data = dataframe2[:, i].reshape(-1, 1)

    retrn_data_standardized = scaler.transform(retrn_data)

    dataframe2[: , i] = retrn_data_standardized.flatten()

##########test data

    retrn_data = dataframe3[:, i].reshape(-1, 1)

    retrn_data_standardized = scaler.transform(retrn_data)

    dataframe3[: , i] = retrn_data_standardized.flatten()




  return dataframe1 , dataframe2, dataframe3

dataset_train , dataset_val , dataset_test = standardization(dataset_train , dataset_val , dataset_test)

# %%
import pandas as pd
import os


filepath = "/content/drive/MyDrive/parameter_tuning_15min.csv"

# check if the file exists, create it if not
if not os.path.isfile(filepath):
    columns_name = ['learning_rate' , 'num_hidden_layers', 'regularizer', 'num_neurons', 'droput' , 'optimizer' , 
                    'train_loss' , 'val_loss' , 'train_accuracy' , 'val_accuracy', 'test_loss' , 'test_accuracy']
    df = pd.DataFrame(columns=columns_name)  # create an empty dataframe
    df.to_csv(filepath, index=False)  # save as a CSV file with no index

# %%
from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from tensorflow import keras
from keras import regularizers
import tensorflow

#reproducibility 
np.random.seed(0)
tensorflow.random.set_seed(0)

def Create_model(my_learning_rate , num_hidden_layers, regularizer, num_neurons, droput , optimizer_fun):
    # Define the model
    model = Sequential()

    
    # Add layers
    model.add(Dense(num_neurons, activation='relu', input_shape=(dataset_train.shape[1],) ,kernel_regularizer=regularizers.l1(regularizer), bias_regularizer=regularizers.l1(regularizer)))
    model.add(BatchNormalization())
    model.add(Dropout(droput))
    num_neurons = int(num_neurons/2)


    for i in range(num_hidden_layers):
        model.add(Dense(num_neurons, activation='relu', kernel_regularizer=regularizers.l1(regularizer), bias_regularizer=regularizers.l1(regularizer)))
        model.add(BatchNormalization())
        model.add(Dropout(droput))
        num_neurons = int(num_neurons/2)

# model.add(Dense(128,kernel_regularizer=regularizers.l1(0.5), bias_regularizer=regularizers.l1(0.5)))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))

# model.add(Dense(64,kernel_regularizer=regularizers.l1(0.5), bias_regularizer=regularizers.l1(0.5)))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))

# model.add(Dense(32,kernel_regularizer=regularizers.l1(0.5), bias_regularizer=regularizers.l1(0.5)))
# model.add(BatchNormalization())
# model.add(Dropout(0.5))

    model.add(Dense(1, activation='sigmoid'))

    if (optimizer_fun == 'SGD'):
      optimizer = keras.optimizers.SGD(learning_rate=my_learning_rate)
    else:
      optimizer = keras.optimizers.Adam(learning_rate=my_learning_rate)



    # Compile the model
    model.compile(optimizer=optimizer, loss='binary_crossentropy', metrics=['binary_accuracy'] )

    # Print the summary of the model
    model.summary()

    return model

my_learning_rate = 0.0005
num_hidden_layers  = 4
regularizer = 0
num_neurons = 512
dropout = 0.5
optimizer = 'Adam'

model = Create_model(my_learning_rate, num_hidden_layers , regularizer , num_neurons , dropout , optimizer)
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 512)               25600
#
#  batch_normalization (BatchN  (None, 512)              2048
#  ormalization)
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  batch_normalization_1 (Batc  (None, 256)              1024
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  batch_normalization_2 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 64)                8256
#
#  batch_normalization_3 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_4 (Dense)             (None, 32)                2080
#
#  batch_normalization_4 (Batc  (None, 32)               128
#  hNormalization)
#
#  dropout_4 (Dropout)         (None, 32)                0
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 204,161
# Trainable params: 202,177
# Non-trainable params: 1,984
# _________________________________________________________________

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping


checkpoint_path = '/content/drive/MyDrive/my_best_model_FNN_15min.hdf5'

checkpoint = ModelCheckpoint(filepath=checkpoint_path, 
                             monitor='val_binary_accuracy',
                             verbose=1, 
                             save_best_only=True,
                             mode='max')


earlystopping = EarlyStopping(monitor='val_binary_accuracy', patience=10, restore_best_weights=True)

callback = [checkpoint, earlystopping]

# Train the model
history = model.fit(dataset_train, labels_train, validation_data=[dataset_val , labels_val], epochs=150, batch_size=128, callbacks=callback, class_weight=class_weights)

# Evaluate the model
loss, accuracy = model.evaluate(dataset_test, labels_test, batch_size=128)

print(f"Loss: {loss:.4f}")
print(f"Accuracy: {accuracy*100:.2f}%")
# Out:
# Epoch 1/150
# 2467/2467 [==============================] - ETA: 0s - loss: 0.7406 - binary_accuracy: 0.5011
# Epoch 1: val_binary_accuracy improved from -inf to 0.50258, saving model to /content/drive/MyDrive/my_best_model_FNN_15min.hdf5
# 2467/2467 [==============================] - 34s 9ms/step - loss: 0.7406 - binary_accuracy: 0.5011 - val_loss: 0.6930 - val_binary_accuracy: 0.5026
# Epoch 2/150
# 2465/2467 [============================>.] - ETA: 0s - loss: 0.6932 - binary_accuracy: 0.5051
# Epoch 2: val_binary_accuracy improved from 0.50258 to 0.53025, saving model to /content/drive/MyDrive/my_best_model_FNN_15min.hdf5
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6932 - binary_accuracy: 0.5051 - val_loss: 0.6921 - val_binary_accuracy: 0.5303
# Epoch 3/150
# 2466/2467 [============================>.] - ETA: 0s - loss: 0.6912 - binary_accuracy: 0.5273
# Epoch 3: val_binary_accuracy improved from 0.53025 to 0.53715, saving model to /content/drive/MyDrive/my_best_model_FNN_15min.hdf5
# 2467/2467 [==============================] - 23s 9ms/step - loss: 0.6912 - binary_accuracy: 0.5273 - val_loss: 0.6889 - val_binary_accuracy: 0.5371
# Epoch 4/150
# 2463/2467 [============================>.] - ETA: 0s - loss: 0.6892 - binary_accuracy: 0.5394
# Epoch 4: val_binary_accuracy improved from 0.53715 to 0.54047, saving model to /content/drive/MyDrive/my_best_model_FNN_15min.hdf5
# 2467/2467 [==============================] - 25s 10ms/step - loss: 0.6892 - binary_accuracy: 0.5394 - val_loss: 0.6885 - val_binary_accuracy: 0.5405
# Epoch 5/150
# 2464/2467 [============================>.] - ETA: 0s - loss: 0.6879 - binary_accuracy: 0.5455
# Epoch 5: val_binary_accuracy did not improve from 0.54047
# 2467/2467 [==============================] - 21s 8ms/step - loss: 0.6879 - binary_accuracy: 0.5455 - val_loss: 0.6884 - val_binary_accuracy: 0.5367
# Epoch 6/150
# 2466/2467 [============================>.] - ETA: 0s - loss: 0.6871 - binary_accuracy: 0.5478
# Epoch 6: val_binary_accuracy improved from 0.54047 to 0.54369, saving model to /content/drive/MyDrive/my_best_model_FNN_15min.hdf5
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6872 - binary_accuracy: 0.5478 - val_loss: 0.6878 - val_binary_accuracy: 0.5437
# Epoch 7/150
# 2467/2467 [==============================] - ETA: 0s - loss: 0.6865 - binary_accuracy: 0.5506
# Epoch 7: val_binary_accuracy did not improve from 0.54369
# 2467/2467 [==============================] - 21s 9ms/step - loss: 0.6865 - binary_accuracy: 0.5506 - val_loss: 0.6884 - val_binary_accuracy: 0.5375
# Epoch 8/150
# 2465/2467 [============================>.] - ETA: 0s - loss: 0.6857 - binary_accuracy: 0.5531
# Epoch 8: val_binary_accuracy did not improve from 0.54369
# 2467/2467 [==============================] - 21s 9ms/step - loss: 0.6857 - binary_accuracy: 0.5531 - val_loss: 0.6883 - val_binary_accuracy: 0.5415
# Epoch 9/150
# 2466/2467 [============================>.] - ETA: 0s - loss: 0.6848 - binary_accuracy: 0.5554
# Epoch 9: val_binary_accuracy did not improve from 0.54369
# 2467/2467 [==============================] - 21s 9ms/step - loss: 0.6848 - binary_accuracy: 0.5554 - val_loss: 0.6892 - val_binary_accuracy: 0.5411
# Epoch 10/150
# 2466/2467 [============================>.] - ETA: 0s - loss: 0.6839 - binary_accuracy: 0.5577
# Epoch 10: val_binary_accuracy did not improve from 0.54369
# 2467/2467 [==============================] - 21s 9ms/step - loss: 0.6839 - binary_accuracy: 0.5577 - val_loss: 0.6897 - val_binary_accuracy: 0.5373
# Epoch 11/150
# 2465/2467 [============================>.] - ETA: 0s - loss: 0.6831 - binary_accuracy: 0.5600
# Epoch 11: val_binary_accuracy did not improve from 0.54369
# 2467/2467 [==============================] - 24s 10ms/step - loss: 0.6831 - binary_accuracy: 0.5600 - val_loss: 0.6899 - val_binary_accuracy: 0.5402
# Epoch 12/150
# 2462/2467 [============================>.] - ETA: 0s - loss: 0.6821 - binary_accuracy: 0.5618
# Epoch 12: val_binary_accuracy did not improve from 0.54369
# 2467/2467 [==============================] - 21s 9ms/step - loss: 0.6821 - binary_accuracy: 0.5617 - val_loss: 0.6900 - val_binary_accuracy: 0.5376
# Epoch 13/150
# 2467/2467 [==============================] - ETA: 0s - loss: 0.6815 - binary_accuracy: 0.5631
# Epoch 13: val_binary_accuracy did not improve from 0.54369
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6815 - binary_accuracy: 0.5631 - val_loss: 0.6902 - val_binary_accuracy: 0.5395
# Epoch 14/150
# 2467/2467 [==============================] - ETA: 0s - loss: 0.6808 - binary_accuracy: 0.5650
# Epoch 14: val_binary_accuracy did not improve from 0.54369
# 2467/2467 [==============================] - 22s 9ms/step - loss: 0.6808 - binary_accuracy: 0.5650 - val_loss: 0.6911 - val_binary_accuracy: 0.5386
# Epoch 15/150
# 2463/2467 [============================>.] - ETA: 0s - loss: 0.6798 - binary_accuracy: 0.5671
# Epoch 15: val_binary_accuracy did not improve from 0.54369
# 2467/2467 [==============================] - 21s 9ms/step - loss: 0.6798 - binary_accuracy: 0.5671 - val_loss: 0.6928 - val_binary_accuracy: 0.5400
# Epoch 16/150
# 2466/2467 [============================>.] - ETA: 0s - loss: 0.6791 - binary_accuracy: 0.5689
# Epoch 16: val_binary_accuracy did not improve from 0.54369
# 2467/2467 [==============================] - 23s 9ms/step - loss: 0.6791 - binary_accuracy: 0.5689 - val_loss: 0.6909 - val_binary_accuracy: 0.5403
# 353/353 [==============================] - 1s 3ms/step - loss: 0.6878 - binary_accuracy: 0.5464
# Loss: 0.6878
# Accuracy: 54.64%

# %%
import pandas as pd
import matplotlib.pyplot as plt

fig, axs = plt.subplots(2,1, figsize = (15,15))
axs = axs.flatten()
axs[0].plot(history.history['binary_accuracy'])
axs[0].plot(history.history['val_binary_accuracy'])
axs[0].set_title('model accuracy')

axs[0].legend(['train', 'val'], loc='upper left')

# summarize history for loss
axs[1].plot(history.history['loss'])
axs[1].plot(history.history['val_loss'])
axs[1].set_title('model loss')

axs[1].legend(['train', 'val'], loc='upper left')


parameters_to_save = pd.read_csv(filepath)

parameters_to_save = parameters_to_save.append({'learning_rate' : my_learning_rate , 'num_hidden_layers' : num_hidden_layers  , 'regularizer' : regularizer, 
                              'num_neurons' : num_neurons, 'droput': dropout , 'optimizer' : optimizer, 
                              'train_loss' : history.history['loss'][-1] , 'val_loss' : history.history['val_loss'][-1] 
                              , 'train_accuracy' : history.history['binary_accuracy'][-1] , 'val_accuracy' : history.history['val_binary_accuracy'][-1],
                             'test_loss' : f"{loss:.4f}" , 'test_accuracy' : f"{accuracy*100:.2f}%" } , ignore_index = True ) 

parameters_to_save.to_csv(filepath, index=False)
